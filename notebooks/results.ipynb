# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/production/database.csv")
data
# Out:
# /tmp/ipykernel_155539/2947733450.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/production/database.csv")
#                  code                                                url  \
# 0                   5  http://world-en.openfoodfacts.org/product/0000...
# 1                  10  http://world-en.openfoodfacts.org/product/0000...
# 2                  15  http://world-en.openfoodfacts.org/product/0000...
# 3                  20  http://world-en.openfoodfacts.org/product/0000...
# 4                  22  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 320436  9999864004549  http://world-en.openfoodfacts.org/product/9999...
# 320437  9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 320438  9999991042704  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
biggest_cluster = data[data["cluster_text"] == 366]
display(biggest_cluster["product_name"].head(50))
# Out:
# 26                                 Bio Gerstengras Pulver
# 34                                         Passiflore BIO
# 39                                               Encore +
# 43                                  collagen skin booster
# 44                                     Thé noir Assam bio
# 93                                                 Maraes
# 97                                                Hydrate
# 134                                              Dictator
# 143                                      Hard Boiled Eggs
# 144                              Complejo Multivitaminico
# 146                                             Niteworks
# 157                                                   vin
# 167                                Electrolytes en poudre
# 184                         Moustapha issa issa souleyman
# 193                                               Tic Tac
# 276                                      Miel de Sarrasin
# ...

# %%
cluster = data[data["cluster_text"] == 124]
display(cluster["product_name"].head(50))
# Out:
# 267                                    2 Pâtes feuilletées
# 398                                        English Muffins
# 931                         Sea salt black pepper croutons
# 1231                                            Plain naan
# 1263                             Frozen Spring Roll Pastry
# 1980                             Pain Soft White Farmhouse
# 2702                        Medium sliced super soft white
# 2726                                      Gnocchi à poêler
# 3233                           Thick White Super Soft Loaf
# 4181                               6 super soft white baps
# 4652                          Medium White Super Soft Loaf
# 4747                                 Peanut Butter Crunchy
# 5091                                       Wholemeal rolls
# 5160                                     Tortillas grandes
# 5208                                         Eggo original
# 5398     Panure Assaisonnée Shake 'n Bake (poulet Crous...
# ...

# %%
cat_feat = pd.read_csv("../data/production/categorical_features.csv")

# %%
pd.set_option('display.max_columns', None)

display(cat_feat)
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.256591 -0.083747  0.047796  0.900420 -0.280977  0.057464  0.044577
# 1      -0.265005 -0.074533 -0.064067 -0.024236 -0.021165 -0.032712 -0.010122
# 2      -0.261706 -0.076841 -0.044593 -0.039716  0.008258 -0.030184 -0.011741
# 3      -0.261261 -0.021585 -0.033787  0.047180  0.287192  0.043234 -0.075801
# 4       0.725739 -0.153952 -0.111477 -0.030292  0.027245 -0.046148 -0.023135
# ...          ...       ...       ...       ...       ...       ...       ...
# 320436 -0.261026 -0.078595 -0.045590 -0.040708  0.001692 -0.030016 -0.019057
# 320437 -0.261026 -0.078595 -0.045590 -0.040708  0.001692 -0.030016 -0.019057
# 320438 -0.261932 -0.046988 -0.043470 -0.039183 -0.036914  0.058603  0.023882
# 320439 -0.261026 -0.078595 -0.045590 -0.040708  0.001692 -0.030016 -0.019057
# 320440 -0.261694 -0.079619 -0.046003 -0.041079 -0.001444 -0.030958 -0.021635
#
# ...
