# %%
import os
import sys

# Ajouter le répertoire parent au sys.path
sys.path.append(os.path.abspath('..'))

import re
from collections import Counter

import en_core_web_sm
import pandas as pd
import plotly.express as px
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.impute import SimpleImputer
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from spacy.lang.en.stop_words import STOP_WORDS

from training.classes.language_tools import TextProcessing

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Introduction et contexte
#
# Ce notebook a pour but de faire une première exploration des données mises à disposition par openfoodfacts pour répondre à notre problème qui est:
#
# quelle alternative à un produit alimentaire pourrait nous être proposé ?
#
# Dans ces alternatives, quels sont les produits qui ne contiennent pas de produit susceptible de provoquer une allergie alimentaire ?
#
# Le volume de données est important, nous allons nous concentrer sur les produits où la liste des ingrédients est renseignés et ou les produits sont vendus en france.

# %% [markdown]
# ## Chargement des Données

# %%
rawdata = None
def extract_raw_data():
    file_path = '../data/en.openfoodfacts.org.products.csv.gz'
    chunk_size = 10000

    filtered_chunks_list = []

    for chunk in pd.read_csv(file_path, chunksize=chunk_size, compression='gzip', sep='\t', engine='python', quoting=3):
        filtered_chunks = chunk[(chunk['countries_tags'] == 'en:france') & (chunk['ingredients_tags'].notna())]
        filtered_chunks_list.append(filtered_chunks)

    if filtered_chunks_list:
        rawdata = pd.concat(filtered_chunks_list, axis=0)
    return rawdata

rawdata = extract_raw_data()
# rawdata = pd.read_csv('filtered_dataset_openfoodfacts_raw_en.csv')
display(rawdata)
# Out:
#                   code                                                url  \
# 4                    5  http://world-en.openfoodfacts.org/product/0000...
# 9                   10  http://world-en.openfoodfacts.org/product/0000...
# 14                  15  http://world-en.openfoodfacts.org/product/0000...
# 18                  20  http://world-en.openfoodfacts.org/product/0000...
# 20                  22  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 3498741  9999864004549  http://world-en.openfoodfacts.org/product/9999...
# 3498753  9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 3498810  9999991042704  http://world-en.openfoodfacts.org/product/9999...
# 3498834  9999999004360  http://world-en.openfoodfacts.org/product/9999...
# 3498839       99999995  http://world-en.openfoodfacts.org/product/9999...
#
#                             creator   created_t      created_datetime  \
# 4                         touchette  1605337720  2020-11-14T07:08:40Z
# 9                          jeanbono  1476947941  2016-10-20T07:19:01Z
# 14       openfoodfacts-contributors  1523810594  2018-04-15T16:43:14Z
# 18       openfoodfacts-contributors  1536930846  2018-09-14T13:14:06Z
# 20       openfoodfacts-contributors  1614525537  2021-02-28T15:18:57Z
# ...                             ...         ...                   ...
# 3498741  openfoodfacts-contributors  1564657971  2019-08-01T11:12:51Z
# 3498753                     kiliweb  1515171187  2018-01-05T16:53:07Z
# 3498810                     kiliweb  1525862784  2018-05-09T10:46:24Z
# 3498834                     kiliweb  1548086277  2019-01-21T15:57:57Z
# 3498839                     kiliweb  1538818432  2018-10-06T09:33:52Z
#
#          last_modified_t last_modified_datetime last_modified_by  \
# 4             1729432954   2024-10-20T14:02:34Z       roboto-app
# 9             1728034727   2024-10-04T09:38:47Z     fix-code-bot
# 14            1728034730   2024-10-04T09:38:50Z     fix-code-bot
# 18            1728034733   2024-10-04T09:38:53Z     fix-code-bot
# 20            1728034734   2024-10-04T09:38:54Z     fix-code-bot
# ...                  ...                    ...              ...
# 3498741       1564658722   2019-08-01T11:25:22Z       roboto-app
# 3498753       1515171193   2018-01-05T16:53:13Z              NaN
# 3498810       1718572213   2024-06-16T21:10:13Z          geodata
# 3498834       1682697806   2023-04-28T16:03:26Z       roboto-app
# 3498839       1725169096   2024-09-01T05:38:16Z       quentinbrd
#
#          last_updated_t last_updated_datetime            product_name  \
# 4          1.729433e+09  2024-10-20T14:02:34Z              Bio inulin
# 9          1.729852e+09  2024-10-25T10:25:56Z       Madeleines nature
# 14         1.729852e+09  2024-10-25T10:25:56Z    Madeleines ChocoLait
# 18         1.729852e+09  2024-10-25T10:25:56Z   Madeleines Choco Noir
# 20         1.729852e+09  2024-10-25T10:25:55Z  Farandole de madeleine
# ...                 ...                   ...                     ...
# 3498741    1.729988e+09  2024-10-27T00:08:44Z     Boudin à l’ancienne
# 3498753    1.707599e+09  2024-02-10T21:06:07Z                 Kabanos
# 3498810    1.729873e+09  2024-10-25T16:12:01Z          Yaourt vanille
# 3498834    1.707611e+09  2024-02-11T00:22:00Z          Minis beignets
# 3498839    1.729859e+09  2024-10-25T12:18:53Z          Steak haché 5%
#
#         abbreviated_product_name  \
# 4                            NaN
# 9                            NaN
# 14                           NaN
# 18                           NaN
# 20                           NaN
# ...                          ...
# 3498741                      NaN
# 3498753                      NaN
# 3498810                      NaN
# 3498834                      NaN
# 3498839                      NaN
#
#                                               generic_name  \
# 4                                                      NaN
# 9                                                      NaN
# 14                                                     NaN
# 18                                                     NaN
# 20                                                     NaN
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834  Minis beignets Beignet au sucre, surgelé, prêt...
# 3498839                                                NaN
#
#                        quantity  \
# 4                          550g
# 9                         880 g
# 14                       1080 g
# 18       1080 g / 50 madeleines
# 20                        590 g
# ...                         ...
# 3498741                    240g
# 3498753                     NaN
# 3498810                   120 g
# 3498834                9 x 15 g
# 3498839                     NaN
#
#                                                  packaging  \
# 4                                                    Glass
# 9        Plastic,Cardboard,fr:Boîte en carton,fr:Film e...
# 14                                       Plastique, Carton
# 18       1 boîte en carton à recycler 50 sachets indivi...
# 20                      Boîte en carton, Film en plastique
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                             packaging_tags  \
# 4                                                 en:glass
# 9        en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14                                 en:plastic,en:cardboard
# 18       fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20                 fr:boite-en-carton,fr:film-en-plastique
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                               packaging_en packaging_text  \
# 4                                                    Glass            NaN
# 9        Plastic,Cardboard,fr:boite-en-carton,fr:film-e...            NaN
# 14                                       Plastic,Cardboard            NaN
# 18       fr:1-boite-en-carton-a-recycler-50-sachets-ind...            NaN
# 20                 fr:boite-en-carton,fr:film-en-plastique            NaN
# ...                                                    ...            ...
# 3498741                                                NaN            NaN
# 3498753                                                NaN            NaN
# 3498810                                                NaN            NaN
# 3498834                                                NaN            NaN
# 3498839                                                NaN            NaN
#
#                        brands           brands_tags  \
# 4                         EWL                   ewl
# 9                       Bijou                 bijou
# 14                      Bijou                 bijou
# 18                      BIJOU                 bijou
# 20                      Bijou                 bijou
# ...                       ...                   ...
# 3498741  Biocoop Bordeaux lac  biocoop-bordeaux-lac
# 3498753            Tarczynski            tarczynski
# 3498810              Patapain              patapain
# 3498834                   NaN                   NaN
# 3498839                   NaN                   NaN
#
#                                                 categories  \
# 4                                                   Gemüse
# 9        Snacks, Desserts, Snacks sucrés, Biscuits et g...
# 14       Snacks, Snacks sucrés, Biscuits et gâteaux, Gâ...
# 18       Snacks, Snacks sucrés, Biscuits et gâteaux, Gâ...
# 20       Snacks, Snacks sucrés, Biscuits et gâteaux, Gâ...
# ...                                                    ...
# 3498741  Viandes et dérivés, Viandes, Charcuteries, Poi...
# 3498753                                                NaN
# 3498810                                    Yaourts vanille
# 3498834             Snacks, Snacks sucrés, Beignets sucrés
# 3498839  Viandes et dérivés,Viande de bœuf et dérivés,P...
#
#                                            categories_tags  \
# 4        en:plant-based-foods-and-beverages,en:plant-ba...
# 9        en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# ...                                                    ...
# 3498741  en:meats-and-their-products,en:meats,en:prepar...
# 3498753                                                NaN
# 3498810  en:dairies,en:fermented-foods,en:fermented-mil...
# 3498834        en:snacks,en:sweet-snacks,en:sweet-fritters
# 3498839  en:meats-and-their-products,en:beef-and-its-pr...
#
#                                              categories_en  \
# 4        Plant-based foods and beverages,Plant-based fo...
# 9        Snacks,Desserts,Sweet snacks,Biscuits and cake...
# 14       Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...
# 18       Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...
# 20       Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...
# ...                                                    ...
# 3498741  Meats and their products,Meats,Prepared meats,...
# 3498753                                                NaN
# 3498810  Dairies,Fermented foods,Fermented milk product...
# 3498834                 Snacks,Sweet snacks,Sweet Fritters
# 3498839  Meats and their products,Beef and its products...
#
#                                               origins  \
# 4                                                 NaN
# 9                                                 NaN
# 14                                                NaN
# 18       fr:Blé origine France,fr:Œufs origine France
# 20                                                NaN
# ...                                               ...
# 3498741                                           NaN
# 3498753                                           NaN
# 3498810                                           NaN
# 3498834                                           NaN
# 3498839                                           NaN
#
#                                           origins_tags  \
# 4                                                  NaN
# 9                                                  NaN
# 14                                                 NaN
# 18       fr:ble-origine-france,fr:oeufs-origine-france
# 20                                                 NaN
# ...                                                ...
# 3498741                                            NaN
# 3498753                                            NaN
# 3498810                                            NaN
# 3498834                                            NaN
# 3498839                                            NaN
#
#                                             origins_en manufacturing_places  \
# 4                                                  NaN        bénivay-ollon
# 9                                                  NaN               France
# 14                                                 NaN                  NaN
# 18       fr:ble-origine-france,fr:oeufs-origine-france  Saint-Yrieix,France
# 20                                                 NaN                  NaN
# ...                                                ...                  ...
# 3498741                                            NaN                  NaN
# 3498753                                            NaN                  NaN
# 3498810                                            NaN                  NaN
# 3498834                                            NaN                  NaN
# 3498839                                            NaN                  NaN
#
#         manufacturing_places_tags  \
# 4                   benivay-ollon
# 9                          france
# 14                            NaN
# 18            saint-yrieix,france
# 20                            NaN
# ...                           ...
# 3498741                       NaN
# 3498753                       NaN
# 3498810                       NaN
# 3498834                       NaN
# 3498839                       NaN
#
#                                                     labels  \
# 4                                            en:no-lactose
# 9          Point Vert, Sans colorants, Sans huile de palme
# 14                                                     NaN
# 18       Plein air, Sans conservateurs, Œufs de poules ...
# 20                                                     NaN
# ...                                                    ...
# 3498741                       Bio, Bio européen, FR-BIO-01
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839           Viande Française,Viande Bovine Française
#
#                                                labels_tags  \
# 4                                            en:no-lactose
# 9              en:green-dot,en:no-colorings,en:no-palm-oil
# 14                                                     NaN
# 18       en:free-range,en:no-preservatives,en:free-rang...
# 20                                                     NaN
# ...                                                    ...
# 3498741              en:organic,en:eu-organic,en:fr-bio-01
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                      en:french-meat,en:french-beef
#
#                                                  labels_en         emb_codes  \
# 4                                               No lactose            13089c
# 9                       Green Dot,No colorings,No palm oil               NaN
# 14                                                     NaN               NaN
# 18       Free range,No preservatives,Free range eggs,Gr...               NaN
# 20                                                     NaN               NaN
# ...                                                    ...               ...
# 3498741                       Organic,EU Organic,FR-BIO-01               NaN
# 3498753                                                NaN               NaN
# 3498810                                                NaN  FR 13.005.028 EC
# 3498834                                                NaN               NaN
# 3498839                            French meat,French beef               NaN
#
#            emb_codes_tags first_packaging_code_geo  cities  \
# 4                  13089c                      NaN     NaN
# 9                     NaN                      NaN     NaN
# 14                    NaN                      NaN     NaN
# 18                    NaN                      NaN     NaN
# 20                    NaN                      NaN     NaN
# ...                   ...                      ...     ...
# 3498741               NaN                      NaN     NaN
# 3498753               NaN                      NaN     NaN
# 3498810  fr-13-005-028-ec       43.283333,5.566667     NaN
# 3498834               NaN                      NaN     NaN
# 3498839               NaN                      NaN     NaN
#
#                              cities_tags      purchase_places  \
# 4                                    NaN               France
# 9                                    NaN  Lyon,France,Limoges
# 14                                   NaN                  NaN
# 18                                   NaN               France
# 20                                   NaN                  NaN
# ...                                  ...                  ...
# 3498741                              NaN                  NaN
# 3498753                              NaN                  NaN
# 3498810  aubagne-bouches-du-rhone-france                  NaN
# 3498834                              NaN                  NaN
# 3498839                              NaN                  NaN
#
#                                                     stores  countries  \
# 4                                                      NaN     France
# 9                                                M2I,Bijou     France
# 14                                                     NaN     France
# 18       magasin d'usine,magasin Bijou bordeaux,magasin...     France
# 20                                                     NaN  en:France
# ...                                                    ...        ...
# 3498741                                            Biocoop  en:France
# 3498753                                                NaN     France
# 3498810                                                NaN     France
# 3498834                                                NaN     France
# 3498839                                                NaN     France
#
#         countries_tags countries_en  \
# 4            en:france       France
# 9            en:france       France
# 14           en:france       France
# 18           en:france       France
# 20           en:france       France
# ...                ...          ...
# 3498741      en:france       France
# 3498753      en:france       France
# 3498810      en:france       France
# 3498834      en:france       France
# 3498839      en:france       France
#
#                                           ingredients_text  \
# 4               Jus et purée d'abricots (50%), eau, sucre.
# 9        Farine de blé 33%, sucre, huile de colza, œufs...
# 14       Farine de blé 27%, chocolat au lait 18% (sucre...
# 18       Farine de _blé_ 27%, chocolat noir 18% (pâte d...
# 20       Madeleines ChocoNoir - Madeleines nappées de c...
# ...                                                    ...
# 3498741  BIOCOOP BORDEAUX LAC distribue par les eleveur...
# 3498753  KABANOSÈRÇ Sktadn' wiep -zEkrobia, Guszcz 'o.e...
# 3498810  Lait entier 77%, crème, sucre 7,5%, ferments l...
# 3498834  MATIÈRE GRASSE DU LAIT BABEURRE (34%), FARINE ...
# 3498839  VIANDE HACHEE PUR BOEUF 5% M,G, POURCENTAGE DE...
#
#                                           ingredients_tags  \
# 4        en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9        en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20       fr:madeleines-choconoir,fr:madeleines-nappees-...
# ...                                                    ...
# 3498741  fr:biocoop-bordeaux-lac-distribue-par-les-elev...
# 3498753  fr:kabanoserc-sktadn-wiep,fr:zekrobia,fr:guszc...
# 3498810  en:whole-milk,en:dairy,en:milk,en:cream,en:sug...
# 3498834  fr:matiere-grasse-du-lait-babeurre,fr:farine-d...
# 3498839  fr:viande-hachee-pur-boeuf-5-m,fr:g,fr:pourcen...
#
#                                  ingredients_analysis_tags  \
# 4                  en:palm-oil-free,en:vegan,en:vegetarian
# 9        en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 14       en:palm-oil-free,en:non-vegan,en:maybe-vegetarian
# 18       en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 20       en:palm-oil-content-unknown,en:non-vegan,en:ve...
# ...                                                    ...
# 3498741  en:may-contain-palm-oil,en:non-vegan,en:non-ve...
# 3498753  en:palm-oil-content-unknown,en:vegan-status-un...
# 3498810  en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 3498834  en:palm-oil,en:non-vegan,en:vegetarian-status-...
# 3498839  en:palm-oil-content-unknown,en:vegan-status-un...
#
#                                      allergens  allergens_en  \
# 4                                          NaN           NaN
# 9                    en:eggs,en:gluten,en:milk           NaN
# 14                                         NaN           NaN
# 18       en:eggs,en:gluten,en:milk,en:soybeans           NaN
# 20                                         NaN           NaN
# ...                                        ...           ...
# 3498741                                    NaN           NaN
# 3498753                                    NaN           NaN
# 3498810                                en:milk           NaN
# 3498834                                    NaN           NaN
# 3498839                                    NaN           NaN
#
#                       traces                traces_tags         traces_en  \
# 4                        NaN                        NaN               NaN
# 9        en:nuts,en:soybeans        en:nuts,en:soybeans     Nuts,Soybeans
# 14                   en:nuts                    en:nuts              Nuts
# 18                   en:nuts                    en:nuts              Nuts
# 20                       NaN                    en:nuts              Nuts
# ...                      ...                        ...               ...
# 3498741                  NaN                        NaN               NaN
# 3498753                  NaN                        NaN               NaN
# 3498810                  NaN  en:eggs,en:gluten,en:nuts  Eggs,Gluten,Nuts
# 3498834                  NaN            en:sesame-seeds      Sesame seeds
# 3498839                  NaN                        NaN               NaN
#
#         serving_size  serving_quantity no_nutrition_data  additives_n  \
# 4                NaN               NaN               NaN          0.0
# 9              17,6g              17.6               NaN          3.0
# 14             21,6g              21.6               NaN          5.0
# 18             21.6g              21.6               NaN          5.0
# 20               NaN               NaN               off          5.0
# ...              ...               ...               ...          ...
# 3498741          NaN               NaN                on          0.0
# 3498753          NaN               NaN               NaN          0.0
# 3498810          NaN               NaN               NaN          0.0
# 3498834          NaN               NaN               NaN          5.0
# 3498839          NaN               NaN               NaN          0.0
#
#         additives                                     additives_tags  \
# 4             NaN                                                NaN
# 9             NaN                            en:e331,en:e422,en:e503
# 14            NaN   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# 18            NaN            en:e322,en:e331,en:e422,en:e500,en:e503
# 20            NaN   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# ...           ...                                                ...
# 3498741       NaN                                                NaN
# 3498753       NaN                                                NaN
# 3498810       NaN                                                NaN
# 3498834       NaN  en:e322,en:e322i,en:e412,en:e450,en:e471,en:e5...
# 3498839       NaN                                                NaN
#
#                                               additives_en  nutriscore_score  \
# 4                                                      NaN              -2.0
# 9        E331 - Sodium citrates,E422 - Glycerol,E503 - ...              13.0
# 14       E322 - Lecithins,E322i - Lecithin,E331 - Sodiu...              17.0
# 18       E322 - Lecithins,E331 - Sodium citrates,E422 -...              16.0
# 20       E322 - Lecithins,E322i - Lecithin,E331 - Sodiu...               NaN
# ...                                                    ...               ...
# 3498741                                                NaN               NaN
# 3498753                                                NaN               NaN
# 3498810                                                NaN               7.0
# 3498834  E322 - Lecithins,E322i - Lecithin,E412 - Guar ...              15.0
# 3498839                                                NaN              -2.0
#
#         nutriscore_grade  nova_group            pnns_groups_1  \
# 4                      a         3.0    Fruits and vegetables
# 9                      d         4.0            Sugary snacks
# 14                     d         4.0            Sugary snacks
# 18                     d         4.0            Sugary snacks
# 20               unknown         4.0            Sugary snacks
# ...                  ...         ...                      ...
# 3498741          unknown         3.0           Fish Meat Eggs
# 3498753          unknown         NaN                  unknown
# 3498810                c         3.0  Milk and dairy products
# 3498834                d         4.0                  unknown
# 3498839                a         NaN           Fish Meat Eggs
#
#               pnns_groups_2                 food_groups  \
# 4                Vegetables               en:vegetables
# 9        Biscuits and cakes       en:biscuits-and-cakes
# 14       Biscuits and cakes       en:biscuits-and-cakes
# 18       Biscuits and cakes       en:biscuits-and-cakes
# 20       Biscuits and cakes       en:biscuits-and-cakes
# ...                     ...                         ...
# 3498741              Offals                   en:offals
# 3498753             unknown                         NaN
# 3498810     Milk and yogurt          en:milk-and-yogurt
# 3498834             unknown                         NaN
# 3498839                Meat  en:meat-other-than-poultry
#
#                                           food_groups_tags  \
# 4                   en:fruits-and-vegetables,en:vegetables
# 9                   en:sugary-snacks,en:biscuits-and-cakes
# 14                  en:sugary-snacks,en:biscuits-and-cakes
# 18                  en:sugary-snacks,en:biscuits-and-cakes
# 20                  en:sugary-snacks,en:biscuits-and-cakes
# ...                                                    ...
# 3498741                        en:fish-meat-eggs,en:offals
# 3498753                                                NaN
# 3498810      en:milk-and-dairy-products,en:milk-and-yogurt
# 3498834                                                NaN
# 3498839  en:fish-meat-eggs,en:meat,en:meat-other-than-p...
#
#                                         food_groups_en  \
# 4                     Fruits and vegetables,Vegetables
# 9                     Sugary snacks,Biscuits and cakes
# 14                    Sugary snacks,Biscuits and cakes
# 18                    Sugary snacks,Biscuits and cakes
# 20                    Sugary snacks,Biscuits and cakes
# ...                                                ...
# 3498741                        Fish‚ Meat‚ Eggs,Offals
# 3498753                                            NaN
# 3498810        Milk and dairy products,Milk and yogurt
# 3498834                                            NaN
# 3498839  Fish‚ Meat‚ Eggs,Meat,Meat other than poultry
#
#                                                     states  \
# 4        en:to-be-completed, en:nutrition-facts-complet...
# 9        en:to-be-completed, en:nutrition-facts-complet...
# 14       en:to-be-completed, en:nutrition-facts-complet...
# 18       en:to-be-checked, en:complete, en:nutrition-fa...
# 20       en:to-be-completed, en:nutrition-facts-complet...
# ...                                                    ...
# 3498741  en:to-be-completed, en:nutrition-facts-complet...
# 3498753  en:to-be-completed, en:nutrition-facts-complet...
# 3498810  en:to-be-completed, en:nutrition-facts-complet...
# 3498834  en:to-be-completed, en:nutrition-facts-complet...
# 3498839  en:to-be-completed, en:nutrition-facts-complet...
#
#                                                states_tags  \
# 4        en:to-be-completed,en:nutrition-facts-complete...
# 9        en:to-be-completed,en:nutrition-facts-complete...
# 14       en:to-be-completed,en:nutrition-facts-complete...
# 18       en:to-be-checked,en:complete,en:nutrition-fact...
# 20       en:to-be-completed,en:nutrition-facts-complete...
# ...                                                    ...
# 3498741  en:to-be-completed,en:nutrition-facts-complete...
# 3498753  en:to-be-completed,en:nutrition-facts-complete...
# 3498810  en:to-be-completed,en:nutrition-facts-complete...
# 3498834  en:to-be-completed,en:nutrition-facts-complete...
# 3498839  en:to-be-completed,en:nutrition-facts-complete...
#
#                                                  states_en brand_owner  \
# 4        To be completed,Nutrition facts completed,Ingr...         NaN
# 9        To be completed,Nutrition facts completed,Ingr...         NaN
# 14       To be completed,Nutrition facts completed,Ingr...         NaN
# 18       To be checked,Complete,Nutrition facts complet...         NaN
# 20       To be completed,Nutrition facts completed,Ingr...         NaN
# ...                                                    ...         ...
# 3498741  To be completed,Nutrition facts completed,Ingr...         NaN
# 3498753  To be completed,Nutrition facts completed,Ingr...         NaN
# 3498810  To be completed,Nutrition facts completed,Ingr...         NaN
# 3498834  To be completed,Nutrition facts completed,Ingr...         NaN
# 3498839  To be completed,Nutrition facts completed,Ingr...         NaN
#
#          ecoscore_score ecoscore_grade  \
# 4                   NaN        unknown
# 9                  53.0              c
# 14                 32.0              d
# 18                 39.0              d
# 20                 41.0              d
# ...                 ...            ...
# 3498741            86.0              a
# 3498753             NaN        unknown
# 3498810            67.0              b
# 3498834             NaN        unknown
# 3498839           -20.0              f
#
#                                       nutrient_levels_tags  product_quantity  \
# 4        en:fat-in-low-quantity,en:saturated-fat-in-low...             550.0
# 9        en:fat-in-high-quantity,en:saturated-fat-in-mo...             880.0
# 14       en:fat-in-high-quantity,en:saturated-fat-in-hi...            1080.0
# 18       en:fat-in-high-quantity,en:saturated-fat-in-hi...            1080.0
# 20                                                     NaN             590.0
# ...                                                    ...               ...
# 3498741                                                NaN             240.0
# 3498753                                                NaN               NaN
# 3498810  en:fat-in-moderate-quantity,en:saturated-fat-i...             120.0
# 3498834  en:fat-in-high-quantity,en:saturated-fat-in-hi...             135.0
# 3498839  en:fat-in-moderate-quantity,en:saturated-fat-i...               NaN
#
#         owner data_quality_errors_tags  unique_scans_n  \
# 4         NaN                      NaN             NaN
# 9         NaN                      NaN            17.0
# 14        NaN                      NaN            14.0
# 18        NaN                      NaN            21.0
# 20        NaN                      NaN             2.0
# ...       ...                      ...             ...
# 3498741   NaN                      NaN             1.0
# 3498753   NaN                      NaN             NaN
# 3498810   NaN                      NaN             1.0
# 3498834   NaN                      NaN             NaN
# 3498839   NaN                      NaN             2.0
#
#                                            popularity_tags  completeness  \
# 4                                                      NaN        0.8875
# 9        top-50000-scans-2019,top-100000-scans-2019,at-...        0.8875
# 14       top-50000-scans-2019,top-100000-scans-2019,at-...        0.7875
# 18       top-50000-scans-2019,top-100000-scans-2019,at-...        0.9000
# 20       top-75-percent-scans-2020,top-80-percent-scans...        0.8000
# ...                                                    ...           ...
# 3498741  bottom-25-percent-scans-2019,bottom-20-percent...        0.7750
# 3498753                                                NaN        0.4750
# 3498810  bottom-25-percent-scans-2019,bottom-20-percent...        0.7750
# 3498834                                                NaN        0.5750
# 3498839  bottom-25-percent-scans-2019,bottom-20-percent...        0.4750
#
#          last_image_t   last_image_datetime             main_category  \
# 4        1.729432e+09  2024-10-20T13:51:45Z             en:vegetables
# 9        1.636213e+09  2021-11-06T15:34:48Z       en:plain-madeleines
# 14       1.636214e+09  2021-11-06T15:46:13Z   en:chocolate-madeleines
# 18       1.687002e+09  2023-06-17T11:42:30Z   en:chocolate-madeleines
# 20       1.614526e+09  2021-02-28T15:20:00Z        en:long-madeleines
# ...               ...                   ...                       ...
# 3498741  1.564658e+09  2019-08-01T11:12:52Z  en:sauteed-black-pudding
# 3498753  1.515171e+09  2018-01-05T16:53:12Z                       NaN
# 3498810  1.718572e+09  2024-06-16T21:08:23Z         en:vanilla-yogurt
# 3498834  1.548086e+09  2019-01-21T15:58:00Z         en:sweet-fritters
# 3498839  1.607509e+09  2020-12-09T10:16:01Z                en:viandes
#
#               main_category_en  \
# 4                   Vegetables
# 9             Plain madeleines
# 14        Chocolate madeleines
# 18        Chocolate madeleines
# 20             Long madeleines
# ...                        ...
# 3498741  Sautéed black pudding
# 3498753                    NaN
# 3498810         Vanilla yogurt
# 3498834         Sweet Fritters
# 3498839                Viandes
#
#                                                  image_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                            image_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                      image_ingredients_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                image_ingredients_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                        image_nutrition_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                  image_nutrition_small_url  energy-kj_100g  \
# 4        https://images.openfoodfacts.org/images/produc...           840.0
# 9        https://images.openfoodfacts.org/images/produc...          1852.0
# 14       https://images.openfoodfacts.org/images/produc...          1926.0
# 18       https://images.openfoodfacts.org/images/produc...          1953.0
# 20       https://images.openfoodfacts.org/images/produc...             NaN
# ...                                                    ...             ...
# 3498741                                                NaN             NaN
# 3498753                                                NaN             NaN
# 3498810                                                NaN             NaN
# 3498834                                                NaN             NaN
# 3498839                                                NaN             NaN
#
#          energy-kcal_100g  energy_100g  energy-from-fat_100g  fat_100g  \
# 4                   208.0        840.0                   NaN       0.0
# 9                   442.0       1852.0                   NaN      22.0
# 14                  460.0       1926.0                   NaN      24.0
# 18                  467.0       1953.0                   NaN      25.0
# 20                    NaN          NaN                   NaN       NaN
# ...                   ...          ...                   ...       ...
# 3498741               NaN          NaN                   NaN       NaN
# 3498753             549.0       2297.0                   NaN      48.0
# 3498810             128.0        536.0                   NaN       7.6
# 3498834             333.0       1393.0                   NaN      20.2
# 3498839             131.0        548.0                   NaN       5.0
#
#          saturated-fat_100g  butyric-acid_100g  caproic-acid_100g  \
# 4                       0.0                NaN                NaN
# 9                       2.6                NaN                NaN
# 14                      6.0                NaN                NaN
# 18                      6.1                NaN                NaN
# 20                      NaN                NaN                NaN
# ...                     ...                ...                ...
# 3498741                 NaN                NaN                NaN
# 3498753                18.0                NaN                NaN
# 3498810                 5.1                NaN                NaN
# 3498834                 6.0                NaN                NaN
# 3498839                 2.3                NaN                NaN
#
#          caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 4                       NaN               NaN               NaN
# 9                       NaN               NaN               NaN
# 14                      NaN               NaN               NaN
# 18                      NaN               NaN               NaN
# 20                      NaN               NaN               NaN
# ...                     ...               ...               ...
# 3498741                 NaN               NaN               NaN
# 3498753                 NaN               NaN               NaN
# 3498810                 NaN               NaN               NaN
# 3498834                 NaN               NaN               NaN
# 3498839                 NaN               NaN               NaN
#
#          myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
# 4                       NaN                 NaN                NaN
# 9                       NaN                 NaN                NaN
# 14                      NaN                 NaN                NaN
# 18                      NaN                 NaN                NaN
# 20                      NaN                 NaN                NaN
# ...                     ...                 ...                ...
# 3498741                 NaN                 NaN                NaN
# 3498753                 NaN                 NaN                NaN
# 3498810                 NaN                 NaN                NaN
# 3498834                 NaN                 NaN                NaN
# 3498839                 NaN                 NaN                NaN
#
#          arachidic-acid_100g  behenic-acid_100g  lignoceric-acid_100g  \
# 4                        NaN                NaN                   NaN
# 9                        NaN                NaN                   NaN
# 14                       NaN                NaN                   NaN
# 18                       NaN                NaN                   NaN
# 20                       NaN                NaN                   NaN
# ...                      ...                ...                   ...
# 3498741                  NaN                NaN                   NaN
# 3498753                  NaN                NaN                   NaN
# 3498810                  NaN                NaN                   NaN
# 3498834                  NaN                NaN                   NaN
# 3498839                  NaN                NaN                   NaN
#
#          cerotic-acid_100g  montanic-acid_100g  melissic-acid_100g  \
# 4                      NaN                 NaN                 NaN
# 9                      NaN                 NaN                 NaN
# 14                     NaN                 NaN                 NaN
# 18                     NaN                 NaN                 NaN
# 20                     NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 3498741                NaN                 NaN                 NaN
# 3498753                NaN                 NaN                 NaN
# 3498810                NaN                 NaN                 NaN
# 3498834                NaN                 NaN                 NaN
# 3498839                NaN                 NaN                 NaN
#
#          unsaturated-fat_100g  monounsaturated-fat_100g  omega-9-fat_100g  \
# 4                         NaN                       NaN               NaN
# 9                         NaN                       NaN               NaN
# 14                        NaN                       NaN               NaN
# 18                        NaN                       NaN               NaN
# 20                        NaN                       NaN               NaN
# ...                       ...                       ...               ...
# 3498741                   NaN                       NaN               NaN
# 3498753                   NaN                       NaN               NaN
# 3498810                   NaN                       NaN               NaN
# 3498834                   NaN                       NaN               NaN
# 3498839                   NaN                       NaN               NaN
#
#          polyunsaturated-fat_100g  omega-3-fat_100g  omega-6-fat_100g  \
# 4                             NaN               NaN               NaN
# 9                             NaN               NaN               NaN
# 14                            NaN               NaN               NaN
# 18                            NaN               NaN               NaN
# 20                            NaN               NaN               NaN
# ...                           ...               ...               ...
# 3498741                       NaN               NaN               NaN
# 3498753                       NaN               NaN               NaN
# 3498810                       NaN               NaN               NaN
# 3498834                       NaN               NaN               NaN
# 3498839                       NaN               NaN               NaN
#
#          alpha-linolenic-acid_100g  eicosapentaenoic-acid_100g  \
# 4                              NaN                         NaN
# 9                              NaN                         NaN
# 14                             NaN                         NaN
# 18                             NaN                         NaN
# 20                             NaN                         NaN
# ...                            ...                         ...
# 3498741                        NaN                         NaN
# 3498753                        NaN                         NaN
# 3498810                        NaN                         NaN
# 3498834                        NaN                         NaN
# 3498839                        NaN                         NaN
#
#          docosahexaenoic-acid_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# 4                              NaN                 NaN                    NaN
# 9                              NaN                 NaN                    NaN
# 14                             NaN                 NaN                    NaN
# 18                             NaN                 NaN                    NaN
# 20                             NaN                 NaN                    NaN
# ...                            ...                 ...                    ...
# 3498741                        NaN                 NaN                    NaN
# 3498753                        NaN                 NaN                    NaN
# 3498810                        NaN                 NaN                    NaN
# ...
# 4                        NaN               NaN       0.23              NaN
# 9                        NaN               NaN       0.53              NaN
# 14                       NaN               NaN       0.48              NaN
# 18                       NaN               NaN       0.45              NaN
# 20                       NaN               NaN        NaN              NaN
# ...                      ...               ...        ...              ...
# 3498741                  NaN               NaN        NaN              NaN
# 3498753                  NaN               NaN       3.10              NaN
# 3498810                  NaN               NaN       0.09              NaN
# 3498834                  NaN               NaN       1.10              NaN
# 3498839                  NaN               NaN       0.18              NaN
#
#          sodium_100g  alcohol_100g  vitamin-a_100g  beta-carotene_100g  \
# 4              0.092           NaN             NaN                 NaN
# 9              0.212           NaN             NaN                 NaN
# 14             0.192           0.0             NaN                 NaN
# 18             0.180           NaN             NaN                 NaN
# 20               NaN           NaN             NaN                 NaN
# ...              ...           ...             ...                 ...
# 3498741          NaN           NaN             NaN                 NaN
# 3498753        1.240           NaN             NaN                 NaN
# 3498810        0.036           NaN             NaN                 NaN
# 3498834        0.440           NaN             NaN                 NaN
# 3498839        0.072           NaN             NaN                 NaN
#
#          vitamin-d_100g  vitamin-e_100g  vitamin-k_100g  vitamin-c_100g  \
# 4                   NaN             NaN             NaN             NaN
# 9                   NaN             NaN             NaN             NaN
# 14                  NaN             NaN             NaN             NaN
# 18                  NaN             NaN             NaN             NaN
# 20                  NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 3498741             NaN             NaN             NaN             NaN
# 3498753             NaN             NaN             NaN             NaN
# 3498810             NaN             NaN             NaN             NaN
# 3498834             NaN             NaN             NaN             NaN
# 3498839             NaN             NaN             NaN             NaN
#
#          vitamin-b1_100g  vitamin-b2_100g  vitamin-pp_100g  vitamin-b6_100g  \
# 4                    NaN              NaN              NaN              NaN
# 9                    NaN              NaN              NaN              NaN
# 14                   NaN              NaN              NaN              NaN
# 18                   NaN              NaN              NaN              NaN
# 20                   NaN              NaN              NaN              NaN
# ...                  ...              ...              ...              ...
# 3498741              NaN              NaN              NaN              NaN
# 3498753              NaN              NaN              NaN              NaN
# 3498810              NaN              NaN              NaN              NaN
# 3498834              NaN              NaN              NaN              NaN
# 3498839              NaN              NaN              NaN              NaN
#
#          vitamin-b9_100g  folates_100g  vitamin-b12_100g  biotin_100g  \
# 4                    NaN           NaN               NaN          NaN
# 9                    NaN           NaN               NaN          NaN
# 14                   NaN           NaN               NaN          NaN
# 18                   NaN           NaN               NaN          NaN
# 20                   NaN           NaN               NaN          NaN
# ...                  ...           ...               ...          ...
# 3498741              NaN           NaN               NaN          NaN
# 3498753              NaN           NaN               NaN          NaN
# 3498810              NaN           NaN               NaN          NaN
# 3498834              NaN           NaN               NaN          NaN
# 3498839              NaN           NaN               NaN          NaN
#
#          pantothenic-acid_100g  silica_100g  bicarbonate_100g  potassium_100g  \
# 4                          NaN          NaN               NaN             NaN
# 9                          NaN          NaN               NaN             NaN
# 14                         NaN          NaN               NaN             NaN
# 18                         NaN          NaN               NaN             NaN
# 20                         NaN          NaN               NaN             NaN
# ...                        ...          ...               ...             ...
# 3498741                    NaN          NaN               NaN             NaN
# 3498753                    NaN          NaN               NaN             NaN
# 3498810                    NaN          NaN               NaN             NaN
# 3498834                    NaN          NaN               NaN             NaN
# 3498839                    NaN          NaN               NaN             NaN
#
#          chloride_100g  calcium_100g  phosphorus_100g  iron_100g  \
# 4                  NaN           NaN              NaN        NaN
# 9                  NaN           NaN              NaN        NaN
# 14                 NaN           NaN              NaN        NaN
# 18                 NaN           NaN              NaN        NaN
# 20                 NaN           NaN              NaN        NaN
# ...                ...           ...              ...        ...
# 3498741            NaN           NaN              NaN        NaN
# 3498753            NaN           NaN              NaN        NaN
# 3498810            NaN           NaN              NaN        NaN
# 3498834            NaN           NaN              NaN        NaN
# 3498839            NaN           NaN              NaN        NaN
#
#          magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 4                   NaN        NaN          NaN             NaN
# 9                   NaN        NaN          NaN             NaN
# 14                  NaN        NaN          NaN             NaN
# 18                  NaN        NaN          NaN             NaN
# 20                  NaN        NaN          NaN             NaN
# ...                 ...        ...          ...             ...
# 3498741             NaN        NaN          NaN             NaN
# 3498753             NaN        NaN          NaN             NaN
# 3498810             NaN        NaN          NaN             NaN
# 3498834             NaN        NaN          NaN             NaN
# 3498839             NaN        NaN          NaN             NaN
#
#          fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 4                  NaN            NaN            NaN              NaN
# 9                  NaN            NaN            NaN              NaN
# 14                 NaN            NaN            NaN              NaN
# 18                 NaN            NaN            NaN              NaN
# 20                 NaN            NaN            NaN              NaN
# ...                ...            ...            ...              ...
# 3498741            NaN            NaN            NaN              NaN
# 3498753            NaN            NaN            NaN              NaN
# 3498810            NaN            NaN            NaN              NaN
# 3498834            NaN            NaN            NaN              NaN
# 3498839            NaN            NaN            NaN              NaN
#
#          iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 4                NaN            NaN           NaN      NaN
# 9                NaN            NaN           NaN      NaN
# 14               NaN            NaN           NaN      NaN
# 18               NaN            NaN           NaN      NaN
# 20               NaN            NaN           NaN      NaN
# ...              ...            ...           ...      ...
# 3498741          NaN            NaN           NaN      NaN
# 3498753          NaN            NaN           NaN      NaN
# 3498810          NaN            NaN           NaN      NaN
# 3498834          NaN            NaN           NaN      NaN
# 3498839          NaN            NaN           NaN      NaN
#
#          fruits-vegetables-nuts_100g  fruits-vegetables-nuts-dried_100g  \
# 4                                NaN                                NaN
# 9                                NaN                                NaN
# 14                               NaN                                NaN
# 18                               NaN                                NaN
# 20                               NaN                                NaN
# ...                              ...                                ...
# 3498741                          NaN                                NaN
# 3498753                          NaN                                NaN
# 3498810                          NaN                                NaN
# 3498834                          NaN                                NaN
# 3498839                          NaN                                NaN
#
#          fruits-vegetables-nuts-estimate_100g  \
# 4                                         NaN
# 9                                         NaN
# 14                                        NaN
# 18                                        NaN
# 20                                        NaN
# ...                                       ...
# 3498741                                   NaN
# 3498753                                   NaN
# 3498810                                   NaN
# 3498834                                   NaN
# 3498839                                   NaN
#
#          fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 4                                                50.000000
# 9                                                22.666667
# 14                                               16.250000
# 18                                               16.250000
# 20                                                1.750000
# ...                                                    ...
# 3498741                                           5.357143
# 3498753                                           0.000000
# 3498810                                           0.000000
# 3498834                                           0.000000
# 3498839                                           0.000000
#
#          collagen-meat-protein-ratio_100g  cocoa_100g  chlorophyl_100g  \
# 4                                     NaN         NaN              NaN
# 9                                     NaN         NaN              NaN
# 14                                    NaN         NaN              NaN
# 18                                    NaN         NaN              NaN
# 20                                    NaN         NaN              NaN
# ...                                   ...         ...              ...
# 3498741                               NaN         NaN              NaN
# 3498753                               NaN         NaN              NaN
# 3498810                               NaN         NaN              NaN
# 3498834                               NaN         NaN              NaN
# 3498839                               NaN         NaN              NaN
#
#          carbon-footprint_100g  carbon-footprint-from-meat-or-fish_100g  \
# 4                          NaN                                      NaN
# 9                          NaN                                      NaN
# 14                         NaN                                      NaN
# 18                         NaN                                      NaN
# 20                         NaN                                      NaN
# ...                        ...                                      ...
# 3498741                    NaN                                      NaN
# 3498753                    NaN                                      NaN
# 3498810                    NaN                                      NaN
# 3498834                    NaN                                      NaN
# 3498839                    NaN                                      NaN
#
#          nutrition-score-fr_100g  nutrition-score-uk_100g  \
# 4                           -2.0                      NaN
# 9                           13.0                      NaN
# 14                          17.0                      NaN
# 18                          16.0                      NaN
# 20                           NaN                      NaN
# ...                          ...                      ...
# 3498741                      NaN                      NaN
# 3498753                      NaN                      NaN
# 3498810                      7.0                      NaN
# 3498834                     15.0                      NaN
# 3498839                     -2.0                      NaN
#
#          glycemic-index_100g  water-hardness_100g  choline_100g  \
# 4                        NaN                  NaN           NaN
# 9                        NaN                  NaN           NaN
# 14                       NaN                  NaN           NaN
# 18                       NaN                  NaN           NaN
# 20                       NaN                  NaN           NaN
# ...                      ...                  ...           ...
# 3498741                  NaN                  NaN           NaN
# 3498753                  NaN                  NaN           NaN
# 3498810                  NaN                  NaN           NaN
# 3498834                  NaN                  NaN           NaN
# 3498839                  NaN                  NaN           NaN
#
#          phylloquinone_100g  beta-glucan_100g  inositol_100g  carnitine_100g  \
# 4                       NaN               NaN            NaN             NaN
# 9                       NaN               NaN            NaN             NaN
# 14                      NaN               NaN            NaN             NaN
# 18                      NaN               NaN            NaN             NaN
# 20                      NaN               NaN            NaN             NaN
# ...                     ...               ...            ...             ...
# 3498741                 NaN               NaN            NaN             NaN
# 3498753                 NaN               NaN            NaN             NaN
# 3498810                 NaN               NaN            NaN             NaN
# 3498834                 NaN               NaN            NaN             NaN
# 3498839                 NaN               NaN            NaN             NaN
#
#          sulphate_100g  nitrate_100g  acidity_100g
# 4                  NaN           NaN           NaN
# 9                  NaN           NaN           NaN
# 14                 NaN           NaN           NaN
# 18                 NaN           NaN           NaN
# 20                 NaN           NaN           NaN
# ...                ...           ...           ...
# 3498741            NaN           NaN           NaN
# 3498753            NaN           NaN           NaN
# 3498810            NaN           NaN           NaN
# 3498834            NaN           NaN           NaN
# 3498839            NaN           NaN           NaN
#
# [262446 rows x 206 columns]

# %% [markdown]
# ## Inspection des Données Brutes

# %%
# Basic stats
print("Taille du dataset:")
print("Number of rows : {}".format(rawdata.shape[0]))
print("Number of columns : {}".format(rawdata.shape[1]))
print()
print("---------------------------")
print()

print("Basics infos:")
print()
display(rawdata.info())
print()
print("---------------------------")
print()

print("Basics statistics: ")
print()
data_desc = rawdata.describe(include='all')
display(data_desc)
print()
print("---------------------------")
print()

print("Unique elements by feature: ")
print()
display(rawdata.nunique().sort_values())
print()
print("---------------------------")
print()

print("Percentage of missing values: ")
print()
null_percentage = 100 * rawdata.isnull().mean()
null_percentage_df = null_percentage.to_frame(name='Null Percentage').T
display(null_percentage_df)
# Out:
# Taille du dataset:
# Number of rows : 262446
# Number of columns : 206
#
# ---------------------------
#
# Basics infos:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 262446 entries, 4 to 3498839
# Columns: 206 entries, code to acidity_100g
# dtypes: float64(131), int64(2), object(73)
# memory usage: 414.5+ MB
# None
# ---------------------------
#
# Basics statistics:
#                  code                                                url  \
# count          262446                                             262446
# unique         261662                                             261668
# top     3017800180426  http://world-en.openfoodfacts.org/product/3017...
# freq                2                                                  2
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#         creator     created_t      created_datetime  last_modified_t  \
# count    262445  2.624460e+05                262446     2.624460e+05
# unique     4907           NaN                257802              NaN
# top     kiliweb           NaN  2021-04-20T10:35:38Z              NaN
# freq     164342           NaN                    13              NaN
# mean        NaN  1.527818e+09                   NaN     1.668274e+09
# std         NaN  7.293705e+07                   NaN     4.790528e+07
# min         NaN  1.328021e+09                   NaN     1.362683e+09
# 25%         NaN  1.494173e+09                   NaN     1.644552e+09
# 50%         NaN  1.517339e+09                   NaN     1.682667e+09
# 75%         NaN  1.556192e+09                   NaN     1.701680e+09
# max         NaN  1.730869e+09                   NaN     1.730869e+09
#
#        last_modified_datetime last_modified_by  last_updated_t  \
# count                  262446           255918    2.623840e+05
# unique                 230022             6587             NaN
# top      2023-10-26T17:32:26Z          packbot             NaN
# freq                       23            48909             NaN
# mean                      NaN              NaN    1.722693e+09
# std                       NaN              NaN    1.019181e+07
# min                       NaN              NaN    1.706029e+09
# 25%                       NaN              NaN    1.707650e+09
# 50%                       NaN              NaN    1.729883e+09
# 75%                       NaN              NaN    1.729944e+09
# max                       NaN              NaN    1.730869e+09
#
#        last_updated_datetime product_name abbreviated_product_name  \
# count                 262384       259542                    14365
# unique                154956       200193                    13357
# top     2024-10-26T19:22:56Z        Comté                      150
# freq                      34          204                       18
# mean                     NaN          NaN                      NaN
# std                      NaN          NaN                      NaN
# min                      NaN          NaN                      NaN
# 25%                      NaN          NaN                      NaN
# 50%                      NaN          NaN                      NaN
# 75%                      NaN          NaN                      NaN
# max                      NaN          NaN                      NaN
#
#                                     generic_name quantity          packaging  \
# count                                      72756   193203             131260
# unique                                     52181    17499              22398
# top     Pâtes alimentaires de qualité supérieure    500 g  Plastique, Sachet
# freq                                         275     8667               6996
# mean                                         NaN      NaN                NaN
# std                                          NaN      NaN                NaN
# min                                          NaN      NaN                NaN
# 25%                                          NaN      NaN                NaN
# 50%                                          NaN      NaN                NaN
# 75%                                          NaN      NaN                NaN
# max                                          NaN      NaN                NaN
#
#            packaging_tags packaging_en              packaging_text     brands  \
# count              131260       131260                       12133     247022
# unique              18531        18516                        5722      57908
# top     en:plastic,en:bag  Plastic,Bag  1 sachet plastique à jeter  Carrefour
# freq                 7464         7464                         521       5706
# mean                  NaN          NaN                         NaN        NaN
# std                   NaN          NaN                         NaN        NaN
# min                   NaN          NaN                         NaN        NaN
# 25%                   NaN          NaN                         NaN        NaN
# 50%                   NaN          NaN                         NaN        NaN
# 75%                   NaN          NaN                         NaN        NaN
# max                   NaN          NaN                         NaN        NaN
#
#        brands_tags categories categories_tags categories_en origins  \
# count       247013     224425          224425        224425   50696
# unique       42433      63700           49862         49855    8397
# top      carrefour   Boissons    en:beverages     Beverages  France
# freq          5909       1668            1739          1739   20889
# mean           NaN        NaN             NaN           NaN     NaN
# std            NaN        NaN             NaN           NaN     NaN
# min            NaN        NaN             NaN           NaN     NaN
# 25%            NaN        NaN             NaN           NaN     NaN
# 50%            NaN        NaN             NaN           NaN     NaN
# 75%            NaN        NaN             NaN           NaN     NaN
# max            NaN        NaN             NaN           NaN     NaN
#
#        origins_tags origins_en manufacturing_places manufacturing_places_tags  \
# count         50660      50659                62115                     62091
# unique         6562       6502                12943                     11536
# top       en:france     France               France                    france
# freq          21334      21336                22922                     23766
# mean            NaN        NaN                  NaN                       NaN
# std             NaN        NaN                  NaN                       NaN
# min             NaN        NaN                  NaN                       NaN
# 25%             NaN        NaN                  NaN                       NaN
# 50%             NaN        NaN                  NaN                       NaN
# 75%             NaN        NaN                  NaN                       NaN
# max             NaN        NaN                  NaN                       NaN
#
#             labels   labels_tags  labels_en   emb_codes emb_codes_tags  \
# count       162683        162683     162683       62206          62195
# unique       46308         39319      39319       17632          15280
# top     Point Vert  en:green-dot  Green Dot  EMB 56251E     emb-56251e
# freq         10079         10872      10872         346            350
# mean           NaN           NaN        NaN         NaN            NaN
# std            NaN           NaN        NaN         NaN            NaN
# min            NaN           NaN        NaN         NaN            NaN
# 25%            NaN           NaN        NaN         NaN            NaN
# 50%            NaN           NaN        NaN         NaN            NaN
# 75%            NaN           NaN        NaN         NaN            NaN
# max            NaN           NaN        NaN         NaN            NaN
#
#        first_packaging_code_geo  cities                     cities_tags  \
# count                     48498     0.0                           51890
# unique                     2868     NaN                            5780
# top         47.833333,-0.333333     NaN  sable-sur-sarthe-sarthe-france
# freq                        756     NaN                             536
# mean                        NaN     NaN                             NaN
# std                         NaN     NaN                             NaN
# min                         NaN     NaN                             NaN
# 25%                         NaN     NaN                             NaN
# 50%                         NaN     NaN                             NaN
# 75%                         NaN     NaN                             NaN
# max                         NaN     NaN                             NaN
#
#        purchase_places     stores countries countries_tags countries_en  \
# count            77227     113823    262446         262446       262446
# unique            5382       8035        60              1            1
# top             France  Carrefour    France      en:france       France
# freq             38289       8446    229398         262446       262446
# mean               NaN        NaN       NaN            NaN          NaN
# std                NaN        NaN       NaN            NaN          NaN
# min                NaN        NaN       NaN            NaN          NaN
# 25%                NaN        NaN       NaN            NaN          NaN
# 50%                NaN        NaN       NaN            NaN          NaN
# 75%                NaN        NaN       NaN            NaN          NaN
# max                NaN        NaN       NaN            NaN          NaN
#
#        ingredients_text                                   ingredients_tags  \
# count            262445                                             262446
# unique           237469                                             200778
# top              Poulet  en:superior-quality-durum-wheat-semolina,en:ce...
# freq                518                                                785
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
#                       ingredients_analysis_tags allergens  allergens_en  \
# count                                    262444    101898           0.0
# unique                                       37      3280           NaN
# top     en:palm-oil-free,en:vegan,en:vegetarian   en:milk           NaN
# freq                                      45476     23942           NaN
# mean                                        NaN       NaN           NaN
# std                                         NaN       NaN           NaN
# min                                         NaN       NaN           NaN
# 25%                                         NaN       NaN           NaN
# 50%                                         NaN       NaN           NaN
# 75%                                         NaN       NaN           NaN
# max                                         NaN       NaN           NaN
#
#          traces traces_tags traces_en serving_size  serving_quantity  \
# count     60167       78640     77682        65262      6.330200e+04
# unique     5692        6096      6095         8421               NaN
# top     en:nuts     en:nuts      Nuts         100g               NaN
# freq       5372        7498      7498         5560               NaN
# mean        NaN         NaN       NaN          NaN      5.940229e+07
# std         NaN         NaN       NaN          NaN      1.494552e+10
# min         NaN         NaN       NaN          NaN      0.000000e+00
# 25%         NaN         NaN       NaN          NaN      3.000000e+01
# 50%         NaN         NaN       NaN          NaN      1.000000e+02
# 75%         NaN         NaN       NaN          NaN      1.500000e+02
# max         NaN         NaN       NaN          NaN      3.760276e+12
#
#        no_nutrition_data    additives_n  \
# count              13393  262446.000000
# unique                 4            NaN
# top                   on            NaN
# freq               10679            NaN
# mean                 NaN       1.534716
# std                  NaN       2.334788
# min                  NaN       0.000000
# 25%                  NaN       0.000000
# 50%                  NaN       1.000000
# 75%                  NaN       2.000000
# max                  NaN      35.000000
#
#                                                 additives    additives_tags  \
# count                                                   2            134324
# unique                                                  2             33903
# top      [ farine-de-ble -> fr:farine-de-ble  ]  [ far...  en:e322,en:e322i
# freq                                                    1              6771
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#                              additives_en  nutriscore_score nutriscore_grade  \
# count                              134324     193651.000000           262428
# unique                              33903               NaN                7
# top     E322 - Lecithins,E322i - Lecithin               NaN          unknown
# freq                                 6771               NaN            57958
# mean                                  NaN          8.424036              NaN
# std                                   NaN          9.006878              NaN
# min                                   NaN        -20.000000              NaN
# 25%                                   NaN          1.000000              NaN
# 50%                                   NaN          8.000000              NaN
# 75%                                   NaN         15.000000              NaN
# max                                   NaN         40.000000              NaN
#
#            nova_group pnns_groups_1 pnns_groups_2            food_groups  \
# count   226888.000000        262445        262446                 202214
# unique            NaN            11            40                     45
# top               NaN       unknown       unknown  en:biscuits-and-cakes
# freq              NaN         61029         61029                  17610
# mean         3.332873           NaN           NaN                    NaN
# std          1.024788           NaN           NaN                    NaN
# min          1.000000           NaN           NaN                    NaN
# 25%          3.000000           NaN           NaN                    NaN
# 50%          4.000000           NaN           NaN                    NaN
# 75%          4.000000           NaN           NaN                    NaN
# max          4.000000           NaN           NaN                    NaN
#
#                               food_groups_tags  \
# count                                   202214
# unique                                      45
# top     en:sugary-snacks,en:biscuits-and-cakes
# freq                                     17610
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                           food_groups_en  \
# count                             202214
# unique                                45
# top     Sugary snacks,Biscuits and cakes
# freq                               17610
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#                                                    states  \
# count                                              262446
# unique                                               2408
# top     en:to-be-completed, en:nutrition-facts-complet...
# freq                                                20867
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               states_tags  \
# count                                              262446
# unique                                               2408
# top     en:to-be-completed,en:nutrition-facts-complete...
# freq                                                20867
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 states_en brand_owner  \
# count                                              262446        3884
# unique                                               2408          74
# top     To be completed,Nutrition facts completed,Ingr...      Casino
# freq                                                20867        2313
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#         ecoscore_score ecoscore_grade  \
# count    161513.000000         262438
# unique             NaN              9
# top                NaN        unknown
# freq               NaN          96770
# mean         55.292809            NaN
# std          28.200915            NaN
# min         -30.000000            NaN
# 25%          35.000000            NaN
# 50%          56.000000            NaN
# 75%          76.000000            NaN
# max         125.000000            NaN
#
#                                      nutrient_levels_tags  product_quantity  \
# count                                              195942     191720.000000
# unique                                                225               NaN
# top     en:fat-in-low-quantity,en:saturated-fat-in-low...               NaN
# freq                                                22330               NaN
# mean                                                  NaN        454.639577
# std                                                   NaN       2617.209263
# min                                                   NaN          0.000000
# 25%                                                   NaN        160.000000
# 50%                                                   NaN        290.000000
# 75%                                                   NaN        500.000000
# max                                                   NaN    1000000.000000
#
#                 owner                           data_quality_errors_tags  \
# count           50955                                               8612
# unique            219                                                173
# top     org-carrefour  en:energy-value-in-kcal-does-not-match-value-c...
# freq             8370                                               3323
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#         unique_scans_n                                    popularity_tags  \
# count    191012.000000                                             187639
# unique             NaN                                              86978
# top                NaN  bottom-25-percent-scans-2019,bottom-20-percent...
# freq               NaN                                               6297
# mean          4.643771                                                NaN
# std          12.189710                                                NaN
# min           1.000000                                                NaN
# 25%           1.000000                                                NaN
# 50%           2.000000                                                NaN
# 75%           4.000000                                                NaN
# max         842.000000                                                NaN
#
#          completeness  last_image_t   last_image_datetime main_category  \
# count   262446.000000  2.561790e+05                256179        224425
# unique            NaN           NaN                254506         17144
# top               NaN           NaN  2021-07-06T13:01:18Z  en:groceries
# freq              NaN           NaN                     4          8801
# mean         0.754019  1.589367e+09                   NaN           NaN
# std          0.176202  8.104755e+07                   NaN           NaN
# min          0.100000  1.328987e+09                   NaN           NaN
# 25%          0.587500  1.519127e+09                   NaN           NaN
# 50%          0.775000  1.600427e+09                   NaN           NaN
# 75%          0.887500  1.652449e+09                   NaN           NaN
# max          1.100000  1.730869e+09                   NaN           NaN
#
#        main_category_en                                          image_url  \
# count            224425                                             243009
# unique            17142                                             242255
# top           Groceries  https://images.openfoodfacts.org/images/produc...
# freq               8801                                                  2
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
#                                           image_small_url  \
# count                                              243009
# unique                                             242255
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                     image_ingredients_url  \
# count                                              228118
# unique                                             227393
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               image_ingredients_small_url  \
# count                                              228118
# unique                                             227393
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                       image_nutrition_url  \
# count                                              185463
# unique                                             184881
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 image_nutrition_small_url  energy-kj_100g  \
# count                                              185463    85997.000000
# unique                                             184881             NaN
# top     https://images.openfoodfacts.org/images/produc...             NaN
# freq                                                    2             NaN
# mean                                                  NaN     1061.092244
# std                                                   NaN      753.672078
# min                                                   NaN        0.000000
# 25%                                                   NaN      426.000000
# 50%                                                   NaN      952.000000
# 75%                                                   NaN     1569.000000
# max                                                   NaN    23200.000000
#
#         energy-kcal_100g   energy_100g  energy-from-fat_100g       fat_100g  \
# count       2.179070e+05  2.357530e+05             28.000000  235497.000000
# unique               NaN           NaN                   NaN            NaN
# top                  NaN           NaN                   NaN            NaN
# freq                 NaN           NaN                   NaN            NaN
# mean        6.516541e+10  2.523828e+11            763.900000      13.539812
# std         3.041955e+13  1.225430e+14            943.452202      16.981526
# min         0.000000e+00  0.000000e+00              0.000000       0.000000
# 25%         1.117584e+02  4.640000e+02             94.250000       1.100000
# 50%         2.520000e+02  1.042000e+03            471.500000       7.200000
# 75%         3.930000e+02  1.637000e+03           1147.500000      21.000000
# max         1.420000e+16  5.950000e+16           3630.000000     231.000000
#
#         saturated-fat_100g  butyric-acid_100g  caproic-acid_100g  \
# count        233782.000000           4.000000           4.000000
# unique                 NaN                NaN                NaN
# top                    NaN                NaN                NaN
# freq                   NaN                NaN                NaN
# mean              5.254001           6.840750           0.231506
# std               7.936301          13.439585           0.445831
# min               0.000000           0.063000           0.000000
# 25%               0.300000           0.105750           0.000017
# 50%               2.000000           0.150000           0.013011
# 75%               7.300000           6.885000           0.244500
# max             163.000000          27.000000           0.900000
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# count             3.000000           3.00000          4.000000
# unique                 NaN               NaN               NaN
# top                    NaN               NaN               NaN
# freq                   NaN               NaN               NaN
# mean              3.314367           2.62100         36.792500
# std               5.729307           3.31831         23.818779
# min               0.004200           0.58300          1.070000
# 25%               0.006550           0.70650         36.342500
# 50%               0.008900           0.83000         48.550000
# 75%               4.969450           3.64000         49.000000
# max               9.930000           6.45000         49.000000
#
#         myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
# count             2.000000            3.000000           2.000000
# unique                 NaN                 NaN                NaN
# top                    NaN                 NaN                NaN
# freq                   NaN                 NaN                NaN
# mean              9.510000            3.886000          32.470000
# std              13.279465            3.584855          41.761726
# min               0.120000            0.108000           2.940000
# 25%               4.815000            2.209000          17.705000
# 50%               9.510000            4.310000          32.470000
# 75%              14.205000            5.775000          47.235000
# max              18.900000            7.240000          62.000000
#
#         arachidic-acid_100g  behenic-acid_100g  lignoceric-acid_100g  \
# count             22.000000           8.000000                 1.000
# unique                  NaN                NaN                   NaN
# top                     NaN                NaN                   NaN
# freq                    NaN                NaN                   NaN
# mean               0.292605           2.597562                 0.003
# std                0.842357           7.033452                   NaN
# min                0.000000           0.001000                 0.003
# 25%                0.000066           0.003325                 0.003
# 50%                0.006030           0.024500                 0.003
# 75%                0.265000           0.354750                 0.003
# max                4.000000          20.000000                 0.003
#
#         cerotic-acid_100g  montanic-acid_100g  melissic-acid_100g  \
# count                 1.0            3.000000            7.000000
# unique                NaN                 NaN                 NaN
# top                   NaN                 NaN                 NaN
# freq                  NaN                 NaN                 NaN
# mean                  0.0           20.760333            0.040721
# std                   NaN           34.850428            0.052201
# min                   0.0            0.281000            0.000340
# 25%                   0.0            0.640500            0.006455
# 50%                   0.0            1.000000            0.025000
# 75%                   0.0           31.000000            0.048400
# max                   0.0           61.000000            0.150000
#
#         unsaturated-fat_100g  monounsaturated-fat_100g  omega-9-fat_100g  \
# count              23.000000               1767.000000         38.000000
# unique                   NaN                       NaN               NaN
# top                      NaN                       NaN               NaN
# freq                     NaN                       NaN               NaN
# mean               12.865217                 24.670276         84.320439
# std                30.477870                 26.016964        278.682433
# min                 0.000000                  0.000000          0.005500
# 25%                 0.000000                  3.000000         27.025000
# 50%                 0.000000                 15.000000         42.000000
# 75%                 1.900000                 39.000000         62.550000
# max                92.100000                 86.000000       1750.000000
#
#         polyunsaturated-fat_100g  omega-3-fat_100g  omega-6-fat_100g  \
# count                1777.000000       1297.000000        272.000000
# unique                       NaN               NaN               NaN
# top                          NaN               NaN               NaN
# freq                         NaN               NaN               NaN
# mean                   12.470353          4.237112         15.981691
# std                    16.999863         39.550699         29.057123
# min                     0.000000          0.000000          0.000000
# 25%                     2.000000          0.410000          1.450000
# 50%                     6.000000          1.800000          8.000000
# 75%                    13.300000          3.210000         21.125000
# max                    77.000000       1410.000000        404.230000
#
#         alpha-linolenic-acid_100g  eicosapentaenoic-acid_100g  \
# count                  559.000000                   57.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                     1.348583                    1.839791
# std                      5.833911                    7.177955
# min                      0.000000                    0.000000
# 25%                      0.052000                    0.100000
# 50%                      0.087000                    0.200000
# 75%                      0.397000                    0.700000
# max                     81.000000                   39.640000
#
#         docosahexaenoic-acid_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# count                  129.000000          423.000000              52.000000
# unique                        NaN                 NaN                    NaN
# top                           NaN                 NaN                    NaN
# freq                          NaN                 NaN                    NaN
# mean                     0.841817            2.199030               0.055554
# std                      2.815056            6.189702               0.068529
# min                      0.000000            0.000000               0.000000
# 25%                      0.059000            0.354000               0.010000
# 50%                      0.120000            0.486000               0.045500
# 75%                      0.500000            0.696500               0.082000
# max                     19.000000           68.000000               0.428000
#
#         gamma-linolenic-acid_100g  dihomo-gamma-linolenic-acid_100g  \
# count                         1.0                              1.00
# unique                        NaN                               NaN
# top                           NaN                               NaN
# freq                          NaN                               NaN
# mean                          0.6                              5.35
# std                           NaN                               NaN
# min                           0.6                              5.35
# 25%                           0.6                              5.35
# 50%                           0.6                              5.35
# 75%                           0.6                              5.35
# max                           0.6                              5.35
#
#         oleic-acid_100g  elaidic-acid_100g  gondoic-acid_100g  mead-acid_100g  \
# count         27.000000                0.0             1.0000             2.0
# unique              NaN                NaN                NaN             NaN
# top                 NaN                NaN                NaN             NaN
# freq                NaN                NaN                NaN             NaN
# mean          38.494037                NaN             0.0023             0.0
# std           28.291801                NaN                NaN             0.0
# min            0.027000                NaN             0.0023             0.0
# 25%           10.375000                NaN             0.0023             0.0
# 50%           33.000000                NaN             0.0023             0.0
# 75%           67.000000                NaN             0.0023             0.0
# max           76.000000                NaN             0.0023             0.0
#
#         erucic-acid_100g  nervonic-acid_100g  trans-fat_100g  \
# count                0.0            2.000000      561.000000
# unique               NaN                 NaN             NaN
# top                  NaN                 NaN             NaN
# freq                 NaN                 NaN             NaN
# mean                 NaN            7.007100        0.191689
# std                  NaN            9.889454        1.031835
# min                  NaN            0.014200        0.000000
# 25%                  NaN            3.510650        0.000000
# 50%                  NaN            7.007100        0.000000
# 75%                  NaN           10.503550        0.100000
# max                  NaN           14.000000       19.000000
#
#         cholesterol_100g  carbohydrates_100g    sugars_100g  \
# count         644.000000       235376.000000  234382.000000
# unique               NaN                 NaN            NaN
# top                  NaN                 NaN            NaN
# freq                 NaN                 NaN            NaN
# mean            0.128027           27.396272      13.686511
# std             1.438917           27.364661      22.842566
# min             0.000000            0.000000      -0.100000
# 25%             0.000000            3.400000       0.800000
# 50%             0.000000           15.000000       3.600000
# 75%             0.016875           52.000000      19.100000
# max            24.000000          620.000000    5551.000000
#
#         added-sugars_100g  sucrose_100g  glucose_100g  fructose_100g  \
# count          134.000000     19.000000     16.000000      32.000000
# unique                NaN           NaN           NaN            NaN
# top                   NaN           NaN           NaN            NaN
# freq                  NaN           NaN           NaN            NaN
# mean            15.921403     12.939023     14.118931      33.346875
# std             20.051772     27.132520     18.557303      29.308173
# min              0.000000      0.000000      0.000000       0.000000
# 25%              0.000000      0.150000      0.325000       2.375000
# 50%              6.030000      0.300000      5.100000      28.500000
# 75%             31.275000      4.920000     21.550000      55.350000
# max             80.000000     92.800000     55.000000     101.400000
#
#         lactose_100g  maltose_100g  maltodextrins_100g  starch_100g  \
# count     180.000000     11.000000           83.000000   170.000000
# unique           NaN           NaN                 NaN          NaN
# top              NaN           NaN                 NaN          NaN
# freq             NaN           NaN                 NaN          NaN
# mean       35.192159      7.758274            4.470129    30.338441
# std       232.626984     14.854779           17.074520    25.017773
# min         0.000000      0.000000            0.000000     0.000000
# 25%         0.010000      0.005006            0.099000     8.625000
# 50%         5.950000      0.231000            0.120000    29.100000
# 75%        41.925000      3.900000            0.905000    49.750000
# max      3125.000000     39.200000          132.000000    87.500000
#
#         polyols_100g  erythritol_100g     fiber_100g  soluble-fiber_100g  \
# count     933.000000         9.000000  131150.000000             4.00000
# unique           NaN              NaN            NaN                 NaN
# top              NaN              NaN            NaN                 NaN
# freq             NaN              NaN            NaN                 NaN
# mean       60.326955        11.407778       2.957124             2.25000
# std        54.082527        23.133451      13.100406             1.93477
# min         0.000000         0.000000       0.000000             0.80000
# 25%        27.000000         0.000000       0.200000             0.95000
# 50%        66.000000         0.000000       1.600000             1.60000
# 75%        94.000000         6.670000       3.500000             2.90000
# max      1370.000000        68.000000    4380.000000             5.00000
#
#         insoluble-fiber_100g  proteins_100g  casein_100g  serum-proteins_100g  \
# count               2.000000  235344.000000    48.000000            39.000000
# unique                   NaN            NaN          NaN                  NaN
# top                      NaN            NaN          NaN                  NaN
# freq                     NaN            NaN          NaN                  NaN
# mean                2.950000       8.364608     3.643506             5.602054
# std                 2.899138       9.225805     3.117017            15.342642
# min                 0.900000       0.000000     0.001400             0.000300
# 25%                 1.925000       1.700000     1.055000             0.300000
# 50%                 2.950000       6.100000     2.900000             1.900000
# 75%                 3.975000      12.000000     5.400000             5.300000
# max                 5.000000     579.000000    10.700000            95.000000
#
#         nucleotides_100g      salt_100g  added-salt_100g    sodium_100g  \
# count          19.000000  232179.000000              0.0  232179.000000
# unique               NaN            NaN              NaN            NaN
# top                  NaN            NaN              NaN            NaN
# freq                 NaN            NaN              NaN            NaN
# mean            5.954821       1.151902              NaN       0.460968
# std            11.161286       7.316836              NaN       2.928417
# min             0.002500       0.000000              NaN       0.000000
# 25%             0.022000       0.051000              NaN       0.020474
# 50%             0.024000       0.500000              NaN       0.200000
# 75%             7.250000       1.200000              NaN       0.480000
# max            41.000000    2500.000000              NaN    1000.000000
#
#         alcohol_100g  vitamin-a_100g  beta-carotene_100g  vitamin-d_100g  \
# count    7645.000000      998.000000           35.000000    1.443000e+03
# unique           NaN             NaN                 NaN             NaN
# top              NaN             NaN                 NaN             NaN
# freq             NaN             NaN                 NaN             NaN
# mean        4.523002        2.224969            1.135413    2.649090e-02
# std         8.363204       34.440498            6.415153    3.994638e-01
# min         0.000000        0.000000            0.000000    0.000000e+00
# 25%         0.000000        0.000068            0.000029    7.500000e-07
# 50%         0.000000        0.000140            0.000100    1.300000e-06
# 75%         6.000000        0.000450            0.072500    5.000000e-06
# max       100.000000      800.000000           38.000000    9.700000e+00
#
#         vitamin-e_100g  vitamin-k_100g  vitamin-c_100g  vitamin-b1_100g  \
# count      1558.000000      276.000000     2156.000000      1389.000000
# unique             NaN             NaN             NaN              NaN
# top                NaN             NaN             NaN              NaN
# freq               NaN             NaN             NaN              NaN
# mean          0.109450        0.013057        0.242510         0.043429
# std           1.676563        0.198817        3.040437         0.560016
# min           0.000000        0.000000        0.000000         0.000000
# 25%           0.001800        0.000005        0.012000         0.000210
# 50%           0.006000        0.000013        0.020000         0.000500
# 75%           0.013000        0.000036        0.033000         0.000910
# max          50.000000        3.300000       87.000000        15.000000
#
#         vitamin-b2_100g  vitamin-pp_100g  vitamin-b6_100g  vitamin-b9_100g  \
# count       1031.000000      1021.000000      1282.000000      1013.000000
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean           0.078430         0.504083         0.161866         2.596676
# std            1.736091        12.553398         2.376406        78.608404
# min            0.000000         0.000000         0.000000         0.000000
# 25%            0.000230         0.002800         0.000250         0.000030
# 50%            0.000780         0.006400         0.000623         0.000093
# 75%            0.001200         0.013300         0.001200         0.000166
# max           55.000000       400.000000        75.000000      2500.000000
#
#         folates_100g  vitamin-b12_100g  biotin_100g  pantothenic-acid_100g  \
# ...
# 75%                                65.000000
# max                               250.000000
#
#         fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# count                                       262444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            18.953396
# std                                             48.108579
# min                                            -65.887256
# 25%                                              0.000000
# 50%                                              0.030000
# 75%                                             22.219062
# max                                          13461.000000
#
#         collagen-meat-protein-ratio_100g   cocoa_100g  chlorophyl_100g  \
# count                         279.000000  3121.000000         2.000000
# unique                               NaN          NaN              NaN
# top                                  NaN          NaN              NaN
# freq                                 NaN          NaN              NaN
# mean                           14.916487    50.560818         1.879000
# std                             3.238563    22.906160         0.429921
# min                             3.700000     0.000000         1.575000
# 25%                            12.000000    32.000000         1.727000
# 50%                            15.000000    51.000000         1.879000
# 75%                            15.000000    70.000000         2.031000
# max                            25.000000   100.000000         2.183000
#
#         carbon-footprint_100g  carbon-footprint-from-meat-or-fish_100g  \
# count              245.000000                             11471.000000
# unique                    NaN                                      NaN
# top                       NaN                                      NaN
# freq                      NaN                                      NaN
# mean               236.850844                               617.556837
# std                339.512034                              6184.440843
# min                  0.000000                                 0.049000
# 25%                  0.000000                               106.465000
# 50%                126.000000                               325.000000
# 75%                335.000000                               615.000000
# max               2520.000000                            656298.600000
#
#         nutrition-score-fr_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# count             193653.000000                 2.000000             4.000000
# unique                      NaN                      NaN                  NaN
# top                         NaN                      NaN                  NaN
# freq                        NaN                      NaN                  NaN
# mean                   8.424088                 9.500000            37.175000
# std                    9.006858                12.020815            10.889865
# min                  -20.000000                 1.000000            26.000000
# 25%                    1.000000                 5.250000            29.000000
# 50%                    8.000000                 9.500000            37.000000
# 75%                   15.000000                13.750000            45.175000
# max                   40.000000                18.000000            48.700000
#
#         water-hardness_100g  choline_100g  phylloquinone_100g  \
# count                   0.0     48.000000        6.000000e+00
# unique                  NaN           NaN                 NaN
# top                     NaN           NaN                 NaN
# freq                    NaN           NaN                 NaN
# mean                    NaN      0.104835        1.966691e+00
# std                     NaN      0.141583        4.817318e+00
# min                     NaN      0.000000        3.000000e-07
# 25%                     NaN      0.060000        3.150000e-05
# 50%                     NaN      0.070000        3.400000e-05
# 75%                     NaN      0.156500        4.250000e-05
# max                     NaN      1.000000        1.180000e+01
#
#         beta-glucan_100g  inositol_100g  carnitine_100g  sulphate_100g  \
# count          10.000000      39.000000       32.000000      17.000000
# unique               NaN            NaN             NaN            NaN
# top                  NaN            NaN             NaN            NaN
# freq                 NaN            NaN             NaN            NaN
# mean            4.090000       0.039503        0.010034       0.137547
# std             1.890003       0.027770        0.004940       0.346106
# min             0.500000       0.003300        0.000800       0.000020
# 25%             3.100000       0.025000        0.006875       0.001400
# 50%             4.000000       0.029000        0.009050       0.005000
# 75%             5.275000       0.051000        0.015000       0.017400
# max             7.300000       0.150000        0.020000       1.337000
#
#         nitrate_100g  acidity_100g
# count      27.000000      3.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        0.079228      4.463333
# std         0.384357      3.833280
# min         0.000000      0.390000
# 25%         0.000100      2.695000
# 50%         0.000430      5.000000
# 75%         0.001000      6.500000
# max         2.000000      8.000000
# ---------------------------
#
# Unique elements by feature:
# allergens_en                0
# water-hardness_100g         0
# cities                      0
# added-salt_100g             0
# elaidic-acid_100g           0
#                         ...
# last_image_t           254506
# created_datetime       257802
# created_t              257802
# code                   261662
# url                    261668
# Length: 206, dtype: int64
# ---------------------------
#
# Percentage of missing values:
#                  code  url   creator  created_t  created_datetime  \
# Null Percentage   0.0  0.0  0.000381        0.0               0.0
#
#                  last_modified_t  last_modified_datetime  last_modified_by  \
# Null Percentage              0.0                     0.0          2.487369
#
#                  last_updated_t  last_updated_datetime  product_name  \
# Null Percentage        0.023624               0.023624      1.106513
#
#                  abbreviated_product_name  generic_name   quantity  packaging  \
# Null Percentage                 94.526493     72.277726  26.383713  49.985902
#
#                  packaging_tags  packaging_en  packaging_text    brands  \
# Null Percentage       49.985902     49.985902       95.376954  5.877019
#
#                  brands_tags  categories  categories_tags  categories_en  \
# Null Percentage     5.880448   14.487171        14.487171      14.487171
#
#                    origins  origins_tags  origins_en  manufacturing_places  \
# Null Percentage  80.683264     80.696981   80.697363             76.332274
#
#                  manufacturing_places_tags     labels  labels_tags  labels_en  \
# Null Percentage                  76.341419  38.012772    38.012772  38.012772
#
#                  emb_codes  emb_codes_tags  first_packaging_code_geo  cities  \
# Null Percentage    76.2976       76.301792                  81.52077   100.0
#
#                  cities_tags  purchase_places     stores  countries  \
# Null Percentage    80.228314        70.574137  56.629935        0.0
#
#                  countries_tags  countries_en  ingredients_text  \
# Null Percentage             0.0           0.0          0.000381
#
#                  ingredients_tags  ingredients_analysis_tags  allergens  \
# Null Percentage               0.0                   0.000762  61.173727
#
#                  allergens_en     traces  traces_tags  traces_en  \
# Null Percentage         100.0  77.074522    70.035741  70.400768
#
#                  serving_size  serving_quantity  no_nutrition_data  \
# Null Percentage      75.13317         75.879991          94.896855
#
#                  additives_n  additives  additives_tags  additives_en  \
# Null Percentage          0.0  99.999238       48.818424     48.818424
#
#                  nutriscore_score  nutriscore_grade  nova_group  \
# Null Percentage         26.213011          0.006859   13.548692
#
#                  pnns_groups_1  pnns_groups_2  food_groups  food_groups_tags  \
# Null Percentage       0.000381            0.0    22.950245         22.950245
#
#                  food_groups_en  states  states_tags  states_en  brand_owner  \
# Null Percentage       22.950245     0.0          0.0        0.0    98.520077
#
#                  ecoscore_score  ecoscore_grade  nutrient_levels_tags  \
# Null Percentage       38.458578        0.003048              25.34007
#
#                  product_quantity      owner  data_quality_errors_tags  \
# Null Percentage         26.948782  80.584577                 96.718563
#
#                  unique_scans_n  popularity_tags  completeness  last_image_t  \
# Null Percentage       27.218552        28.503768           0.0       2.38792
#
#                  last_image_datetime  main_category  main_category_en  \
# Null Percentage              2.38792      14.487171         14.487171
#
#                  image_url  image_small_url  image_ingredients_url  \
# Null Percentage   7.406095         7.406095              13.080024
#
#                  image_ingredients_small_url  image_nutrition_url  \
# Null Percentage                    13.080024            29.332891
#
#                  image_nutrition_small_url  energy-kj_100g  energy-kcal_100g  \
# Null Percentage                  29.332891       67.232497         16.970729
#
#                  energy_100g  energy-from-fat_100g   fat_100g  \
# Null Percentage    10.170854             99.989331  10.268398
#
#                  saturated-fat_100g  butyric-acid_100g  caproic-acid_100g  \
# Null Percentage           10.921866          99.998476          99.998476
#
#                  caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# Null Percentage           99.998857         99.998857         99.998476
#
#                  myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
# Null Percentage           99.999238           99.998857          99.999238
#
#                  arachidic-acid_100g  behenic-acid_100g  lignoceric-acid_100g  \
# Null Percentage            99.991617          99.996952             99.999619
#
#                  cerotic-acid_100g  montanic-acid_100g  melissic-acid_100g  \
# Null Percentage          99.999619           99.998857           99.997333
#
#                  unsaturated-fat_100g  monounsaturated-fat_100g  \
# Null Percentage             99.991236                 99.326719
#
#                  omega-9-fat_100g  polyunsaturated-fat_100g  omega-3-fat_100g  \
# Null Percentage         99.985521                 99.322908         99.505803
#
#                  omega-6-fat_100g  alpha-linolenic-acid_100g  \
# Null Percentage          99.89636                  99.787004
#
#                  eicosapentaenoic-acid_100g  docosahexaenoic-acid_100g  \
# Null Percentage                   99.978281                  99.950847
#
#                  linoleic-acid_100g  arachidonic-acid_100g  \
# Null Percentage           99.838824              99.980186
#
#                  gamma-linolenic-acid_100g  dihomo-gamma-linolenic-acid_100g  \
# Null Percentage                  99.999619                         99.999619
#
#                  oleic-acid_100g  elaidic-acid_100g  gondoic-acid_100g  \
# Null Percentage        99.989712              100.0          99.999619
#
#                  mead-acid_100g  erucic-acid_100g  nervonic-acid_100g  \
# Null Percentage       99.999238             100.0           99.999238
#
#                  trans-fat_100g  cholesterol_100g  carbohydrates_100g  \
# Null Percentage       99.786242         99.754616           10.314503
#
#                  sugars_100g  added-sugars_100g  sucrose_100g  glucose_100g  \
# Null Percentage    10.693247          99.948942      99.99276     99.993904
#
#                  fructose_100g  lactose_100g  maltose_100g  \
# Null Percentage      99.987807     99.931414     99.995809
#
#                  maltodextrins_100g  starch_100g  polyols_100g  \
# Null Percentage           99.968374    99.935225     99.644498
#
#                  erythritol_100g  fiber_100g  soluble-fiber_100g  \
# Null Percentage        99.996571   50.027815           99.998476
#
#                  insoluble-fiber_100g  proteins_100g  casein_100g  \
# Null Percentage             99.999238      10.326696    99.981711
#
#                  serum-proteins_100g  nucleotides_100g  salt_100g  \
# Null Percentage             99.98514          99.99276  11.532658
#
#                  added-salt_100g  sodium_100g  alcohol_100g  vitamin-a_100g  \
# Null Percentage            100.0    11.532658      97.08702       99.619731
#
#                  beta-carotene_100g  vitamin-d_100g  vitamin-e_100g  \
# Null Percentage           99.986664       99.450173       99.406354
#
#                  vitamin-k_100g  vitamin-c_100g  vitamin-b1_100g  \
# Null Percentage       99.894836       99.178498        99.470748
#
#                  vitamin-b2_100g  vitamin-pp_100g  vitamin-b6_100g  \
# Null Percentage        99.607157        99.610968        99.511519
#
#                  vitamin-b9_100g  folates_100g  vitamin-b12_100g  biotin_100g  \
# Null Percentage        99.614016     99.993141         99.626209    99.842634
#
#                  pantothenic-acid_100g  silica_100g  bicarbonate_100g  \
# Null Percentage              99.716894    99.980567         99.921127
#
#                  potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# Null Percentage       99.554194      99.852541     98.160002        99.573246
#
#                  iron_100g  magnesium_100g  zinc_100g  copper_100g  \
# Null Percentage  99.200597       99.343103  99.755378    99.861305
#
#                  manganese_100g  fluoride_100g  selenium_100g  chromium_100g  \
# Null Percentage       99.856732      99.914268       99.88188      99.982854
#
#                  molybdenum_100g  iodine_100g  caffeine_100g  taurine_100g  \
# Null Percentage        99.983616    99.855589      99.971423     99.979043
#
#                    ph_100g  fruits-vegetables-nuts_100g  \
# Null Percentage  99.926461                    96.811154
#
#                  fruits-vegetables-nuts-dried_100g  \
# Null Percentage                            99.6967
#
#                  fruits-vegetables-nuts-estimate_100g  \
# Null Percentage                             96.903363
#
#                  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# Null Percentage                                           0.000762
#
#                  collagen-meat-protein-ratio_100g  cocoa_100g  \
# Null Percentage                         99.893692   98.810803
#
#                  chlorophyl_100g  carbon-footprint_100g  \
# Null Percentage        99.999238              99.906647
#
#                  carbon-footprint-from-meat-or-fish_100g  \
# Null Percentage                                95.629196
#
#                  nutrition-score-fr_100g  nutrition-score-uk_100g  \
# Null Percentage                26.212249                99.999238
#
#                  glycemic-index_100g  water-hardness_100g  choline_100g  \
# Null Percentage            99.998476                100.0     99.981711
#
#                  phylloquinone_100g  beta-glucan_100g  inositol_100g  \
# Null Percentage           99.997714          99.99619       99.98514
#
#                  carnitine_100g  sulphate_100g  nitrate_100g  acidity_100g
# Null Percentage       99.987807      99.993522     99.989712     99.998857

# %% [markdown]
# **Notes :**
#
# Il y a beaucoup de données manquantes.
#
# Nous allons dans un premier temps nous concentrer sur les données des produits vendus en France.

# %% [markdown]
# ## Analyse Exploratoire des Données

# %%
# Find different states
unique_values = set()
rawdata['states_tags'].str.split(',').apply(unique_values.update)

states_df = pd.DataFrame(data=unique_values, columns=['states'])
display(states_df)
# Out:
#                                  states
# 0                   en:photos-validated
# 1              en:photos-to-be-uploaded
# 2                    en:photos-uploaded
# 3                    en:to-be-completed
# 4           en:nutrition-photo-selected
# 5        en:ingredients-to-be-completed
# 6          en:nutrition-facts-completed
# 7                 en:quantity-completed
# 8         en:front-photo-to-be-selected
# 9                en:packaging-completed
# 10   en:nutrition-facts-to-be-completed
# 11   en:expiration-date-to-be-completed
# 12                  en:brands-completed
# 13    en:packaging-photo-to-be-selected
# 14          en:quantity-to-be-completed
# 15         en:expiration-date-completed
# 16           en:origins-to-be-completed
# 17            en:product-name-completed
# 18          en:packaging-code-completed
# 19  en:ingredients-photo-to-be-selected
# 20            en:photos-to-be-validated
# 21                     en:to-be-checked
# 22                 en:origins-completed
# 23                           en:checked
# 24          en:packaging-photo-selected
# 25              en:categories-completed
# 26    en:nutrition-photo-to-be-selected
# 27            en:brands-to-be-completed
# 28              en:front-photo-selected
# 29    en:packaging-code-to-be-completed
# 30        en:categories-to-be-completed
# 31         en:packaging-to-be-completed
# 32   en:characteristics-to-be-completed
# 33                          en:complete
# 34        en:ingredients-photo-selected
# 35             en:ingredients-completed
# 36      en:product-name-to-be-completed
# 37         en:characteristics-completed

# %%
# Vérifier que la colonne 'state' existe
if 'state' in rawdata.columns:
    # Compter les occurrences de chaque état
    states_count = rawdata['state'].value_counts().reset_index()
    states_count.columns = ['state', 'count']
    
    # Afficher le tableau
    print(states_count)
else:
    print("La colonne 'state' n'existe pas dans le dataset.")
# Out:
# La colonne 'state' n'existe pas dans le dataset.

# %% [markdown]
# **Notes :**
#
# Il y a beaucoup de colonnes, nous allons sélectionner celles qui potentiellement pourront aider nos futurs modèles à apprendre et à répondre à notre problématique.

# %%
columns_to_keep = [
    'code',
    'url',
    'created_datetime',
    'last_modified_datetime',
    'product_name',
    'packaging_tags',
    'categories_tags',
    'ingredients_tags',
    'ingredients_analysis_tags',
    'allergens',
    'traces_tags',
    'additives_n',
    'additives_tags',
    'nutriscore_grade',
    'food_groups_tags',
    'states_tags',
    'ecoscore_score',
    'ecoscore_grade',
    'nutrient_levels_tags',
    'popularity_tags',
    'main_category',
    'image_url',
    'image_small_url',
    'image_ingredients_url',
    'image_ingredients_small_url',
    'image_nutrition_url',
    'image_nutrition_small_url',
    'energy-kcal_100g',
    'energy_100g',
    'fat_100g',
    'saturated-fat_100g',
    'cholesterol_100g',
    'sugars_100g',
    'proteins_100g',
    'salt_100g',
    'fruits-vegetables-nuts-estimate-from-ingredients_100g'
]

data = rawdata[columns_to_keep]
display(data)
# Out:
#                   code                                                url  \
# 4                    5  http://world-en.openfoodfacts.org/product/0000...
# 9                   10  http://world-en.openfoodfacts.org/product/0000...
# 14                  15  http://world-en.openfoodfacts.org/product/0000...
# 18                  20  http://world-en.openfoodfacts.org/product/0000...
# 20                  22  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 3498741  9999864004549  http://world-en.openfoodfacts.org/product/9999...
# 3498753  9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 3498810  9999991042704  http://world-en.openfoodfacts.org/product/9999...
# 3498834  9999999004360  http://world-en.openfoodfacts.org/product/9999...
# 3498839       99999995  http://world-en.openfoodfacts.org/product/9999...
#
#              created_datetime last_modified_datetime            product_name  \
# 4        2020-11-14T07:08:40Z   2024-10-20T14:02:34Z              Bio inulin
# 9        2016-10-20T07:19:01Z   2024-10-04T09:38:47Z       Madeleines nature
# 14       2018-04-15T16:43:14Z   2024-10-04T09:38:50Z    Madeleines ChocoLait
# 18       2018-09-14T13:14:06Z   2024-10-04T09:38:53Z   Madeleines Choco Noir
# 20       2021-02-28T15:18:57Z   2024-10-04T09:38:54Z  Farandole de madeleine
# ...                       ...                    ...                     ...
# 3498741  2019-08-01T11:12:51Z   2019-08-01T11:25:22Z     Boudin à l’ancienne
# 3498753  2018-01-05T16:53:07Z   2018-01-05T16:53:13Z                 Kabanos
# 3498810  2018-05-09T10:46:24Z   2024-06-16T21:10:13Z          Yaourt vanille
# 3498834  2019-01-21T15:57:57Z   2023-04-28T16:03:26Z          Minis beignets
# 3498839  2018-10-06T09:33:52Z   2024-09-01T05:38:16Z          Steak haché 5%
#
#                                             packaging_tags  \
# 4                                                 en:glass
# 9        en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14                                 en:plastic,en:cardboard
# 18       fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20                 fr:boite-en-carton,fr:film-en-plastique
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                            categories_tags  \
# 4        en:plant-based-foods-and-beverages,en:plant-ba...
# 9        en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# ...                                                    ...
# 3498741  en:meats-and-their-products,en:meats,en:prepar...
# 3498753                                                NaN
# 3498810  en:dairies,en:fermented-foods,en:fermented-mil...
# 3498834        en:snacks,en:sweet-snacks,en:sweet-fritters
# 3498839  en:meats-and-their-products,en:beef-and-its-pr...
#
#                                           ingredients_tags  \
# 4        en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9        en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20       fr:madeleines-choconoir,fr:madeleines-nappees-...
# ...                                                    ...
# 3498741  fr:biocoop-bordeaux-lac-distribue-par-les-elev...
# 3498753  fr:kabanoserc-sktadn-wiep,fr:zekrobia,fr:guszc...
# 3498810  en:whole-milk,en:dairy,en:milk,en:cream,en:sug...
# 3498834  fr:matiere-grasse-du-lait-babeurre,fr:farine-d...
# 3498839  fr:viande-hachee-pur-boeuf-5-m,fr:g,fr:pourcen...
#
#                                  ingredients_analysis_tags  \
# 4                  en:palm-oil-free,en:vegan,en:vegetarian
# 9        en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 14       en:palm-oil-free,en:non-vegan,en:maybe-vegetarian
# 18       en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 20       en:palm-oil-content-unknown,en:non-vegan,en:ve...
# ...                                                    ...
# 3498741  en:may-contain-palm-oil,en:non-vegan,en:non-ve...
# 3498753  en:palm-oil-content-unknown,en:vegan-status-un...
# 3498810  en:palm-oil-free,en:non-vegan,en:vegetarian-st...
# 3498834  en:palm-oil,en:non-vegan,en:vegetarian-status-...
# 3498839  en:palm-oil-content-unknown,en:vegan-status-un...
#
#                                      allergens                traces_tags  \
# 4                                          NaN                        NaN
# 9                    en:eggs,en:gluten,en:milk        en:nuts,en:soybeans
# 14                                         NaN                    en:nuts
# 18       en:eggs,en:gluten,en:milk,en:soybeans                    en:nuts
# 20                                         NaN                    en:nuts
# ...                                        ...                        ...
# 3498741                                    NaN                        NaN
# 3498753                                    NaN                        NaN
# 3498810                                en:milk  en:eggs,en:gluten,en:nuts
# 3498834                                    NaN            en:sesame-seeds
# 3498839                                    NaN                        NaN
#
#          additives_n                                     additives_tags  \
# 4                0.0                                                NaN
# 9                3.0                            en:e331,en:e422,en:e503
# 14               5.0   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# 18               5.0            en:e322,en:e331,en:e422,en:e500,en:e503
# 20               5.0   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# ...              ...                                                ...
# 3498741          0.0                                                NaN
# 3498753          0.0                                                NaN
# 3498810          0.0                                                NaN
# 3498834          5.0  en:e322,en:e322i,en:e412,en:e450,en:e471,en:e5...
# 3498839          0.0                                                NaN
#
#         nutriscore_grade                                   food_groups_tags  \
# 4                      a             en:fruits-and-vegetables,en:vegetables
# 9                      d             en:sugary-snacks,en:biscuits-and-cakes
# 14                     d             en:sugary-snacks,en:biscuits-and-cakes
# 18                     d             en:sugary-snacks,en:biscuits-and-cakes
# 20               unknown             en:sugary-snacks,en:biscuits-and-cakes
# ...                  ...                                                ...
# 3498741          unknown                        en:fish-meat-eggs,en:offals
# 3498753          unknown                                                NaN
# 3498810                c      en:milk-and-dairy-products,en:milk-and-yogurt
# 3498834                d                                                NaN
# 3498839                a  en:fish-meat-eggs,en:meat,en:meat-other-than-p...
#
#                                                states_tags  ecoscore_score  \
# 4        en:to-be-completed,en:nutrition-facts-complete...             NaN
# 9        en:to-be-completed,en:nutrition-facts-complete...            53.0
# 14       en:to-be-completed,en:nutrition-facts-complete...            32.0
# 18       en:to-be-checked,en:complete,en:nutrition-fact...            39.0
# 20       en:to-be-completed,en:nutrition-facts-complete...            41.0
# ...                                                    ...             ...
# 3498741  en:to-be-completed,en:nutrition-facts-complete...            86.0
# 3498753  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 3498810  en:to-be-completed,en:nutrition-facts-complete...            67.0
# 3498834  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 3498839  en:to-be-completed,en:nutrition-facts-complete...           -20.0
#
#         ecoscore_grade                               nutrient_levels_tags  \
# 4              unknown  en:fat-in-low-quantity,en:saturated-fat-in-low...
# 9                    c  en:fat-in-high-quantity,en:saturated-fat-in-mo...
# 14                   d  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 18                   d  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 20                   d                                                NaN
# ...                ...                                                ...
# 3498741              a                                                NaN
# 3498753        unknown                                                NaN
# 3498810              b  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 3498834        unknown  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 3498839              f  en:fat-in-moderate-quantity,en:saturated-fat-i...
#
#                                            popularity_tags  \
# 4                                                      NaN
# 9        top-50000-scans-2019,top-100000-scans-2019,at-...
# 14       top-50000-scans-2019,top-100000-scans-2019,at-...
# 18       top-50000-scans-2019,top-100000-scans-2019,at-...
# 20       top-75-percent-scans-2020,top-80-percent-scans...
# ...                                                    ...
# 3498741  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498753                                                NaN
# 3498810  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498834                                                NaN
# 3498839  bottom-25-percent-scans-2019,bottom-20-percent...
#
#                     main_category  \
# 4                   en:vegetables
# 9             en:plain-madeleines
# 14        en:chocolate-madeleines
# 18        en:chocolate-madeleines
# 20             en:long-madeleines
# ...                           ...
# 3498741  en:sauteed-black-pudding
# 3498753                       NaN
# 3498810         en:vanilla-yogurt
# 3498834         en:sweet-fritters
# 3498839                en:viandes
#
#                                                  image_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                            image_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                      image_ingredients_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                image_ingredients_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                        image_nutrition_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                  image_nutrition_small_url  energy-kcal_100g  \
# 4        https://images.openfoodfacts.org/images/produc...             208.0
# 9        https://images.openfoodfacts.org/images/produc...             442.0
# 14       https://images.openfoodfacts.org/images/produc...             460.0
# 18       https://images.openfoodfacts.org/images/produc...             467.0
# 20       https://images.openfoodfacts.org/images/produc...               NaN
# ...                                                    ...               ...
# 3498741                                                NaN               NaN
# 3498753                                                NaN             549.0
# 3498810                                                NaN             128.0
# 3498834                                                NaN             333.0
# 3498839                                                NaN             131.0
#
#          energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 4              840.0       0.0                 0.0               NaN
# 9             1852.0      22.0                 2.6               NaN
# 14            1926.0      24.0                 6.0               NaN
# 18            1953.0      25.0                 6.1               NaN
# 20               NaN       NaN                 NaN               NaN
# ...              ...       ...                 ...               ...
# 3498741          NaN       NaN                 NaN               NaN
# 3498753       2297.0      48.0                18.0               NaN
# 3498810        536.0       7.6                 5.1               NaN
# 3498834       1393.0      20.2                 6.0               NaN
# 3498839        548.0       5.0                 2.3               NaN
#
#          sugars_100g  proteins_100g  salt_100g  \
# 4                8.0            0.0       0.23
# 9               25.0            6.4       0.53
# 14              31.0            6.4       0.48
# 18              29.0            6.3       0.45
# 20               NaN            NaN        NaN
# ...              ...            ...        ...
# 3498741          NaN            NaN        NaN
# 3498753          1.9           24.0       3.10
# 3498810         11.0            2.7       0.09
# 3498834         10.4            7.4       1.10
# 3498839          0.0           21.5       0.18
#
#          fruits-vegetables-nuts-estimate-from-ingredients_100g
# 4                                                50.000000
# 9                                                22.666667
# 14                                               16.250000
# 18                                               16.250000
# 20                                                1.750000
# ...                                                    ...
# 3498741                                           5.357143
# 3498753                                           0.000000
# 3498810                                           0.000000
# 3498834                                           0.000000
# 3498839                                           0.000000
#
# [262446 rows x 36 columns]

# %%
# Liste des états cibles
target_states = ["en:completed", "en:origins-completed", "en:ingredients-completed"]

# Construire une expression régulière pour les états
pattern = '|'.join(target_states)

# Compter les lignes contenant au moins un des états cibles
count = data['states_tags'].str.contains(pattern).sum()

print("Nombre de lignes avec les états spécifiés:", count)
# Out:
# Nombre de lignes avec les états spécifiés: 258361

# %%
data = data[data['states_tags'].str.contains(pattern)]

# %%
count_data_allergen = data['allergens'].notna().sum()
print("Nombre de lignes avec des allergens:", count_data_allergen)
# Out:
# Nombre de lignes avec des allergens: 100665

# %% [markdown]
# **Notes:**
#
# Nous allons remplacer les valeurs de la colonne allergens non renseignées par la valeur `en:none`.

# %%
data.loc[:, 'allergens'] = data['allergens'].astype(str)
data['allergens'] = data['allergens'].str.lower()
data['allergens'] = data['allergens'].apply(lambda x: 'en:none' if x == 'nan' else x)
data['allergens'].value_counts()
# Out:
# allergens
# en:none                                                                       158457
# en:milk                                                                        23667
# en:gluten                                                                      12388
# en:gluten,en:milk                                                               5871
# en:eggs,en:gluten,en:milk                                                       5612
#                                                                                ...
# en:eggs,fr:omelette                                                                1
# en:celery,en:eggs,en:gluten,en:milk,fr:curry                                       1
# en:celery,en:crustaceans,en:eggs,en:gluten,en:milk,en:molluscs,en:soybeans         1
# en:eggs,en:gluten,en:milk,fr:thon albacore 45 %,fr:colin d'alaska 30 %             1
# en:eggs,en:gluten,en:milk,en:nuts,en:peanuts,fr:biscuit spéculoos                  1
# Name: count, Length: 3144, dtype: int64

# %%
# Divise chaque entrée par ',' et compile tous les allergènes en une seule liste
allergens_list = data["allergens"].fillna('').str.split(',').sum()

# Compte les occurrences de chaque allergène
allergen_counts = Counter(allergens_list)

# Convertir le résultat en DataFrame
allergens_df = pd.DataFrame(allergen_counts.items(), columns=['allergen', 'count']).sort_values(by='count', ascending=False)
display(allergens_df)
# Out:
#                    allergen   count
# 0                   en:none  158511
# 3                   en:milk   56302
# 2                 en:gluten   44189
# 1                   en:eggs   20899
# 4               en:soybeans   15370
# ...                     ...     ...
# 725   fr:disufite de sodium       1
# 726    fr:lait entier crème       1
# 727             fr:cacahete       1
# 728    fr:emmental français       1
# 1487   fr:biscuit spéculoos       1
#
# [1488 rows x 2 columns]

# %% [markdown]
# **Notes :**
#
# On peu se fier seulement aux allergènes contenant plus de 100 produits dans la base de données.
#
# Nous pourronts mettre les autres dans une autre catégories nommée `other`.

# %%
display(allergens_df[allergens_df['count'] > 100])
# Out:
#                              allergen   count
# 0                             en:none  158511
# 3                             en:milk   56302
# 2                           en:gluten   44189
# 1                             en:eggs   20899
# 4                         en:soybeans   15370
# 6                             en:nuts   10530
# 8                             en:fish    8302
# 10   en:sulphur-dioxide-and-sulphites    7400
# 7                          en:mustard    5597
# 5                           en:celery    4356
# 9                     en:sesame-seeds    2590
# 15                     en:crustaceans    2305
# 14                         en:peanuts    1897
# 22                        en:molluscs    1683
# 23                           en:lupin     350
# 13                          fr:avoine     248
# 830                            fr:non     128
# 30                          en:orange     101

# %% [markdown]
# **Notes:**
#
# Nous allons considérer que la valeur vide correspond à pas d'allergène : `en:none`.
#
# Nous allons mettre les allergènes qui ne sont pas dans cette liste dans une catégorie `other`.
#
# Nous pouvons fusionner les valeurs `fr:Non` et `en:none` et traduire `fr:avoine` en `en:oats`.

# %%
# Liste des allergènes à conserver (ceux dont le count est supérieur à 100)
allergens_to_keep = allergens_df[allergens_df['count'] > 100]['allergen'].tolist()
allergens_to_keep.append('en:none') # Ajoute l'entrée none

data['allergens'] = data['allergens'].apply(lambda x: 'other' if x not in allergens_to_keep  else x)
data['allergens'] = data['allergens'].apply(lambda x: 'en:oats' if x == 'fr:avoine' else x)
data['allergens'].value_counts()

display(data)
# Out:
#                   code                                                url  \
# 4                    5  http://world-en.openfoodfacts.org/product/0000...
# 9                   10  http://world-en.openfoodfacts.org/product/0000...
# 14                  15  http://world-en.openfoodfacts.org/product/0000...
# 18                  20  http://world-en.openfoodfacts.org/product/0000...
# 20                  22  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 3498741  9999864004549  http://world-en.openfoodfacts.org/product/9999...
# 3498753  9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 3498810  9999991042704  http://world-en.openfoodfacts.org/product/9999...
# 3498834  9999999004360  http://world-en.openfoodfacts.org/product/9999...
# 3498839       99999995  http://world-en.openfoodfacts.org/product/9999...
#
#              created_datetime last_modified_datetime            product_name  \
# 4        2020-11-14T07:08:40Z   2024-10-20T14:02:34Z              Bio inulin
# 9        2016-10-20T07:19:01Z   2024-10-04T09:38:47Z       Madeleines nature
# 14       2018-04-15T16:43:14Z   2024-10-04T09:38:50Z    Madeleines ChocoLait
# 18       2018-09-14T13:14:06Z   2024-10-04T09:38:53Z   Madeleines Choco Noir
# 20       2021-02-28T15:18:57Z   2024-10-04T09:38:54Z  Farandole de madeleine
# ...                       ...                    ...                     ...
# 3498741  2019-08-01T11:12:51Z   2019-08-01T11:25:22Z     Boudin à l’ancienne
# 3498753  2018-01-05T16:53:07Z   2018-01-05T16:53:13Z                 Kabanos
# 3498810  2018-05-09T10:46:24Z   2024-06-16T21:10:13Z          Yaourt vanille
# 3498834  2019-01-21T15:57:57Z   2023-04-28T16:03:26Z          Minis beignets
# 3498839  2018-10-06T09:33:52Z   2024-09-01T05:38:16Z          Steak haché 5%
#
#                                             packaging_tags  \
# 4                                                 en:glass
# 9        en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14                                 en:plastic,en:cardboard
# 18       fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20                 fr:boite-en-carton,fr:film-en-plastique
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                            categories_tags  \
# 4        en:plant-based-foods-and-beverages,en:plant-ba...
# 9        en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# ...                                                    ...
# 3498741  en:meats-and-their-products,en:meats,en:prepar...
# 3498753                                                NaN
# 3498810  en:dairies,en:fermented-foods,en:fermented-mil...
# 3498834        en:snacks,en:sweet-snacks,en:sweet-fritters
# 3498839  en:meats-and-their-products,en:beef-and-its-pr...
#
#                                           ingredients_tags  \
# 4        en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9        en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20       fr:madeleines-choconoir,fr:madeleines-nappees-...
# ...                                                    ...
# 3498741  fr:biocoop-bordeaux-lac-distribue-par-les-elev...
# 3498753  fr:kabanoserc-sktadn-wiep,fr:zekrobia,fr:guszc...
# 3498810  en:whole-milk,en:dairy,en:milk,en:cream,en:sug...
# 3498834  fr:matiere-grasse-du-lait-babeurre,fr:farine-d...
# 3498839  fr:viande-hachee-pur-boeuf-5-m,fr:g,fr:pourcen...
#
#                                  ingredients_analysis_tags allergens  \
# 4                  en:palm-oil-free,en:vegan,en:vegetarian   en:none
# 9        en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 14       en:palm-oil-free,en:non-vegan,en:maybe-vegetarian   en:none
# 18       en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 20       en:palm-oil-content-unknown,en:non-vegan,en:ve...   en:none
# ...                                                    ...       ...
# 3498741  en:may-contain-palm-oil,en:non-vegan,en:non-ve...   en:none
# 3498753  en:palm-oil-content-unknown,en:vegan-status-un...   en:none
# 3498810  en:palm-oil-free,en:non-vegan,en:vegetarian-st...   en:milk
# 3498834  en:palm-oil,en:non-vegan,en:vegetarian-status-...   en:none
# 3498839  en:palm-oil-content-unknown,en:vegan-status-un...   en:none
#
#                        traces_tags  additives_n  \
# 4                              NaN          0.0
# 9              en:nuts,en:soybeans          3.0
# 14                         en:nuts          5.0
# 18                         en:nuts          5.0
# 20                         en:nuts          5.0
# ...                            ...          ...
# 3498741                        NaN          0.0
# 3498753                        NaN          0.0
# 3498810  en:eggs,en:gluten,en:nuts          0.0
# 3498834            en:sesame-seeds          5.0
# 3498839                        NaN          0.0
#
#                                             additives_tags nutriscore_grade  \
# 4                                                      NaN                a
# 9                                  en:e331,en:e422,en:e503                d
# 14        en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503                d
# 18                 en:e322,en:e331,en:e422,en:e500,en:e503                d
# 20        en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503          unknown
# ...                                                    ...              ...
# 3498741                                                NaN          unknown
# 3498753                                                NaN          unknown
# 3498810                                                NaN                c
# 3498834  en:e322,en:e322i,en:e412,en:e450,en:e471,en:e5...                d
# 3498839                                                NaN                a
#
#                                           food_groups_tags  \
# 4                   en:fruits-and-vegetables,en:vegetables
# 9                   en:sugary-snacks,en:biscuits-and-cakes
# 14                  en:sugary-snacks,en:biscuits-and-cakes
# 18                  en:sugary-snacks,en:biscuits-and-cakes
# 20                  en:sugary-snacks,en:biscuits-and-cakes
# ...                                                    ...
# 3498741                        en:fish-meat-eggs,en:offals
# 3498753                                                NaN
# 3498810      en:milk-and-dairy-products,en:milk-and-yogurt
# 3498834                                                NaN
# 3498839  en:fish-meat-eggs,en:meat,en:meat-other-than-p...
#
#                                                states_tags  ecoscore_score  \
# 4        en:to-be-completed,en:nutrition-facts-complete...             NaN
# 9        en:to-be-completed,en:nutrition-facts-complete...            53.0
# 14       en:to-be-completed,en:nutrition-facts-complete...            32.0
# 18       en:to-be-checked,en:complete,en:nutrition-fact...            39.0
# 20       en:to-be-completed,en:nutrition-facts-complete...            41.0
# ...                                                    ...             ...
# 3498741  en:to-be-completed,en:nutrition-facts-complete...            86.0
# 3498753  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 3498810  en:to-be-completed,en:nutrition-facts-complete...            67.0
# 3498834  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 3498839  en:to-be-completed,en:nutrition-facts-complete...           -20.0
#
#         ecoscore_grade                               nutrient_levels_tags  \
# 4              unknown  en:fat-in-low-quantity,en:saturated-fat-in-low...
# 9                    c  en:fat-in-high-quantity,en:saturated-fat-in-mo...
# 14                   d  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 18                   d  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 20                   d                                                NaN
# ...                ...                                                ...
# 3498741              a                                                NaN
# 3498753        unknown                                                NaN
# 3498810              b  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 3498834        unknown  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 3498839              f  en:fat-in-moderate-quantity,en:saturated-fat-i...
#
#                                            popularity_tags  \
# 4                                                      NaN
# 9        top-50000-scans-2019,top-100000-scans-2019,at-...
# 14       top-50000-scans-2019,top-100000-scans-2019,at-...
# 18       top-50000-scans-2019,top-100000-scans-2019,at-...
# 20       top-75-percent-scans-2020,top-80-percent-scans...
# ...                                                    ...
# 3498741  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498753                                                NaN
# 3498810  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498834                                                NaN
# 3498839  bottom-25-percent-scans-2019,bottom-20-percent...
#
#                     main_category  \
# 4                   en:vegetables
# 9             en:plain-madeleines
# 14        en:chocolate-madeleines
# 18        en:chocolate-madeleines
# 20             en:long-madeleines
# ...                           ...
# 3498741  en:sauteed-black-pudding
# 3498753                       NaN
# 3498810         en:vanilla-yogurt
# 3498834         en:sweet-fritters
# 3498839                en:viandes
#
#                                                  image_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                            image_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                      image_ingredients_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                image_ingredients_small_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741  https://images.openfoodfacts.org/images/produc...
# 3498753  https://images.openfoodfacts.org/images/produc...
# 3498810  https://images.openfoodfacts.org/images/produc...
# 3498834  https://images.openfoodfacts.org/images/produc...
# 3498839  https://images.openfoodfacts.org/images/produc...
#
#                                        image_nutrition_url  \
# 4        https://images.openfoodfacts.org/images/produc...
# 9        https://images.openfoodfacts.org/images/produc...
# 14       https://images.openfoodfacts.org/images/produc...
# 18       https://images.openfoodfacts.org/images/produc...
# 20       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                  image_nutrition_small_url  energy-kcal_100g  \
# 4        https://images.openfoodfacts.org/images/produc...             208.0
# 9        https://images.openfoodfacts.org/images/produc...             442.0
# 14       https://images.openfoodfacts.org/images/produc...             460.0
# 18       https://images.openfoodfacts.org/images/produc...             467.0
# 20       https://images.openfoodfacts.org/images/produc...               NaN
# ...                                                    ...               ...
# 3498741                                                NaN               NaN
# 3498753                                                NaN             549.0
# 3498810                                                NaN             128.0
# 3498834                                                NaN             333.0
# 3498839                                                NaN             131.0
#
#          energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 4              840.0       0.0                 0.0               NaN
# 9             1852.0      22.0                 2.6               NaN
# 14            1926.0      24.0                 6.0               NaN
# 18            1953.0      25.0                 6.1               NaN
# 20               NaN       NaN                 NaN               NaN
# ...              ...       ...                 ...               ...
# 3498741          NaN       NaN                 NaN               NaN
# 3498753       2297.0      48.0                18.0               NaN
# 3498810        536.0       7.6                 5.1               NaN
# 3498834       1393.0      20.2                 6.0               NaN
# 3498839        548.0       5.0                 2.3               NaN
#
#          sugars_100g  proteins_100g  salt_100g  \
# 4                8.0            0.0       0.23
# 9               25.0            6.4       0.53
# 14              31.0            6.4       0.48
# 18              29.0            6.3       0.45
# 20               NaN            NaN        NaN
# ...              ...            ...        ...
# 3498741          NaN            NaN        NaN
# 3498753          1.9           24.0       3.10
# 3498810         11.0            2.7       0.09
# 3498834         10.4            7.4       1.10
# 3498839          0.0           21.5       0.18
#
#          fruits-vegetables-nuts-estimate-from-ingredients_100g
# 4                                                50.000000
# 9                                                22.666667
# 14                                               16.250000
# 18                                               16.250000
# 20                                                1.750000
# ...                                                    ...
# 3498741                                           5.357143
# 3498753                                           0.000000
# 3498810                                           0.000000
# 3498834                                           0.000000
# 3498839                                           0.000000
#
# [258361 rows x 36 columns]

# %%
# Séparer les allergènes par ",", et convertir en une liste
allergens_series = data['allergens'].str.split(',').explode().str.strip()
# Compter les occurrences de chaque allergène
allergens_counts = allergens_series.value_counts().reset_index()
allergens_counts.columns = ['allergen', 'count']

# Créer le graphique
fig = px.bar(allergens_counts, x='allergen', y='count', 
             title="Répartition des allergènes dans le dataset",
             labels={'allergen': 'Allergènes', 'count': 'Nombre d\'occurrences'},
             height=500)

fig.show()

# %% [markdown]
# Maintenant nous allons nous focaliser sur les traces d'allergènes.

# %%
data.loc[:, 'traces_tags'] = data['traces_tags'].astype(str).str.lower()

# Divise chaque entrée par ',' et compile tous les traces d'allergènes en une seule liste
traces_allergens_list = data["traces_tags"].fillna('').str.split(',').sum()

# Compte les occurrences de chaque traces d'allergène
traces_allergen_counts = Counter(traces_allergens_list)

# Convertir le résultat en DataFrame
traces_allergens_df = pd.DataFrame(traces_allergen_counts.items(), columns=['allergen', 'count']).sort_values(by='count', ascending=False)
display(allergens_df)
# Out:
#                    allergen   count
# 0                   en:none  158511
# 3                   en:milk   56302
# 2                 en:gluten   44189
# 1                   en:eggs   20899
# 4               en:soybeans   15370
# ...                     ...     ...
# 725   fr:disufite de sodium       1
# 726    fr:lait entier crème       1
# 727             fr:cacahete       1
# 728    fr:emmental français       1
# 1487   fr:biscuit spéculoos       1
#
# [1488 rows x 2 columns]

# %%
display(traces_allergens_df[traces_allergens_df['count'] > 20])
# Out:
#                                          allergen   count
# 0                                             nan  180752
# 1                                         en:nuts   41442
# 2                                     en:soybeans   28009
# 11                                        en:milk   25267
# 4                                       en:gluten   21943
# 6                                         en:eggs   21711
# 5                                 en:sesame-seeds   17072
# 20                                     en:mustard   13961
# 7                                       en:celery   13398
# 17                                     en:peanuts   10851
# 16                                        en:fish    9226
# 15                                 en:crustaceans    8425
# 22                                    en:molluscs    7018
# 19               en:sulphur-dioxide-and-sulphites    4533
# 23                                       en:lupin    2416
# 36                                        en:none    1026
# 62                               fr:phenylalanine     140
# 38                                         fr:non     131
# 50                                      fr:noyaux     119
# 256                                      fr:arete      63
# 28                                        en:lait      62
# 257                                     fr:aretes      61
# 483                                      fr:noyau      61
# 39                              en:fruits-a-coque      50
# 242                                   fr:cereales      49
# 51                                       fr:neant      43
# 139                                fr:sans-gluten      36
# 271              fr:dioxyde-de-soufre-et-sulfites      36
# 536   fr:si-le-numero-de-lot-contient-la-lettre-n      35
# 289                                     en:celeri      29
# 376                                   en:moutarde      28
# 356                                     fr:alcool      26
# 111                                    en:en-nuts      24
# 1946          fr:peu-contenir-des-traces-d-alcool      22
# 88                                         fr:sel      21
# 731                                       fr:gras      21

# %%
# Séparer les allergènes par ",", et convertir en une liste
data.loc[:, 'traces_tags'] = data['traces_tags'].astype(str)

traces_allergens_to_keep = traces_allergens_df[traces_allergens_df['count'] > 20]['allergen'].tolist()

data['traces_tags'] = data['traces_tags'].apply(lambda x: 'en:none' if (x == 'nan')  else x)
data['traces_tags'] = data['traces_tags'].apply(lambda x: 'other' if x not in traces_allergens_to_keep  else x)

traces_allergens_series = data['traces_tags'].str.split(',').explode().str.strip()
traces_allergens_counts = traces_allergens_series.value_counts().reset_index()
traces_allergens_counts.columns = ['traces_tags', 'count']

# Créer le graphique
fig = px.bar(traces_allergens_counts, x='traces_tags', y='count', 
             title="Répartition des traces d'allergènes dans le dataset",
             labels={'traces_tags': 'Traces allergènes', 'count': 'Nombre d\'occurrences'},
             height=500)

fig.show()

# %% [markdown]
# ### Sélections et nettoyage des données

# %%
data.describe(include='all')
# Out:
#                  code                                                url  \
# count          258361                                             258361
# unique         257585                                             257591
# top     3250390663201  http://world-en.openfoodfacts.org/product/3254...
# freq                2                                                  2
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#             created_datetime last_modified_datetime product_name  \
# count                 258361                 258361       255537
# unique                253809                 226334       197147
# top     2021-04-20T10:35:38Z   2023-10-26T17:32:26Z        Comté
# freq                      13                     23          204
# mean                     NaN                    NaN          NaN
# std                      NaN                    NaN          NaN
# min                      NaN                    NaN          NaN
# 25%                      NaN                    NaN          NaN
# 50%                      NaN                    NaN          NaN
# 75%                      NaN                    NaN          NaN
# max                      NaN                    NaN          NaN
#
#            packaging_tags categories_tags  \
# count              130790          222035
# unique              18477           49675
# top     en:plastic,en:bag    en:beverages
# freq                 7450            1681
# mean                  NaN             NaN
# std                   NaN             NaN
# min                   NaN             NaN
# 25%                   NaN             NaN
# 50%                   NaN             NaN
# 75%                   NaN             NaN
# max                   NaN             NaN
#
#                                          ingredients_tags  \
# count                                              258361
# unique                                             196813
# top     en:superior-quality-durum-wheat-semolina,en:ce...
# freq                                                  784
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       ingredients_analysis_tags allergens traces_tags  \
# count                                    258359    258361      258361
# unique                                       37        19          33
# top     en:palm-oil-free,en:vegan,en:vegetarian   en:none     en:none
# freq                                      45406    158457      181708
# mean                                        NaN       NaN         NaN
# std                                         NaN       NaN         NaN
# min                                         NaN       NaN         NaN
# 25%                                         NaN       NaN         NaN
# 50%                                         NaN       NaN         NaN
# 75%                                         NaN       NaN         NaN
# max                                         NaN       NaN         NaN
#
#           additives_n    additives_tags nutriscore_grade  \
# count   258361.000000            131893           258345
# unique            NaN             33170                7
# top               NaN  en:e322,en:e322i          unknown
# freq              NaN              6665            56101
# mean         1.529871               NaN              NaN
# std          2.332687               NaN              NaN
# min          0.000000               NaN              NaN
# 25%          0.000000               NaN              NaN
# 50%          1.000000               NaN              NaN
# 75%          2.000000               NaN              NaN
# max         35.000000               NaN              NaN
#
#                               food_groups_tags  \
# count                                   200085
# unique                                      45
# top     en:sugary-snacks,en:biscuits-and-cakes
# freq                                     17355
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                                               states_tags  ecoscore_score  \
# count                                              258361   159886.000000
# unique                                               2159             NaN
# top     en:to-be-completed,en:nutrition-facts-complete...             NaN
# freq                                                20867             NaN
# mean                                                  NaN       55.388873
# std                                                   NaN       28.206574
# min                                                   NaN      -30.000000
# 25%                                                   NaN       35.000000
# 50%                                                   NaN       56.000000
# 75%                                                   NaN       76.000000
# max                                                   NaN      125.000000
#
#        ecoscore_grade                               nutrient_levels_tags  \
# count          258353                                             193750
# unique              9                                                225
# top           unknown  en:fat-in-low-quantity,en:saturated-fat-in-low...
# freq            94324                                              22137
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#                                           popularity_tags main_category  \
# count                                              185127        222035
# unique                                              86223         17077
# top     bottom-25-percent-scans-2019,bottom-20-percent...  en:groceries
# freq                                                 6150          8684
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#                                                 image_url  \
# count                                              239625
# unique                                             238878
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           image_small_url  \
# count                                              239625
# unique                                             238878
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                     image_ingredients_url  \
# count                                              224313
# unique                                             223596
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               image_ingredients_small_url  \
# count                                              224313
# unique                                             223596
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                       image_nutrition_url  \
# count                                              183187
# unique                                             182612
# top     https://images.openfoodfacts.org/images/produc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 image_nutrition_small_url  energy-kcal_100g  \
# count                                              183187      2.139710e+05
# unique                                             182612               NaN
# top     https://images.openfoodfacts.org/images/produc...               NaN
# freq                                                    2               NaN
# mean                                                  NaN      6.636413e+10
# std                                                   NaN      3.069806e+13
# min                                                   NaN      0.000000e+00
# 25%                                                   NaN      1.110000e+02
# 50%                                                   NaN      2.520000e+02
# 75%                                                   NaN      3.930000e+02
# max                                                   NaN      1.420000e+16
#
#          energy_100g       fat_100g  saturated-fat_100g  cholesterol_100g  \
# count   2.318000e+05  231549.000000       229837.000000        637.000000
# unique           NaN            NaN                 NaN               NaN
# top              NaN            NaN                 NaN               NaN
# freq             NaN            NaN                 NaN               NaN
# mean    2.566868e+11      13.531768            5.250109          0.128933
# std     1.235834e+14      17.007197            7.945012          1.446770
# min     0.000000e+00       0.000000            0.000000          0.000000
# 25%     4.610000e+02       1.100000            0.260000          0.000000
# 50%     1.040000e+03       7.200000            2.000000          0.000000
# 75%     1.636000e+03      21.000000            7.200000          0.016700
# max     5.950000e+16     231.000000          163.000000         24.000000
#
#           sugars_100g  proteins_100g      salt_100g  \
# count   230437.000000  231393.000000  228250.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean        13.672234       8.337464       1.148384
# std         22.894757       9.162811       7.355613
# min         -0.100000       0.000000       0.000000
# 25%          0.800000       1.700000       0.050000
# 50%          3.600000       6.000000       0.500000
# 75%         19.000000      12.000000       1.200000
# max       5551.000000     579.000000    2500.000000
#
#         fruits-vegetables-nuts-estimate-from-ingredients_100g
# count                                       258359.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            19.084162
# std                                             48.318683
# min                                            -65.887256
# 25%                                              0.000000
# 50%                                              0.044759
# 75%                                             22.525240
# max                                          13461.000000

# %%
data[data['additives_n'] == 1.0].head()
# Out:
#     code                                                url  \
# 49    51  http://world-en.openfoodfacts.org/product/0000...
# 120  131  http://world-en.openfoodfacts.org/product/0000...
# 170  184  http://world-en.openfoodfacts.org/product/0000...
# 260  289  http://world-en.openfoodfacts.org/product/0000...
# 402  476  http://world-en.openfoodfacts.org/product/0000...
#
#          created_datetime last_modified_datetime  \
# 49   2016-12-01T19:59:24Z   2024-10-11T08:26:38Z
# 120  2020-06-30T12:29:48Z   2024-10-29T14:06:01Z
# 170  2023-02-25T11:51:38Z   2024-10-04T09:45:42Z
# 260  2019-09-14T10:42:53Z   2024-10-04T09:40:01Z
# 402  2019-08-19T21:04:21Z   2024-10-11T14:12:41Z
#
#                           product_name                       packaging_tags  \
# 49                     Fondants Citron  fr:boite-carton,fr:sachet-plastique
# 120  Confiture de fraise mara des bois                                  NaN
# 170               Whey Protein Vanilla                                  NaN
# 260                     Passiflore BIO                                  NaN
# 402                           Encore +                               flacon
#
#                                        categories_tags  \
# 49   en:plant-based-foods-and-beverages,en:plant-ba...
# 120  en:plant-based-foods-and-beverages,en:plant-ba...
# 170                             en:dietary-supplements
# 260                             en:dietary-supplements
# 402                              fr:lubrifiant-feminin
#
#                                       ingredients_tags  \
# 49   en:blackberry,en:fruit,en:berries,en:cane-suga...
# 120         en:e968,en:monk-fruit-extract,en:sweetener
# 170  fr:ingredients,fr:tunique,fr:extrait-de-fruits...
# 260  fr:complement-alimentair-ingredients-pour-3-co...
# 402  fr:cyclopentasiloxane,en:e900,fr:paraben-free,...
#
#                              ingredients_analysis_tags allergens traces_tags  \
# 49   en:palm-oil-free,en:vegan-status-unknown,en:ve...     other       other
# 120  en:palm-oil-free,en:vegan-status-unknown,en:ve...   en:none     en:none
# 170  en:palm-oil-content-unknown,en:vegan-status-un...     other     en:none
# 260  en:palm-oil-content-unknown,en:vegan-status-un...   en:none     en:none
# 402  en:palm-oil-content-unknown,en:vegan-status-un...   en:none     en:none
#
#      additives_n    additives_tags nutriscore_grade  \
# 49           1.0           en:e440                c
# 120          1.0           en:e968                c
# 170          1.0           en:e464                b
# 260          1.0  en:e553,en:e553b          unknown
# 402          1.0           en:e900              NaN
#
#                food_groups_tags  \
# 49   en:sugary-snacks,en:sweets
# 120  en:sugary-snacks,en:sweets
# 170                         NaN
# 260                         NaN
# 402                         NaN
#
#                                            states_tags  ecoscore_score  \
# 49   en:to-be-completed,en:nutrition-facts-complete...            64.0
# 120  en:to-be-completed,en:nutrition-facts-complete...            60.0
# 170  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 260  en:to-be-completed,en:nutrition-facts-complete...             NaN
# 402  en:to-be-completed,en:nutrition-facts-to-be-co...             NaN
#
#     ecoscore_grade                               nutrient_levels_tags  \
# 49               b  en:fat-in-low-quantity,en:saturated-fat-in-low...
# 120              b  en:fat-in-low-quantity,en:saturated-fat-in-low...
# 170        unknown  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 260        unknown                                                NaN
# 402            NaN                                                NaN
#
#                                        popularity_tags  \
# 49   top-50000-scans-2019,top-100000-scans-2019,at-...
# 120                                                NaN
# 170                                                NaN
# 260  bottom-25-percent-scans-2019,bottom-20-percent...
# 402                                                NaN
#
#               main_category  \
# 49                  en:jams
# 120      en:strawberry-jams
# 170  en:dietary-supplements
# 260  en:dietary-supplements
# 402   fr:lubrifiant-feminin
#
#                                              image_url  \
# 49   https://images.openfoodfacts.org/images/produc...
# 120  https://images.openfoodfacts.org/images/produc...
# 170                                                NaN
# 260  https://images.openfoodfacts.org/images/produc...
# 402  https://images.openfoodfacts.org/images/produc...
#
#                                        image_small_url  \
# 49   https://images.openfoodfacts.org/images/produc...
# 120  https://images.openfoodfacts.org/images/produc...
# 170                                                NaN
# 260  https://images.openfoodfacts.org/images/produc...
# 402  https://images.openfoodfacts.org/images/produc...
#
#                                  image_ingredients_url  \
# 49   https://images.openfoodfacts.org/images/produc...
# 120                                                NaN
# 170                                                NaN
# 260  https://images.openfoodfacts.org/images/produc...
# 402  https://images.openfoodfacts.org/images/produc...
#
#                            image_ingredients_small_url  \
# 49   https://images.openfoodfacts.org/images/produc...
# 120                                                NaN
# 170                                                NaN
# 260  https://images.openfoodfacts.org/images/produc...
# 402  https://images.openfoodfacts.org/images/produc...
#
#                                    image_nutrition_url  \
# 49   https://images.openfoodfacts.org/images/produc...
# 120  https://images.openfoodfacts.org/images/produc...
# 170                                                NaN
# 260                                                NaN
# 402                                                NaN
#
#                              image_nutrition_small_url  energy-kcal_100g  \
# 49   https://images.openfoodfacts.org/images/produc...             249.0
# 120  https://images.openfoodfacts.org/images/produc...               0.0
# 170                                                NaN             377.0
# 260                                                NaN               NaN
# 402                                                NaN               NaN
#
#      energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  sugars_100g  \
# 49        1056.0      0.30                0.05               NaN        59.00
# 120          0.0      0.00                0.00               NaN       725.00
# 170       1580.0      4.33                1.33               NaN         3.33
# 260          NaN       NaN                 NaN               NaN          NaN
# 402          NaN       NaN                 NaN               NaN          NaN
#
#      proteins_100g  salt_100g  \
# 49             0.5      0.050
# 120            0.0      0.000
# 170           80.0      0.233
# 260            NaN        NaN
# 402            NaN        NaN
#
#      fruits-vegetables-nuts-estimate-from-ingredients_100g
# 49                                                50.0
# 120                                                0.0
# 170                                                0.0
# 260                                                0.0
# 402                                                0.0

# %% [markdown]
# - url --> ok
# - created_datetime --> transform to 1 column for year
# - last_modified_datetime --> transform to 1 column for year
# - product_name --> delete empty rows
# - packaging_tags --> set 'en:unknown' for empty rows
# - categories_tags --> set 'en:unknown' for empty rows
# - ingredients_tags --> delete empty rows
# - ingredients_analysis_tags --> set 'unknown' for empty rows
# - allergens --> set 'en:none' for empty rows
# - traces_tags --> set 'en:none' for empty rows
# - additives_n --> ok
# - additives_tags --> set en:none when empty
# - nutriscore_grade --> set unknown when empty
# - food_groups_tags --> set en:none when empty
# - states_tags --> ok
# - ecoscore_grade --> set unknown when empty
# - nutrient_levels_tags --> set en:unknown when empty
# - popularity_tags --> set unknown when empty
# - main_category --> set en:none when empty
# - image_url --> set 'en:none' for empty rows
# - energy-kcal_100g --> set -1 for empty rows
# - energy_100g --> set -1 for empty rows
# - fat_100g --> set -1 for empty rows
# - cholesterol_100g --> set -1 for empty rows
# - sugars_100g --> set -1 for empty rows
# - proteins_100g --> set -1 for empty rows
# - salt_100g --> set -1 for empty rows

# %%
columns_to_keep = [
    'code',
    'url',
    'last_modified_datetime',
    'product_name',
    'packaging_tags',
    'categories_tags',
    'ingredients_tags',
    'ingredients_analysis_tags',
    'allergens',
    'traces_tags',
    'additives_tags',
    'nutriscore_grade',
    'food_groups_tags',
    'states_tags',
    'ecoscore_grade',
    'nutrient_levels_tags',
    'popularity_tags',
    'main_category',
    'image_url',
    'energy_100g',
    'fat_100g',
    'saturated-fat_100g',
    'cholesterol_100g',
    'sugars_100g',
    'proteins_100g',
    'salt_100g',
    'fruits-vegetables-nuts-estimate-from-ingredients_100g'
]

clean_data = data[columns_to_keep]
display(clean_data)
# Out:
#                   code                                                url  \
# 4                    5  http://world-en.openfoodfacts.org/product/0000...
# 9                   10  http://world-en.openfoodfacts.org/product/0000...
# 14                  15  http://world-en.openfoodfacts.org/product/0000...
# 18                  20  http://world-en.openfoodfacts.org/product/0000...
# 20                  22  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 3498741  9999864004549  http://world-en.openfoodfacts.org/product/9999...
# 3498753  9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 3498810  9999991042704  http://world-en.openfoodfacts.org/product/9999...
# 3498834  9999999004360  http://world-en.openfoodfacts.org/product/9999...
# 3498839       99999995  http://world-en.openfoodfacts.org/product/9999...
#
#         last_modified_datetime            product_name  \
# 4         2024-10-20T14:02:34Z              Bio inulin
# 9         2024-10-04T09:38:47Z       Madeleines nature
# 14        2024-10-04T09:38:50Z    Madeleines ChocoLait
# 18        2024-10-04T09:38:53Z   Madeleines Choco Noir
# 20        2024-10-04T09:38:54Z  Farandole de madeleine
# ...                        ...                     ...
# 3498741   2019-08-01T11:25:22Z     Boudin à l’ancienne
# 3498753   2018-01-05T16:53:13Z                 Kabanos
# 3498810   2024-06-16T21:10:13Z          Yaourt vanille
# 3498834   2023-04-28T16:03:26Z          Minis beignets
# 3498839   2024-09-01T05:38:16Z          Steak haché 5%
#
#                                             packaging_tags  \
# 4                                                 en:glass
# 9        en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14                                 en:plastic,en:cardboard
# 18       fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20                 fr:boite-en-carton,fr:film-en-plastique
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810                                                NaN
# 3498834                                                NaN
# 3498839                                                NaN
#
#                                            categories_tags  \
# 4        en:plant-based-foods-and-beverages,en:plant-ba...
# 9        en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20       en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# ...                                                    ...
# 3498741  en:meats-and-their-products,en:meats,en:prepar...
# 3498753                                                NaN
# 3498810  en:dairies,en:fermented-foods,en:fermented-mil...
# 3498834        en:snacks,en:sweet-snacks,en:sweet-fritters
# 3498839  en:meats-and-their-products,en:beef-and-its-pr...
#
#                                           ingredients_tags  \
# 4        en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9        en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18       en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20       fr:madeleines-choconoir,fr:madeleines-nappees-...
# ...                                                    ...
# 3498741  fr:biocoop-bordeaux-lac-distribue-par-les-elev...
# 3498753  fr:kabanoserc-sktadn-wiep,fr:zekrobia,fr:guszc...
# 3498810  en:whole-milk,en:dairy,en:milk,en:cream,en:sug...
# 3498834  fr:matiere-grasse-du-lait-babeurre,fr:farine-d...
# 3498839  fr:viande-hachee-pur-boeuf-5-m,fr:g,fr:pourcen...
#
#                                  ingredients_analysis_tags allergens  \
# 4                  en:palm-oil-free,en:vegan,en:vegetarian   en:none
# 9        en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 14       en:palm-oil-free,en:non-vegan,en:maybe-vegetarian   en:none
# 18       en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 20       en:palm-oil-content-unknown,en:non-vegan,en:ve...   en:none
# ...                                                    ...       ...
# 3498741  en:may-contain-palm-oil,en:non-vegan,en:non-ve...   en:none
# 3498753  en:palm-oil-content-unknown,en:vegan-status-un...   en:none
# 3498810  en:palm-oil-free,en:non-vegan,en:vegetarian-st...   en:milk
# 3498834  en:palm-oil,en:non-vegan,en:vegetarian-status-...   en:none
# 3498839  en:palm-oil-content-unknown,en:vegan-status-un...   en:none
#
#              traces_tags                                     additives_tags  \
# 4                en:none                                                NaN
# 9                  other                            en:e331,en:e422,en:e503
# 14               en:nuts   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# 18               en:nuts            en:e322,en:e331,en:e422,en:e500,en:e503
# 20               en:nuts   en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# ...                  ...                                                ...
# 3498741          en:none                                                NaN
# 3498753          en:none                                                NaN
# 3498810            other                                                NaN
# 3498834  en:sesame-seeds  en:e322,en:e322i,en:e412,en:e450,en:e471,en:e5...
# 3498839          en:none                                                NaN
#
#         nutriscore_grade                                   food_groups_tags  \
# 4                      a             en:fruits-and-vegetables,en:vegetables
# 9                      d             en:sugary-snacks,en:biscuits-and-cakes
# 14                     d             en:sugary-snacks,en:biscuits-and-cakes
# 18                     d             en:sugary-snacks,en:biscuits-and-cakes
# 20               unknown             en:sugary-snacks,en:biscuits-and-cakes
# ...                  ...                                                ...
# 3498741          unknown                        en:fish-meat-eggs,en:offals
# 3498753          unknown                                                NaN
# 3498810                c      en:milk-and-dairy-products,en:milk-and-yogurt
# 3498834                d                                                NaN
# 3498839                a  en:fish-meat-eggs,en:meat,en:meat-other-than-p...
#
#                                                states_tags ecoscore_grade  \
# 4        en:to-be-completed,en:nutrition-facts-complete...        unknown
# 9        en:to-be-completed,en:nutrition-facts-complete...              c
# 14       en:to-be-completed,en:nutrition-facts-complete...              d
# 18       en:to-be-checked,en:complete,en:nutrition-fact...              d
# 20       en:to-be-completed,en:nutrition-facts-complete...              d
# ...                                                    ...            ...
# 3498741  en:to-be-completed,en:nutrition-facts-complete...              a
# 3498753  en:to-be-completed,en:nutrition-facts-complete...        unknown
# 3498810  en:to-be-completed,en:nutrition-facts-complete...              b
# 3498834  en:to-be-completed,en:nutrition-facts-complete...        unknown
# 3498839  en:to-be-completed,en:nutrition-facts-complete...              f
#
#                                       nutrient_levels_tags  \
# 4        en:fat-in-low-quantity,en:saturated-fat-in-low...
# 9        en:fat-in-high-quantity,en:saturated-fat-in-mo...
# 14       en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 18       en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 20                                                     NaN
# ...                                                    ...
# 3498741                                                NaN
# 3498753                                                NaN
# 3498810  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 3498834  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 3498839  en:fat-in-moderate-quantity,en:saturated-fat-i...
#
#                                            popularity_tags  \
# 4                                                      NaN
# 9        top-50000-scans-2019,top-100000-scans-2019,at-...
# 14       top-50000-scans-2019,top-100000-scans-2019,at-...
# 18       top-50000-scans-2019,top-100000-scans-2019,at-...
# 20       top-75-percent-scans-2020,top-80-percent-scans...
# ...                                                    ...
# 3498741  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498753                                                NaN
# 3498810  bottom-25-percent-scans-2019,bottom-20-percent...
# 3498834                                                NaN
# 3498839  bottom-25-percent-scans-2019,bottom-20-percent...
#
#                     main_category  \
# 4                   en:vegetables
# 9             en:plain-madeleines
# 14        en:chocolate-madeleines
# 18        en:chocolate-madeleines
# 20             en:long-madeleines
# ...                           ...
# 3498741  en:sauteed-black-pudding
# 3498753                       NaN
# 3498810         en:vanilla-yogurt
# 3498834         en:sweet-fritters
# 3498839                en:viandes
#
#                                                  image_url  energy_100g  \
# 4        https://images.openfoodfacts.org/images/produc...        840.0
# 9        https://images.openfoodfacts.org/images/produc...       1852.0
# 14       https://images.openfoodfacts.org/images/produc...       1926.0
# 18       https://images.openfoodfacts.org/images/produc...       1953.0
# 20       https://images.openfoodfacts.org/images/produc...          NaN
# ...                                                    ...          ...
# 3498741                                                NaN          NaN
# 3498753  https://images.openfoodfacts.org/images/produc...       2297.0
# 3498810  https://images.openfoodfacts.org/images/produc...        536.0
# 3498834  https://images.openfoodfacts.org/images/produc...       1393.0
# 3498839  https://images.openfoodfacts.org/images/produc...        548.0
#
#          fat_100g  saturated-fat_100g  cholesterol_100g  sugars_100g  \
# 4             0.0                 0.0               NaN          8.0
# 9            22.0                 2.6               NaN         25.0
# 14           24.0                 6.0               NaN         31.0
# 18           25.0                 6.1               NaN         29.0
# 20            NaN                 NaN               NaN          NaN
# ...           ...                 ...               ...          ...
# 3498741       NaN                 NaN               NaN          NaN
# 3498753      48.0                18.0               NaN          1.9
# 3498810       7.6                 5.1               NaN         11.0
# 3498834      20.2                 6.0               NaN         10.4
# 3498839       5.0                 2.3               NaN          0.0
#
#          proteins_100g  salt_100g  \
# 4                  0.0       0.23
# 9                  6.4       0.53
# 14                 6.4       0.48
# 18                 6.3       0.45
# 20                 NaN        NaN
# ...                ...        ...
# 3498741            NaN        NaN
# 3498753           24.0       3.10
# 3498810            2.7       0.09
# 3498834            7.4       1.10
# 3498839           21.5       0.18
#
#          fruits-vegetables-nuts-estimate-from-ingredients_100g
# 4                                                50.000000
# 9                                                22.666667
# 14                                               16.250000
# 18                                               16.250000
# 20                                                1.750000
# ...                                                    ...
# 3498741                                           5.357143
# 3498753                                           0.000000
# 3498810                                           0.000000
# 3498834                                           0.000000
# 3498839                                           0.000000
#
# [258361 rows x 27 columns]

# %%
import pandas as pd


def clean_dataset(df):
    # Transformation des dates en année
    df['last_modified_year'] = pd.to_datetime(df['last_modified_datetime']).dt.year
    
    # Supprimer les lignes vides pour certaines colonnes
    df = df.dropna(subset=['product_name', 'ingredients_tags'])
    
    # Remplacer les valeurs vides dans d'autres colonnes
    fill_values = {
        'packaging_tags': 'en:unknown',
        'categories_tags': 'en:unknown',
        'ingredients_analysis_tags': 'unknown',
        'allergens': 'en:none',
        'traces_tags': 'en:none',
        'additives_tags': 'en:none',
        'nutriscore_grade': 'unknown',
        'food_groups_tags': 'en:none',
        'states_tags': 'en:unknown',
        'ecoscore_grade': 'unknown',
        'nutrient_levels_tags': 'en:unknown',
        'popularity_tags': 'unknown',
        'main_category': 'en:none',
        'image_url': 'en:none',
        'energy_100g': -1,
        'fat_100g': -1,
        'saturated-fat_100g': -1,
        'cholesterol_100g': -1,
        'sugars_100g': -1,
        'proteins_100g': -1,
        'salt_100g': -1,
        'fruits-vegetables-nuts-estimate-from-ingredients_100g': -1
    }

    df.fillna(value=fill_values, inplace=True)
    
    # Supprimer les colonnes non nécessaires
    df = df.drop(columns=['last_modified_datetime'])
    
    return df

clean_data = clean_dataset(clean_data)
clean_data.head()
# Out:
# /tmp/ipykernel_255177/127166964.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_255177/127166964.py:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    code                                                url  \
# 4     5  http://world-en.openfoodfacts.org/product/0000...
# 9    10  http://world-en.openfoodfacts.org/product/0000...
# 14   15  http://world-en.openfoodfacts.org/product/0000...
# 18   20  http://world-en.openfoodfacts.org/product/0000...
# 20   22  http://world-en.openfoodfacts.org/product/0000...
#
#               product_name                                     packaging_tags  \
# 4               Bio inulin                                           en:glass
# 9        Madeleines nature  en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14    Madeleines ChocoLait                            en:plastic,en:cardboard
# 18   Madeleines Choco Noir  fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20  Farandole de madeleine            fr:boite-en-carton,fr:film-en-plastique
#
#                                       categories_tags  \
# 4   en:plant-based-foods-and-beverages,en:plant-ba...
# 9   en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
#
#                                      ingredients_tags  \
# 4   en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9   en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20  fr:madeleines-choconoir,fr:madeleines-nappees-...
#
#                             ingredients_analysis_tags allergens traces_tags  \
# 4             en:palm-oil-free,en:vegan,en:vegetarian   en:none     en:none
# 9   en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other       other
# 14  en:palm-oil-free,en:non-vegan,en:maybe-vegetarian   en:none     en:nuts
# 18  en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other     en:nuts
# 20  en:palm-oil-content-unknown,en:non-vegan,en:ve...   en:none     en:nuts
#
#                                       additives_tags nutriscore_grade  \
# 4                                            en:none                a
# 9                            en:e331,en:e422,en:e503                d
# 14  en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503                d
# 18           en:e322,en:e331,en:e422,en:e500,en:e503                d
# 20  en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503          unknown
#
#                           food_groups_tags  \
# 4   en:fruits-and-vegetables,en:vegetables
# 9   en:sugary-snacks,en:biscuits-and-cakes
# 14  en:sugary-snacks,en:biscuits-and-cakes
# 18  en:sugary-snacks,en:biscuits-and-cakes
# 20  en:sugary-snacks,en:biscuits-and-cakes
#
#                                           states_tags ecoscore_grade  \
# 4   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 9   en:to-be-completed,en:nutrition-facts-complete...              c
# 14  en:to-be-completed,en:nutrition-facts-complete...              d
# 18  en:to-be-checked,en:complete,en:nutrition-fact...              d
# 20  en:to-be-completed,en:nutrition-facts-complete...              d
#
#                                  nutrient_levels_tags  \
# 4   en:fat-in-low-quantity,en:saturated-fat-in-low...
# 9   en:fat-in-high-quantity,en:saturated-fat-in-mo...
# 14  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 18  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 20                                         en:unknown
#
#                                       popularity_tags  \
# 4                                             unknown
# 9   top-50000-scans-2019,top-100000-scans-2019,at-...
# 14  top-50000-scans-2019,top-100000-scans-2019,at-...
# 18  top-50000-scans-2019,top-100000-scans-2019,at-...
# 20  top-75-percent-scans-2020,top-80-percent-scans...
#
#               main_category  \
# 4             en:vegetables
# 9       en:plain-madeleines
# 14  en:chocolate-madeleines
# 18  en:chocolate-madeleines
# 20       en:long-madeleines
#
#                                             image_url  energy_100g  fat_100g  \
# 4   https://images.openfoodfacts.org/images/produc...        840.0       0.0
# 9   https://images.openfoodfacts.org/images/produc...       1852.0      22.0
# 14  https://images.openfoodfacts.org/images/produc...       1926.0      24.0
# 18  https://images.openfoodfacts.org/images/produc...       1953.0      25.0
# 20  https://images.openfoodfacts.org/images/produc...         -1.0      -1.0
#
#     saturated-fat_100g  cholesterol_100g  sugars_100g  proteins_100g  \
# 4                  0.0              -1.0          8.0            0.0
# 9                  2.6              -1.0         25.0            6.4
# 14                 6.0              -1.0         31.0            6.4
# 18                 6.1              -1.0         29.0            6.3
# 20                -1.0              -1.0         -1.0           -1.0
#
#     salt_100g  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 4        0.23                                          50.000000
# 9        0.53                                          22.666667
# 14       0.48                                          16.250000
# 18       0.45                                          16.250000
# 20      -1.00                                           1.750000
#
#     last_modified_year
# 4                 2024
# 9                 2024
# 14                2024
# 18                2024
# 20                2024

# %%
dftest= clean_data['main_category'].value_counts().reset_index()
dftest[dftest['count'] > 100]
# Out:
#                    main_category  count
# 0                        en:none  34985
# 1                   en:groceries   8649
# 2         en:sweetened-beverages   4210
# 3                   en:beverages   1725
# 4                     en:candies   1474
# ..                           ...    ...
# 427           en:smoked-sausages    102
# 428    en:canned-flageolet-beans    102
# 429  en:sardines-in-tomato-sauce    101
# 430           en:blackberry-jams    101
# 431                  en:gherkins    101
#
# [432 rows x 2 columns]

# %%
clean_data.describe(include='all')
# Out:
#                 code                                                url  \
# count   2.555370e+05                                             255537
# unique  2.547650e+05                                             254771
# top     3.254560e+12  http://world-en.openfoodfacts.org/product/3433...
# freq    2.000000e+00                                                  2
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#        product_name packaging_tags categories_tags  \
# count        255537         255537          255537
# unique       197147          18379           49352
# top           Comté     en:unknown      en:unknown
# freq            204         125404           34985
# mean            NaN            NaN             NaN
# std             NaN            NaN             NaN
# min             NaN            NaN             NaN
# 25%             NaN            NaN             NaN
# 50%             NaN            NaN             NaN
# 75%             NaN            NaN             NaN
# max             NaN            NaN             NaN
#
#                                          ingredients_tags  \
# count                                              255537
# unique                                             194509
# top     en:superior-quality-durum-wheat-semolina,en:ce...
# freq                                                  784
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       ingredients_analysis_tags allergens traces_tags  \
# count                                    255537    255537      255537
# unique                                       38        19          33
# top     en:palm-oil-free,en:vegan,en:vegetarian   en:none     en:none
# freq                                      45120    156416      179620
# mean                                        NaN       NaN         NaN
# std                                         NaN       NaN         NaN
# min                                         NaN       NaN         NaN
# 25%                                         NaN       NaN         NaN
# 50%                                         NaN       NaN         NaN
# 75%                                         NaN       NaN         NaN
# max                                         NaN       NaN         NaN
#
#        additives_tags nutriscore_grade food_groups_tags  \
# count          255537           255537           255537
# unique          32825                7               46
# top           en:none          unknown          en:none
# freq           124985            54476            56622
# mean              NaN              NaN              NaN
# std               NaN              NaN              NaN
# min               NaN              NaN              NaN
# 25%               NaN              NaN              NaN
# 50%               NaN              NaN              NaN
# 75%               NaN              NaN              NaN
# max               NaN              NaN              NaN
#
#                                               states_tags ecoscore_grade  \
# count                                              255537         255537
# unique                                               1653              9
# top     en:to-be-completed,en:nutrition-facts-complete...        unknown
# freq                                                20867          92392
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#        nutrient_levels_tags popularity_tags main_category image_url  \
# count                255537          255537        255537    255537
# unique                  224           85393         16911    237020
# top              en:unknown         unknown       en:none   en:none
# freq                  62937           72025         34985     17773
# mean                    NaN             NaN           NaN       NaN
# std                     NaN             NaN           NaN       NaN
# min                     NaN             NaN           NaN       NaN
# 25%                     NaN             NaN           NaN       NaN
# 50%                     NaN             NaN           NaN       NaN
# 75%                     NaN             NaN           NaN       NaN
# max                     NaN             NaN           NaN       NaN
#
#          energy_100g       fat_100g  saturated-fat_100g  cholesterol_100g  \
# count   2.555370e+05  255537.000000       255537.000000     255537.000000
# unique           NaN            NaN                 NaN               NaN
# top              NaN            NaN                 NaN               NaN
# freq             NaN            NaN                 NaN               NaN
# mean    2.328430e+11      12.047864            4.571277         -0.997241
# std     1.177037e+14      16.715739            7.752517          0.091233
# min    -1.000000e+00      -1.000000           -1.000000         -1.000000
# 25%     2.930000e+02       0.500000            0.100000         -1.000000
# 50%     9.080000e+02       5.100000            1.300000         -1.000000
# 75%     1.570000e+03      19.000000            6.000000         -1.000000
# max     5.950000e+16     231.000000          163.000000         24.000000
#
#           sugars_100g  proteins_100g      salt_100g  \
# count   255537.000000  255537.000000  255537.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean        12.075284       7.374202       0.896229
# std         19.215145       9.121442       6.788525
# min         -1.000000      -1.000000      -1.000000
# 25%          0.500000       0.600000       0.010000
# 50%          2.700000       5.200000       0.275000
# 75%         15.000000      10.770000       1.100000
# max        725.000000     579.000000    2500.000000
#
#         fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# count                                       255537.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            19.172789
# std                                             48.506079
# min                                            -65.887256
# 25%                                              0.000000
# 50%                                              0.056676
# 75%                                             22.833333
# max                                          13461.000000
#
#         last_modified_year
# count        255537.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean           2022.430744
# std               1.454487
# min            2013.000000
# 25%            2022.000000
# 50%            2023.000000
# 75%            2023.000000
# max            2024.000000

# %%
clean_data.to_csv("clean_dataset.csv")

# %% [markdown]
# ### Text processing

# %%
clean_data = pd.read_csv("clean_dataset.csv", index_col=[0])
# Out:
# /tmp/ipykernel_53904/1235446198.py:1: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
clean_data.head()
# Out:
#    code                                                url  \
# 4     5  http://world-en.openfoodfacts.org/product/0000...
# 9    10  http://world-en.openfoodfacts.org/product/0000...
# 14   15  http://world-en.openfoodfacts.org/product/0000...
# 18   20  http://world-en.openfoodfacts.org/product/0000...
# 20   22  http://world-en.openfoodfacts.org/product/0000...
#
#               product_name                                     packaging_tags  \
# 4               Bio inulin                                           en:glass
# 9        Madeleines nature  en:plastic,en:cardboard,fr:boite-en-carton,fr:...
# 14    Madeleines ChocoLait                            en:plastic,en:cardboard
# 18   Madeleines Choco Noir  fr:1-boite-en-carton-a-recycler-50-sachets-ind...
# 20  Farandole de madeleine            fr:boite-en-carton,fr:film-en-plastique
#
#                                       categories_tags  \
# 4   en:plant-based-foods-and-beverages,en:plant-ba...
# 9   en:snacks,en:desserts,en:sweet-snacks,en:biscu...
# 14  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
#
#                                      ingredients_tags  \
# 4   en:apricot-juice-and-puree,en:fruit,en:prunus-...
# 9   en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 14  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 20  fr:madeleines-choconoir,fr:madeleines-nappees-...
#
#                             ingredients_analysis_tags allergens  \
# 4             en:palm-oil-free,en:vegan,en:vegetarian   en:none
# 9   en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 14  en:palm-oil-free,en:non-vegan,en:maybe-vegetarian   en:none
# 18  en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 20  en:palm-oil-content-unknown,en:non-vegan,en:ve...   en:none
#
#             traces_tags                                    additives_tags  \
# 4               en:none                                           en:none
# 9   en:nuts,en:soybeans                           en:e331,en:e422,en:e503
# 14              en:nuts  en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
# 18              en:nuts           en:e322,en:e331,en:e422,en:e500,en:e503
# 20              en:nuts  en:e322,en:e322i,en:e331,en:e422,en:e500,en:e503
#
#    nutriscore_grade                        food_groups_tags  \
# 4                 a  en:fruits-and-vegetables,en:vegetables
# 9                 d  en:sugary-snacks,en:biscuits-and-cakes
# 14                d  en:sugary-snacks,en:biscuits-and-cakes
# 18                d  en:sugary-snacks,en:biscuits-and-cakes
# 20          unknown  en:sugary-snacks,en:biscuits-and-cakes
#
#                                           states_tags ecoscore_grade  \
# 4   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 9   en:to-be-completed,en:nutrition-facts-complete...              c
# 14  en:to-be-completed,en:nutrition-facts-complete...              d
# 18  en:to-be-checked,en:complete,en:nutrition-fact...              d
# 20  en:to-be-completed,en:nutrition-facts-complete...              d
#
#                                  nutrient_levels_tags  \
# 4   en:fat-in-low-quantity,en:saturated-fat-in-low...
# 9   en:fat-in-high-quantity,en:saturated-fat-in-mo...
# 14  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 18  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 20                                         en:unknown
#
#                                       popularity_tags  \
# 4                                             unknown
# 9   top-50000-scans-2019,top-100000-scans-2019,at-...
# 14  top-50000-scans-2019,top-100000-scans-2019,at-...
# 18  top-50000-scans-2019,top-100000-scans-2019,at-...
# 20  top-75-percent-scans-2020,top-80-percent-scans...
#
#               main_category  \
# 4             en:vegetables
# 9       en:plain-madeleines
# 14  en:chocolate-madeleines
# 18  en:chocolate-madeleines
# 20       en:long-madeleines
#
#                                             image_url  energy_100g  fat_100g  \
# 4   https://images.openfoodfacts.org/images/produc...        840.0       0.0
# 9   https://images.openfoodfacts.org/images/produc...       1852.0      22.0
# 14  https://images.openfoodfacts.org/images/produc...       1926.0      24.0
# 18  https://images.openfoodfacts.org/images/produc...       1953.0      25.0
# 20  https://images.openfoodfacts.org/images/produc...         -1.0      -1.0
#
#     saturated-fat_100g  cholesterol_100g  sugars_100g  proteins_100g  \
# 4                  0.0              -1.0          8.0            0.0
# 9                  2.6              -1.0         25.0            6.4
# 14                 6.0              -1.0         31.0            6.4
# 18                 6.1              -1.0         29.0            6.3
# 20                -1.0              -1.0         -1.0           -1.0
#
#     salt_100g  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 4        0.23                                          50.000000
# 9        0.53                                          22.666667
# 14       0.48                                          16.250000
# 18       0.45                                          16.250000
# 20      -1.00                                           1.750000
#
#     last_modified_year
# 4                 2024
# 9                 2024
# 14                2024
# 18                2024
# 20                2024

# %%
nlp = en_core_web_sm.load()

text_processing = TextProcessing()

def clean_text_column(text):
    # Suppression des préfixes de langue
    text = re.sub(r'\b\w{2}:\b', ' ', text)  # \b délimite le mot et \w{2} correspond à deux lettres
    # Remplacement des tirets par des espaces
    text = text.replace('-', ' ')
    # Suppression des espaces multiples
    text = re.sub(r'\s+', ' ', text).strip()
    return text

fill_values = {
        'packaging_tags': 'en:unknown',
        'categories_tags': 'en:unknown',
        'ingredients_analysis_tags': 'unknown',
        'allergens': 'en:none',
        'traces_tags': 'en:none',
        'additives_tags': 'en:none',
        'nutriscore_grade': 'unknown',
        'food_groups_tags': 'en:none',
        'states_tags': 'en:unknown',
        'ecoscore_grade': 'unknown',
        'nutrient_levels_tags': 'en:unknown',
        'popularity_tags': 'unknown',
        'main_category': 'en:none',
        'image_url': 'en:none',
        'energy_100g': -1,
        'fat_100g': -1,
        'saturated-fat_100g': -1,
        'cholesterol_100g': -1,
        'sugars_100g': -1,
        'proteins_100g': -1,
        'salt_100g': -1,
        'fruits-vegetables-nuts-estimate-from-ingredients_100g': -1
    }

# Liste des colonnes à traiter
columns_cat = ['product_name', 'packaging_tags', 'categories_tags', 'ingredients_tags', 'ingredients_analysis_tags', 
           'nutrient_levels_tags', 'nutriscore_grade', 'main_category', 'ecoscore_grade', 'popularity_tags']

# Liste pour stocker les noms des nouvelles colonnes créées
new_columns_cat_names = []

# Boucle pour appliquer les transformations et stocker les noms des nouvelles colonnes
for col in columns_cat:
    # Nom des nouvelles colonnes pour chaque transformation
    preprocessed_col = f'preprocessed_{col}'
    # lemmatized_col = f'preprocessed_{col}_lemmatized'
    # len_col = f'len_{preprocessed_col}'
    
    # Appliquer le nettoyage
    clean_data[preprocessed_col] = clean_data[col].fillna('').apply(clean_text_column)
    
    # Appliquer la standardisation
    clean_data[preprocessed_col] = clean_data[preprocessed_col].apply(text_processing.standardize)

    # Calculer la longueur des mots dans la colonne lemmatisée
    # clean_data[len_col] = clean_data[preprocessed_col].apply(lambda x: len(x))
    
    # Appliquer la lemmatisation
    # clean_data[lemmatized_col] = clean_data[preprocessed_col].apply(lambda x: text_processing.lemmatize(x, nlp))
    
    # Calculer la longueur des mots dans la colonne lemmatisée
    # clean_data[len_col] = clean_data[lemmatized_col].apply(lambda x: len(x))
    
    # Ajouter les nouveaux noms de colonnes dans la liste
    # new_columns_cat_names.extend([preprocessed_col, lemmatized_col, len_col])
    new_columns_cat_names.extend([preprocessed_col])

# Affichage des noms des nouvelles colonnes créées
print("Noms des nouvelles colonnes créées :")
print(new_columns_cat_names)
# Affichage des premières lignes des nouvelles colonnes
clean_data[new_columns_cat_names].head()
# Out:
# Noms des nouvelles colonnes créées :
# ['preprocessed_product_name', 'preprocessed_packaging_tags', 'preprocessed_categories_tags', 'preprocessed_ingredients_tags', 'preprocessed_ingredients_analysis_tags', 'preprocessed_nutrient_levels_tags', 'preprocessed_nutriscore_grade', 'preprocessed_main_category', 'preprocessed_ecoscore_grade', 'preprocessed_popularity_tags']
#    preprocessed_product_name  \
# 4                 bio inulin
# 9          madeleines nature
# 14      madeleines chocolait
# 18     madeleines choco noir
# 20    farandole de madeleine
#
#                           preprocessed_packaging_tags  \
# 4                                               glass
# 9   plastic cardboard boite en carton film en plas...
# 14                                  plastic cardboard
# 18  1 boite en carton a recycler 50 sachets indivi...
# 20                  boite en carton film en plastique
#
#                          preprocessed_categories_tags  \
# 4   plant based foods and beverages plant based fo...
# 9   snacks desserts sweet snacks biscuits and cake...
# 14  snacks sweet snacks biscuits and cakes cakes c...
# 18  snacks sweet snacks biscuits and cakes cakes c...
# 20  snacks sweet snacks biscuits and cakes cakes c...
#
#                         preprocessed_ingredients_tags  \
# 4   apricot juice and puree fruit prunus species f...
# 9   wheat flour cereal flour wheat cereal flour su...
# 14  wheat flour cereal flour wheat cereal flour mi...
# 18  wheat flour cereal flour wheat cereal flour da...
# 20  madeleines choconoir madeleines nappees de cho...
#
#                preprocessed_ingredients_analysis_tags  \
# 4                      palm oil free vegan vegetarian
# 9   palm oil free non vegan vegetarian status unknown
# 14           palm oil free non vegan maybe vegetarian
# 18  palm oil free non vegan vegetarian status unknown
# 20  palm oil content unknown non vegan vegetarian ...
#
#                     preprocessed_nutrient_levels_tags  \
# 4   fat in low quantity saturated fat in low quant...
# 9   fat in high quantity saturated fat in moderate...
# 14  fat in high quantity saturated fat in high qua...
# 18  fat in high quantity saturated fat in high qua...
# 20                                            unknown
#
#    preprocessed_nutriscore_grade preprocessed_main_category  \
# 4                              a                 vegetables
# 9                              d           plain madeleines
# 14                             d       chocolate madeleines
# 18                             d       chocolate madeleines
# 20                       unknown            long madeleines
#
#    preprocessed_ecoscore_grade  \
# 4                      unknown
# 9                            c
# 14                           d
# 18                           d
# 20                           d
#
#                          preprocessed_popularity_tags
# 4                                             unknown
# 9   top 50000 scans 2019top 100000 scans 2019at le...
# 14  top 50000 scans 2019top 100000 scans 2019at le...
# 18  top 50000 scans 2019top 100000 scans 2019at le...
# 20  top 75 percent scans 2020top 80 percent scans ...

# %%
clean_data.to_csv('clean_dataset_preprocess.csv')

# %%
clean_data = pd.read_csv("clean_dataset_preprocess.csv")
# Out:
# /tmp/ipykernel_53904/4137305628.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   clean_data = pd.read_csv("clean_dataset_preprocess.csv")

# %% [markdown]
# ## Training
#
# Essai avec un entrainement d'un modèle simple Kmeans.
#
# Rappel :
#
# **1. CountVectorizer**
#
# - **Principe :** Compte le nombre d’occurrences de chaque mot dans un texte ou une liste de tags.
# - **Utilisation :** Représente chaque mot par une colonne dans une matrice, avec une valeur représentant sa fréquence.
# - **Avantage :** Simple et rapide à calculer, utile pour des listes ou textes courts où la présence des mots est suffisante.
# - **Limite :** Ne capture pas les relations sémantiques (ex. "sucre" ≠ "glucose").
#
# **2. TF-IDF Vectorizer**
#
# - **Principe :** Calcule la fréquence des mots ajustée par leur rareté dans l’ensemble des documents.
# - **Utilisation :** Les mots fréquents dans peu de documents reçoivent une valeur plus élevée, permettant de distinguer des termes spécifiques.
# - **Avantage :** Diminue l’importance des mots très fréquents (ex. "de", "le") et met en avant les mots distinctifs.
# - **Limite :** Ne capture pas la similarité sémantique entre les mots.
#
# **3. Word Embeddings (Word2Vec, GloVe)**
#
# - **Principe :** Apprend à représenter chaque mot dans un espace vectoriel de manière à ce que des mots contextuellement proches soient également proches dans l’espace vectoriel.
# - **Utilisation :** Représente chaque mot par un vecteur de plusieurs dimensions, capturant des relations sémantiques (ex. "roi" proche de "reine").
# - **Avantage :** Capture les similarités et relations entre mots, utile pour les tâches nécessitant une compréhension sémantique.
# - **Limite :** Ne prend pas en compte le contexte spécifique d'une phrase.
#
# **4. FastText**
#
# - **Principe :** Apprend également des embeddings mais utilise des sous-mots (n-grammes de caractères), ce qui permet de mieux comprendre les mots avec des similitudes orthographiques.
# - **Exemple :** FastText repère des similarités entre "glucose" et "sucre" en utilisant des sous-parties communes dans les mots. Si des variantes de mots sont dans le dataset (ex. "sucreries", "sucre"), FastText peut capturer ces relations plus finement.
# - **Avantage :** Idéal pour des données contenant des variantes ou des erreurs typographiques, tout en offrant des similarités proches de Word2Vec et BERT pour les termes proches.
# - **Limite :** FastText est limité par son incapacité à capter le contexte global, la syntaxe et la structure grammaticale, ce qui le rend moins performant pour comprendre le sens des mots dans des phrases complexes ou ambiguës
#
# **5. BERT (Contextual Embeddings)**
#
# - **Principe :** Génère des représentations contextuelles pour chaque mot dans une phrase, tenant compte du contexte global.
# - **Utilisation :** Représente chaque mot différemment selon le contexte de la phrase (ex. "batterie" dans "batterie de cuisine" vs. "batterie de voiture").
# - **Avantage :** Idéal pour les phrases et textes complexes nécessitant une compréhension fine du contexte.
# - **Limite :** Modèle très coûteux en calcul, moins utile pour des listes simples de mots isolés.
#
# ---
#
# **En résumé :**
#
# CountVectorizer et TF-IDF sont légers et efficaces pour des listes de tags ou des mots courts.
#
# Word Embeddings ajoutent la dimension sémantique.
#
# BERT excelle dans des phrases contextuelles, mais est plus lourd et parfois excessif pour des mots isolés.

# %%
numeric_columns = [
    'energy_100g', 'fat_100g', 'saturated-fat_100g', 'cholesterol_100g', 
    'sugars_100g', 'proteins_100g', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'
]
categorial_columns = [
    'preprocessed_product_name', 'preprocessed_packaging_tags', 'preprocessed_categories_tags', 
    'preprocessed_ingredients_tags', 'preprocessed_ingredients_analysis_tags', 'preprocessed_main_category'
]

# %%
# Colonnes numériques et catégorielles
from sklearn.decomposition import PCA


numeric_columns = [
    'energy_100g', 'fat_100g', 'saturated-fat_100g', 'cholesterol_100g', 
    'sugars_100g', 'proteins_100g', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'
]
categorial_columns = [
    'preprocessed_product_name', 'preprocessed_packaging_tags', 'preprocessed_categories_tags', 
    'preprocessed_ingredients_tags', 'preprocessed_ingredients_analysis_tags', 'preprocessed_main_category'
]

# Fonction d'imputation pour les valeurs numériques
def impute_numeric_data(df, columns):
    imputer = SimpleImputer(strategy='mean')
    df[columns] = imputer.fit_transform(df[columns])
    return df

# Fonction de normalisation des colonnes numériques
def scale_numeric_data(df, columns):
    scaler = StandardScaler()
    df[columns] = scaler.fit_transform(df[columns])
    return df

# Fonction de transformation de texte pour les colonnes catégorielles
def encode_categorical_data_with_svd(df, columns, max_features=500, min_df=4, n_components=50):
    print('encode_categorical_data_with_svd')
    vectorizer = CountVectorizer(max_features=max_features, min_df=min_df)
    encoded_columns = []
    
    for col in columns:
        print('column', col)
        # Encodage du texte
        encoded = vectorizer.fit_transform(df[col].fillna(''))
        print('encoded.shape', encoded.shape[1])
        
        # Ajustement de n_components pour TruncatedSVD si nécessaire
        adjusted_n_components = min(n_components, encoded.shape[1])
        print('adjusted_n_components:', adjusted_n_components)
        # Réduction de dimensions avec TruncatedSVD plus optimisé avec les sparses matrices que PCA
        svd = TruncatedSVD(n_components=adjusted_n_components, random_state=42)
        
        # Réduction de dimensions
        reduced = svd.fit_transform(encoded)
        encoded_columns.append(pd.DataFrame(reduced))
    
    vectorizer_nb_features = vectorizer.get_feature_names_out()
    print("[INFO][CountVectorizer] : Nombre de features dans le vocabulaire : ", len(vectorizer_nb_features))
    return pd.concat(encoded_columns, axis=1)

# Fonction de transformation de texte pour les colonnes catégorielles avec PCA
def encode_categorical_data_with_pca(df, columns, max_features=500, min_df=4, n_components=50):
    print('encode_categorical_data_with_pca')
    vectorizer = CountVectorizer(max_features=max_features, min_df=min_df)
    encoded_columns = []
    
    for col in columns:
        print('column', col)
        # Encodage du texte
        encoded = vectorizer.fit_transform(df[col].fillna(''))
        print('encoded.shape', encoded.shape[1])
        
        # Conversion en matrice dense
        dense_encoded = encoded.toarray()  
        
        # Ajustement de n_components pour PCA si nécessaire
        adjusted_n_components = min(n_components, dense_encoded.shape[1])
        print('adjusted_n_components:', adjusted_n_components)
        
        # Réduction de dimensions avec PCA
        pca = PCA(n_components=adjusted_n_components, random_state=42)
        
        # Réduction de dimensions
        reduced = pca.fit_transform(dense_encoded)
        encoded_columns.append(pd.DataFrame(reduced))
    
    vectorizer_nb_features = vectorizer.get_feature_names_out()
    print("[INFO][CountVectorizer] : Nombre de features dans le vocabulaire : ", len(vectorizer_nb_features))
    return pd.concat(encoded_columns, axis=1)


# Fonction de clustering et calcul des scores
def cluster_data(features, cluster_range, random_state=42):
    silhouette_scores = []
    inertia = []
    
    for k in cluster_range:
        kmeans = KMeans(n_clusters=k, random_state=random_state)
        labels = kmeans.fit_predict(features)
        inertia.append(kmeans.inertia_)
        silhouette_scores.append(silhouette_score(features, labels))
    
    return labels, silhouette_scores, inertia

# Fonction principale de préparation des données et de clustering
def find_optimal_clusters(df, cluster_range, encoding_method=encode_categorical_data_with_svd, random_state=42):
    # Imputation des valeurs numériques
    df = impute_numeric_data(df, numeric_columns)
    
    # Encodage des données catégorielles
    categorical_features = encoding_method(df, categorial_columns)
    
    # Normalisation des données numériques
    df = scale_numeric_data(df, numeric_columns)
    
    # Assemblage des features
    features = pd.concat([categorical_features, df[numeric_columns].reset_index(drop=True)], axis=1)
    features.columns = features.columns.astype(str)
    
    # Clustering et calcul des scores
    labels, silhouette_scores, inertia = cluster_data(features, cluster_range=cluster_range, random_state=random_state)
    
    # Ajout des labels de clusters au DataFrame
    df['cluster'] = labels
    return labels, silhouette_scores, inertia

def train_kmeans_with_manual_clusters(df, n_clusters, encoding_method=encode_categorical_data_with_svd, random_state=42):
    """
    Applique un KMeans avec un nombre de clusters spécifié manuellement.
    
    Parameters:
        df (DataFrame): Le DataFrame contenant les données sur lesquelles appliquer le KMeans.
        n_clusters (int): Le nombre de clusters à utiliser.
        random_state (int): L'état aléatoire pour assurer la reproductibilité.
    
    Returns:
        DataFrame: Le DataFrame avec les labels de clusters ajoutés.
    """
    # Imputation des valeurs numériques
    df = impute_numeric_data(df, numeric_columns)
    
    # Encodage des données catégorielles
    categorical_features = encoding_method(df, categorial_columns)
    
    # Normalisation des données numériques
    df = scale_numeric_data(df, numeric_columns)
    
    # Assemblage des features
    features = pd.concat([categorical_features, df[numeric_columns].reset_index(drop=True)], axis=1)
    features.columns = features.columns.astype(str)
    
    # Apprentissage du modèle KMeans avec le nombre de clusters spécifié
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
    df['cluster'] = kmeans.fit_predict(features)
    
    return df


def inertia_elbow_plotly(cluster_range, inertia, silhouette_scores):
    data = pd.DataFrame({
        'Number of clusters': cluster_range,
        'Inertia': inertia,
        'Silhouette Score': silhouette_scores
    })
    
    # Graphique Elbow (Inertia)
    fig_inertia = px.line(
        data,
        x='Number of clusters',
        y='Inertia',
        markers=True,
        title="Elbow Method"
    )
    fig_inertia.update_layout(
        xaxis_title="Number of clusters",
        yaxis_title="Inertia"
    )
    
    # Graphique Silhouette
    fig_silhouette = px.line(
        data,
        x='Number of clusters',
        y='Silhouette Score',
        markers=True,
        title="Silhouette Score"
    )
    fig_silhouette.update_layout(
        xaxis_title="Number of clusters",
        yaxis_title="Silhouette Score"
    )
    
    fig_inertia.show()
    fig_silhouette.show()


cluster_range=range(50, 1000, 25)

labels_svd, silhouette_scores_svd, inertia_svd = find_optimal_clusters(df=clean_data.sample(20000), 
                                                                             cluster_range=cluster_range,
                                                                             encoding_method=encode_categorical_data_with_svd)

# Utilisation de la nouvelle fonction dans l'entraînement KMeans
labels_pca, silhouette_scores_pca, inertia_pca = find_optimal_clusters(df=clean_data.sample(20000), 
                                                                             cluster_range=cluster_range,
                                                                             encoding_method=encode_categorical_data_with_pca)
# Out:
# encode_categorical_data_with_svd
# column preprocessed_product_name
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_packaging_tags
# encoded.shape 259
# adjusted_n_components: 50
# column preprocessed_categories_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_nutriscore_grade
# encoded.shape 3
# adjusted_n_components: 3
# column preprocessed_main_category
# encoded.shape 500
# adjusted_n_components: 50
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  500
# encode_categorical_data_with_pca
# column preprocessed_product_name
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_packaging_tags
# encoded.shape 247
# adjusted_n_components: 50
# column preprocessed_categories_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_nutriscore_grade
# encoded.shape 3
# adjusted_n_components: 3
# column preprocessed_main_category
# encoded.shape 500
# adjusted_n_components: 50
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  500

# %%
# Affichage des résultats TruncatedSVD
print(labels_svd[:5], len(labels_svd))
print("Silhouette Scores:", silhouette_scores_svd)
print("Inertia:", inertia_svd)

inertia_elbow_plotly(cluster_range=cluster_range, inertia=inertia_svd, silhouette_scores=silhouette_scores_svd)
# Out:
# [ 36 519 508 818 220] 20000
# Silhouette Scores: [np.float64(0.09939083560998034), np.float64(0.10791151901882261), np.float64(0.10285522558318978), np.float64(0.09865150220767929), np.float64(0.0945047760330589), np.float64(0.09358997364337923), np.float64(0.09282197299797768), np.float64(0.09480502884663529), np.float64(0.09179985269001556), np.float64(0.09281017870148178), np.float64(0.0921787201702414), np.float64(0.09326236763380559), np.float64(0.09365693722387083), np.float64(0.09024837610305544), np.float64(0.09265189133603254), np.float64(0.0963042334358597), np.float64(0.09534747137161344), np.float64(0.09505393775166855), np.float64(0.09544865350231196), np.float64(0.09667639196275117), np.float64(0.09756513331548881), np.float64(0.09716581271444724), np.float64(0.09569976581876363), np.float64(0.09561877783213192), np.float64(0.09544579408283142), np.float64(0.09612958221038273), np.float64(0.09696124631192878), np.float64(0.09663225529629167), np.float64(0.0971416327676246), np.float64(0.09769311629307248), np.float64(0.09718859917658448), np.float64(0.09644256347367207), np.float64(0.09659046750135632), np.float64(0.0972023107326906), np.float64(0.09708382306823173), np.float64(0.09479702389937214), np.float64(0.09441597810060232), np.float64(0.09498747077825032)]
# Inertia: [768804.8944315055, 692221.3313756486, 648883.8052571353, 619664.4352911131, 600570.4367163426, 580173.1367024058, 564726.4794121038, 548470.9569809656, 536149.3741885663, 524975.4450400107, 514445.27622400224, 505153.585619333, 495173.26584949595, 488341.9004140119, 479943.961553172, 474846.6319097511, 469103.7784345712, 464491.9335531109, 457703.87093088974, 451912.90996782266, 446956.58370208606, 442974.1757282243, 437925.37672025146, 434680.4323952968, 430541.2015609606, 425706.4906308898, 421311.2441417156, 417819.4290744, 414239.69344739063, 410709.7037982477, 407802.69893979235, 404185.69888804737, 400631.49944542523, 397465.55112032284, 394220.42608302255, 391059.5397330199, 388578.0554248746, 385504.96231743414]

# %%
# Affichage des résultats PCA
print(labels_pca[:5], len(labels_pca))
print("Silhouette Scores:", silhouette_scores_pca)
print("Inertia:", inertia_pca)

inertia_elbow_plotly(cluster_range=cluster_range, inertia=inertia_pca, silhouette_scores=silhouette_scores_pca)
# Out:
# [183 852 506 297 200] 20000
# Silhouette Scores: [np.float64(0.10628296806444025), np.float64(0.10709067001932822), np.float64(0.0988024586685435), np.float64(0.09329540865848329), np.float64(0.09538192929426673), np.float64(0.0960933774490979), np.float64(0.09572692059874956), np.float64(0.09463767083717557), np.float64(0.09530603137991267), np.float64(0.09440436147659313), np.float64(0.09347909661050134), np.float64(0.09614070610019478), np.float64(0.09476500443480665), np.float64(0.0960528107514509), np.float64(0.09281357738007567), np.float64(0.09543486923578043), np.float64(0.0950641447995405), np.float64(0.09521181382460081), np.float64(0.0920361482670171), np.float64(0.09183376521367025), np.float64(0.09265674918804273), np.float64(0.09297533675398958), np.float64(0.09382960684741418), np.float64(0.09393779482375436), np.float64(0.09386184581293171), np.float64(0.09275338936650335), np.float64(0.09315318431963973), np.float64(0.09366290896434919), np.float64(0.09394758061080015), np.float64(0.09267375502777173), np.float64(0.09186369049606732), np.float64(0.09296240779289074), np.float64(0.09198415151852118), np.float64(0.09266914152686531), np.float64(0.09236896121625598), np.float64(0.09199863246595644), np.float64(0.09235434148795894), np.float64(0.09308861925189484)]
# Inertia: [762340.5619855791, 699368.7205690381, 658802.4790072645, 632124.4198827785, 607616.5401845202, 585584.4417703903, 570278.5967668511, 555471.1702834743, 542038.2200006671, 530587.4262321192, 519489.88248006476, 510084.436593396, 501969.92811686394, 492934.8993778217, 486710.520926194, 479433.12342571194, 473125.1280035567, 467507.9952549736, 462518.45477817825, 457054.0518303547, 451979.2432102044, 447677.6152223801, 442936.7370580507, 438125.2433242971, 434455.11960351845, 431387.68605345045, 427550.7546959889, 423260.54309304606, 419622.15010287624, 416786.09145306377, 413358.7835676088, 409679.52933548094, 406890.14614314074, 403409.38038260874, 400317.6966604998, 397044.5422643017, 394294.0147941088, 391280.32514315826]

# %%
# Appliquer KMeans avec le meilleur nombre de clusters
df_result_svd = train_kmeans_with_manual_clusters(df=clean_data, n_clusters=525, encoding_method=encode_categorical_data_with_svd)
# Out:
# encode_categorical_data_with_svd
# column preprocessed_product_name
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_packaging_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_categories_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_nutriscore_grade
# encoded.shape 3
# adjusted_n_components: 3
# column preprocessed_main_category
# encoded.shape 500
# adjusted_n_components: 50
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  500

# %%
df_result_pca = train_kmeans_with_manual_clusters(df=clean_data, n_clusters=525, encoding_method=encode_categorical_data_with_pca)
# Out:
# encode_categorical_data_with_pca
# column preprocessed_product_name
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_packaging_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_categories_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_tags
# encoded.shape 500
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_nutriscore_grade
# encoded.shape 3
# adjusted_n_components: 3
# column preprocessed_main_category
# encoded.shape 500
# adjusted_n_components: 50
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  500

# %%
df_result_svd.shape
# Out:
# (255537, 49)

# %%
sample_df = df_result_svd.sample(1000)
sample_df.to_csv("sample_svd.csv")

# %%
cluster_count_df =df_result_svd["cluster"].value_counts().reset_index()
cluster_count_df
# Out:
#      cluster  count
# 0         61   4132
# 1          7   2908
# 2        213   1979
# 3        452   1881
# 4         65   1780
# ..       ...    ...
# 520       19      1
# 521      367      1
# 522      140      1
# 523       66      1
# 524      486      1
#
# [525 rows x 2 columns]

# %%
cluster_count_df[cluster_count_df["count"] > 10].reset_index(drop=True)
# Out:
#      cluster  count
# 0         61   4132
# 1          7   2908
# 2        213   1979
# 3        452   1881
# 4         65   1780
# ..       ...    ...
# 511      136     82
# 512      341     56
# 513      401     44
# 514      419     42
# 515      286     23
#
# [516 rows x 2 columns]

# %%
df_result_svd["cluster"].value_counts()


df_result_svd[["product_name"]][df_result_svd["cluster"] == 25].head(20)
# Out:
#                                               product_name
# 299271                      Thon Pale (a L'huile Végétale)
# 589167                          Sardines à la sauce tomate
# 721641                           sardines a la camarguaise
# 790045   Les Sardines à l'huile de tournesol et olives ...
# 985658            sardines entières à l'huile de tournesol
# 995133                                  Sardines à l'Huile
# 997085        Filets de Maquereaux à l'Huile d'Olive (32%)
# 1013202                 Thon entier a l'huile de tournesol
# 1014414                        Miettes de thon à la tomate
# 1016520                 Filets d'anchois à l'huile d'olive
# 1025773                           Filets d'anchois marinés
# 1032047                             Rinderburger Mit Gouda
# 1037424              Thon albacore fumé, à l’huile de soja
# 1038334                   Filets de Thon à L Huile D Olive
# 1039607                     Sardine a l'huile de tournesol
# 1045406                                 Thon huile d'olive
# 1049648                    Thon albacore à l'huile d’olive
# 1211634                        Thon à L'huile De Tournesol
# 1211638  Sardines à l'huile de Tournesol (Lot de 2 boîtes)
# 1211640  Filets de Hareng Fumés à l'Huile de Colza Les ...

# %%
df_result_pca["cluster"].value_counts()


df_result_pca[["product_name"]][df_result_pca["cluster"] == 100].head(20)
# Out:
#                                             product_name
# 1015                   pâte à tartiner noisette et cacao
# 3141                  Pâte à tartiner noisettes et cacao
# 3325                            Pâte à tartiner noisette
# 3411                                     Pate a tartiner
# 7422                     Pâte à tartiner Noisettes Cacao
# 8147                                 pâte à tartiner bio
# 8412                   Pâte à tartiner noisette et cacao
# 8442   Pâte à tartiner 40% de noisette d'Aquitaine et...
# 8521     Gran cremeria au lait avec noisettes italiennes
# 8773                                            Noisette
# 10308                                           Noisella
# 11385                           pâte à tartiner noisette
# 11471     Pâte à tartiner chocolat noisette - Jardin bio
# 14167    Pâte à tartiner aux noisettes du Lot et Garonne
# 14181                             Chokladkrokant Bredbar
# 14414                  Pâte à tartiner Chocolat Noisette
# 15804                  Proteinella Chocolat et Noisettes
# 16842                                    Pâte à tartiner
# 16993                      Pâte a tartiner aux noisettes
# 17592                                         Nut'Alsace

# %%
df_result_svd[["product_name"]][df_result_svd["cluster"] == 20].head(20)
# Out:
#                                             product_name
# 1614                          FREEFROM Haddock Fishcakes
# 2694             Cadbury Fingers Biscuits Milk Chocolate
# 2697                       Cadbury Mellos Caramel 6 / 16
# 2706                               Cadbury Snowy Fingers
# 3358                        Italian Chocolate Collection
# 5213                                      Boules Praliné
# 6805                                  Eclair au chocolat
# 8763                                      DeliChoc sablé
# 8805                                      Mélange yogurt
# 9075   figurine creuse au chocolat au lait avec céréa...
# 9215                  Minuet Duplex Biscuit Vanilla 16CT
# 10954                                     32% whey-wafer
# 11010                                    Choco magnesium
# 14173                   Mon goûter fondant à la noisette
# 14550              Mascotte - parfum chocolat -noisettes
# 16474                             Sweet and sour chicken
# 16694                                   BrowniesBrownies
# 17489                                         Cafe Latte
# 17506  Rübezahl Schokoladen GMBH Choco Star Rice Voll...
# 18390          Biscuits céréales aux pepites de chocolat

# %%
df_result_svd[["product_name"]][df_result_svd["cluster"] == 169].head(20)
# Out:
#                                             product_name
# 8690                                    Poêlée asiatique
# 14025                             printanière de légumes
# 14628  Mélange Persil/Ail coupé surgelé prêt à l'empl...
# 19667                                     Légumes Vapeur
# 21026                                Légumes Pour Potage
# 21027                              Légumes pour couscous
# 27329                  Ail coupé surgelé prêt à l'emploi
# 31853               Légumes Pour Ratatouille 1kg Surgelé
# 31854                                    Printaniere 1kg
# 31856                         Legumes pour soupe dy 1 kg
# 41450                 450G Julienne De Legumes Bonduelle
# 41501                                        Printanière
# 41516                             Purée Délice Trio vert
# 41633  Les 3 Légumes Précuit Vapeur haricots verts, c...
# 41681  Légumes pour potage potiron potimarron carotte...
# 41721                                Légumes pour Potage
# 41769  Purée délice - haricots verts, courgettes, épi...
# 41801  Mes Astuces Légumes pour Tartes : Courgettes, ...
# 53501  Ce produit n'existe plus - La Julienne de légumes
# 53502                               La poêlée Maraîchère

# %%
df_result_svd[["product_name"]][df_result_svd["cluster"] == 165].head(20)
# Out:
#                                            product_name
# 846                             Chocolate Football Game
# 1089  Godiva Chocolate Blond Chocolate Salted Carame...
# 1093                             Limited Edition Carrés
# 1188                                         Miniatures
# 1476                                     Milk Chocolate
# 1537                    SWISS Chocolate Extra Fine Milk
# 1538                           Swiss Milk Chocolate Bar
# 1540     Swiss chocolate - White chocolate mountain bar
# 1542                        Swiss chocolate neapolitans
# 2771                                   Sucette chocolat
# 2922                                       Golden coins
# 3781                                    Yeux Chocolatés
# 8090                          Chocolat blanc Madagascar
# 8456                               Chocolat lait suisse
# 9135                                      Chocolat lait
# 9141                             Tablette Chocolat Lait
# 9142                                 Tablette Noël Lait
# 9155                                     Poule en Choc'
# 9156                           Chocolat lapin de Paques
# 9348              Assortiment De 48 Carrés De Chocolats

# %% [markdown]
# ### Recommandations

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy

# %%
def find_similar_products(df, product_name, allergen=None, top_n=10, encoding_method=encode_categorical_data_with_svd):
    """
    Recherche des produits similaires dans le même cluster en évitant ceux contenant un allergène spécifique.

    Parameters:
        df (DataFrame): Le DataFrame contenant les données produits.
        product_name (str): Nom du produit de référence.
        allergen (str): Allergène à éviter, si spécifié.
        top_n (int): Nombre de produits similaires à retourner.
        encoding_method (function): La méthode d'encodage des données catégorielles.

    Returns:
        DataFrame: Les produits similaires triés par similarité de cosinus.
    """
    # 1. Identifier le cluster du produit de référence
    product_cluster = df.loc[df['product_name'] == product_name, 'cluster'].values[0]

    # 2. Filtrer les produits du même cluster
    similar_cluster_products = df[df['cluster'] == product_cluster]

    # 3. Si un allergène est spécifié, exclure les produits qui le contiennent
    if allergen:
        similar_cluster_products = similar_cluster_products[
            ~similar_cluster_products['allergens'].fillna('').str.contains(allergen, case=False) &
            ~similar_cluster_products['traces_tags'].fillna('').str.contains(allergen, case=False)
        ]

    # 4. Encoder les colonnes catégorielles
    encoded_categorical_features = encoding_method(similar_cluster_products, categorial_columns)

    # Ajouter la colonne product_name à encoded_categorical_features
    encoded_categorical_features['product_name'] = similar_cluster_products['product_name'].reset_index(drop=True)

    # 5. Extraire les caractéristiques du produit cible
    target_product_row = encoded_categorical_features.loc[encoded_categorical_features['product_name'] == product_name]
    target_product_features = target_product_row.drop(columns=['product_name']).values
    target_numeric_features = similar_cluster_products.loc[similar_cluster_products['product_name'] == product_name, numeric_columns].values

    # 6. Supprimer la ligne du produit cible dans encoded_categorical_features et dans les colonnes numériques
    cluster_features = encoded_categorical_features[encoded_categorical_features['product_name'] != product_name].drop(columns=['product_name'])
    cluster_numeric_features = similar_cluster_products[numeric_columns].drop(index=similar_cluster_products[similar_cluster_products['product_name'] == product_name].index)

    # 7. Combiner les caractéristiques numériques et catégorielles
    target_features = np.hstack([target_numeric_features, target_product_features])
    cluster_features_combined = np.hstack([cluster_numeric_features.values, cluster_features.values])

    # 8. Calcul des similarités de cosinus
    similarities = cosine_similarity(target_features.reshape(1, -1), cluster_features_combined).flatten()

    # 9. Réinitialiser l'index pour aligner la longueur des données
    similar_cluster_products = similar_cluster_products[similar_cluster_products['product_name'] != product_name].reset_index(drop=True)

    # 10. Ajouter la similarité aux produits similaires
    similar_cluster_products = similar_cluster_products.assign(similarity=similarities)

    # 11. Trier et retourner les produits les plus similaires
    return similar_cluster_products.sort_values(by="similarity", ascending=False).head(top_n)

# %%
# Premier produit de cette liste choisi
clean_data[~clean_data["allergens"].isin(["en:none", "other"])].tail(9)
# Out:
#                        code  \
# 3496505       9900000003791
# 3496787            99020118
# 3497101  990530101020733500
# 3497327  990530101057763435
# 3497449  990530101110772053
# 3497561       9909471150003
# 3497605       9911111141111
# 3498100            99515874
# 3498810       9999991042704
#
#                                                        url  \
# 3496505  http://world-en.openfoodfacts.org/product/9900...
# 3496787  http://world-en.openfoodfacts.org/product/9902...
# 3497101  http://world-en.openfoodfacts.org/product/9905...
# 3497327  http://world-en.openfoodfacts.org/product/9905...
# 3497449  http://world-en.openfoodfacts.org/product/9905...
# 3497561  http://world-en.openfoodfacts.org/product/9909...
# 3497605  http://world-en.openfoodfacts.org/product/9911...
# 3498100  http://world-en.openfoodfacts.org/product/9951...
# 3498810  http://world-en.openfoodfacts.org/product/9999...
#
#                                    product_name packaging_tags  \
# 3496505                Choco caraïbes & vanille     en:unknown
# 3496787                                pelardon           fr:4
# 3497101                                    Skyr     en:unknown
# 3497327                   Mini croissant beurre     en:unknown
# 3497449                   Saucisses de volaille     en:unknown
# 3497561  Cornet à la glace fabriquée à la ferme     en:unknown
# 3497605                                 Ketchup     en:unknown
# 3498100                            Mini stollen     en:unknown
# 3498810                          Yaourt vanille     en:unknown
#
#                                            categories_tags  \
# 3496505     en:desserts,en:frozen-foods,en:frozen-desserts
# 3496787  en:dairies,en:fermented-foods,en:fermented-mil...
# 3497101  en:dairies,en:fermented-foods,en:fermented-mil...
# 3497327                                         en:unknown
# 3497449  en:meats-and-their-products,en:prepared-meats,...
# 3497561                                         en:unknown
# 3497605  en:condiments,en:sauces,en:tomato-sauces,en:ke...
# 3498100  en:snacks,en:sweet-snacks,en:festive-foods,en:...
# 3498810  en:dairies,en:fermented-foods,en:fermented-mil...
#
#                                           ingredients_tags  \
# 3496505  en:milk,en:dairy,en:cream,en:sugar,en:added-su...
# 3496787  en:whole-goat-milk,en:dairy,en:milk,en:goat-mi...
# 3497101  fr:lait-pasteurise-a-2-2-de-matiere-grasse,en:...
# 3497327  en:flour,fr:bau,en:yeast,fr:sel-poudre-de-lait...
# 3497449  en:poultry-meat,en:poultry,en:chicken-skin,en:...
# 3497561  fr:cornet,fr:glace-caramel,fr:eclats-de-pralin...
# 3497605  en:tomato,en:vegetable,en:fruit-vegetable,en:o...
# 3498100  en:marzipan,en:wheat-flour,en:cereal,en:flour,...
# 3498810  en:whole-milk,en:dairy,en:milk,en:cream,en:sug...
#
#                                  ingredients_analysis_tags  \
# 3496505  en:may-contain-palm-oil,en:non-vegan,en:vegeta...
# 3496787  en:palm-oil-free,en:non-vegan,en:maybe-vegetarian
# 3497101  en:palm-oil-free,en:vegan-status-unknown,en:ve...
# 3497327  en:palm-oil-content-unknown,en:non-vegan,en:ve...
# 3497449    en:palm-oil-free,en:non-vegan,en:non-vegetarian
# 3497561  en:palm-oil-content-unknown,en:non-vegan,en:ve...
# 3497605  en:palm-oil-free,en:vegan-status-unknown,en:ve...
# 3498100  en:palm-oil,en:non-vegan,en:vegetarian-status-...
# 3498810  en:palm-oil-free,en:non-vegan,en:vegetarian-st...
#
#                                 allergens                     traces_tags  \
# 3496505                       en:soybeans                         en:none
# 3496787                           en:milk                         en:none
# 3497101                           en:milk                         en:none
# 3497327                           en:milk                         en:none
# 3497449                         en:gluten                 en:eggs,en:milk
# 3497561                           en:milk                         en:none
# 3497605  en:sulphur-dioxide-and-sulphites                         en:none
# 3498100                         en:gluten  en:nuts,en:peanuts,en:soybeans
# 3498810                           en:milk       en:eggs,en:gluten,en:nuts
#
#                                             additives_tags nutriscore_grade  \
# 3496505  en:e322,en:e322i,en:e401,en:e407,en:e466,en:e4...          unknown
# 3496787                                            en:none          unknown
# 3497101                                            en:none                a
# 3497327                                            en:e300          unknown
# 3497449                                    en:e262,en:e326                b
# 3497561                                   en:e322,en:e322i          unknown
# 3497605                                            en:none          unknown
# 3498100                                            en:none                e
# 3498810                                            en:none                c
#
#                                       food_groups_tags  \
# 3496505                                        en:none
# 3496787           en:milk-and-dairy-products,en:cheese
# 3497101   en:milk-and-dairy-products,en:dairy-desserts
# 3497327                                        en:none
# 3497449            en:fish-meat-eggs,en:processed-meat
# 3497561                                        en:none
# 3497605     en:fats-and-sauces,en:dressings-and-sauces
# 3498100         en:sugary-snacks,en:biscuits-and-cakes
# 3498810  en:milk-and-dairy-products,en:milk-and-yogurt
#
#                                                states_tags ecoscore_grade  \
# 3496505  en:to-be-completed,en:nutrition-facts-to-be-co...        unknown
# 3496787  en:to-be-completed,en:nutrition-facts-complete...              d
# 3497101  en:to-be-completed,en:nutrition-facts-complete...              b
# 3497327  en:to-be-completed,en:nutrition-facts-complete...        unknown
# 3497449  en:to-be-completed,en:nutrition-facts-complete...              d
# 3497561  en:to-be-completed,en:nutrition-facts-complete...        unknown
# 3497605  en:to-be-completed,en:nutrition-facts-complete...              b
# 3498100  en:to-be-completed,en:nutrition-facts-complete...        unknown
# 3498810  en:to-be-completed,en:nutrition-facts-complete...              b
#
#                                       nutrient_levels_tags  \
# 3496505                                         en:unknown
# 3496787  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 3497101  en:fat-in-low-quantity,en:saturated-fat-in-low...
# 3497327                                         en:unknown
# 3497449  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 3497561                                         en:unknown
# 3497605                                         en:unknown
# 3498100  en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 3498810  en:fat-in-moderate-quantity,en:saturated-fat-i...
#
#                                            popularity_tags  \
# 3496505                                            unknown
# 3496787                                            unknown
# 3497101                                            unknown
# 3497327                                            unknown
# 3497449                                            unknown
# 3497561                                            unknown
# 3497605                                            unknown
# 3498100                                            unknown
# 3498810  bottom-25-percent-scans-2019,bottom-20-percent...
#
#                main_category  \
# 3496505   en:frozen-desserts
# 3496787          fr:pelardon
# 3497101             en:skyrs
# 3497327              en:none
# 3497449  en:poultry-sausages
# 3497561              en:none
# 3497605           en:ketchup
# 3498100           en:stollen
# 3498810    en:vanilla-yogurt
#
#                                                  image_url  energy_100g  \
# 3496505  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3496787  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3497101  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3497327  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3497449  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3497561  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3497605  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3498100  https://images.openfoodfacts.org/images/produc...    -0.001978
# 3498810  https://images.openfoodfacts.org/images/produc...    -0.001978
#
#          fat_100g  saturated-fat_100g  cholesterol_100g  sugars_100g  \
# 3496505 -0.780575           -0.718642         -0.030242    -0.680469
# 3496787  0.715024            1.732179         -0.030242    -0.680469
# 3497101 -0.601103           -0.409065         -0.030242    -0.191271
# 3497327  0.535552            1.216217         -0.030242    -0.164729
# 3497449 -0.002863           -0.163983         -0.030242    -0.591997
# 3497561 -0.242159           -0.331671         -0.030242    -0.212088
# 3497605 -0.780575           -0.718642         -0.030242    -0.680469
# 3498100  0.673147            0.648658         -0.030242     0.958866
# 3498810 -0.266089            0.068200         -0.030242    -0.055960
#
#          proteins_100g  salt_100g  \
# 3496505      -0.918081  -0.279329
# 3496787       1.274560   0.015286
# 3497101       0.178239  -0.117291
# 3497327      -0.676890   0.002029
# 3497449       0.945664   0.015286
# 3497561      -0.589185   1.046440
# 3497605      -0.918081  -0.279329
# 3498100       0.233055  -0.061314
# 3498810      -0.512442  -0.118764
#
#          fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 3496505                                          -0.395266
# 3496787                                          -0.395266
# 3497101                                          -0.246144
# 3497327                                          -0.395266
# 3497449                                          -0.394728
# 3497561                                          -0.223466
# 3497605                                           1.236835
# 3498100                                           0.759230
# 3498810                                          -0.395266
#
#          last_modified_year               preprocessed_product_name  \
# 3496505                2023                 choco caraïbes  vanille
# 3496787                2024                                pelardon
# 3497101                2023                                    skyr
# 3497327                2024                   mini croissant beurre
# 3497449                2023                   saucisses de volaille
# 3497561                2023  cornet à la glace fabriquée à la ferme
# 3497605                2023                                 ketchup
# 3498100                2023                            mini stollen
# 3498810                2024                          yaourt vanille
#
#         preprocessed_packaging_tags  \
# 3496505                     unknown
# 3496787                           4
# 3497101                     unknown
# 3497327                     unknown
# 3497449                     unknown
# 3497561                     unknown
# 3497605                     unknown
# 3498100                     unknown
# 3498810                     unknown
#
#                               preprocessed_categories_tags  \
# 3496505              desserts frozen foods frozen desserts
# 3496787  dairies fermented foods fermented milk product...
# 3497101  dairies fermented foods fermented milk product...
# 3497327                                            unknown
# 3497449  meats and their products prepared meats sausag...
# 3497561                                            unknown
# 3497605            condiments sauces tomato sauces ketchup
# 3498100  snacks sweet snacks festive foods biscuits and...
# 3498810  dairies fermented foods fermented milk product...
#
#                              preprocessed_ingredients_tags  \
# 3496505  milk dairy cream sugar added sugar disaccharid...
# 3496787  whole goat milk dairy milk goat milk ferment r...
# 3497101  lait pasteurise a 2 2 de matiere grasse bluebe...
# 3497327  flour bau yeast sel poudre de lait entier barl...
# 3497449  poultry meat poultry chicken skin poultry skin...
# 3497561  cornet glace caramel eclats de pralin saveurs ...
# 3497605  tomato vegetable fruit vegetable onion root ve...
# 3498100  marzipan wheat flour cereal flour wheat cereal...
# 3498810  whole milk dairy milk cream sugar added sugar ...
#
#                     preprocessed_ingredients_analysis_tags  \
# 3496505  may contain palm oil non vegan vegetarian stat...
# 3496787           palm oil free non vegan maybe vegetarian
# 3497101  palm oil free vegan status unknown vegetarian ...
# 3497327  palm oil content unknown non vegan vegetarian ...
# 3497449             palm oil free non vegan non vegetarian
# 3497561  palm oil content unknown non vegan vegetarian ...
# 3497605  palm oil free vegan status unknown vegetarian ...
# 3498100       palm oil non vegan vegetarian status unknown
# 3498810  palm oil free non vegan vegetarian status unknown
#
#                          preprocessed_nutrient_levels_tags  \
# 3496505                                            unknown
# 3496787  fat in high quantity saturated fat in high qua...
# 3497101  fat in low quantity saturated fat in low quant...
# 3497327                                            unknown
# 3497449  fat in moderate quantity saturated fat in mode...
# 3497561                                            unknown
# 3497605                                            unknown
# 3498100  fat in high quantity saturated fat in high qua...
# 3498810  fat in moderate quantity saturated fat in high...
#
#         preprocessed_nutriscore_grade preprocessed_main_category  \
# 3496505                       unknown            frozen desserts
# 3496787                       unknown                   pelardon
# 3497101                             a                      skyrs
# 3497327                       unknown                       none
# 3497449                             b           poultry sausages
# 3497561                       unknown                       none
# 3497605                       unknown                    ketchup
# 3498100                             e                    stollen
# 3498810                             c             vanilla yogurt
#
#         preprocessed_ecoscore_grade  \
# 3496505                     unknown
# 3496787                           d
# 3497101                           b
# 3497327                     unknown
# 3497449                           d
# 3497561                     unknown
# 3497605                           b
# 3498100                     unknown
# 3498810                           b
#
#                               preprocessed_popularity_tags  cluster
# 3496505                                            unknown       45
# 3496787                                            unknown       33
# 3497101                                            unknown       32
# 3497327                                            unknown      306
# 3497449                                            unknown      513
# 3497561                                            unknown       59
# 3497605                                            unknown      510
# 3498100                                            unknown      473
# 3498810  bottom 25 percent scans 2019bottom 20 percent ...       95

# %%
find_similar_products(clean_data, "Choco caraïbes & vanille")
# Out:
# encode_categorical_data_with_svd
# column preprocessed_product_name
# encoded.shape 52
# adjusted_n_components: 50
# column preprocessed_packaging_tags
# encoded.shape 19
# adjusted_n_components: 19
# column preprocessed_categories_tags
# encoded.shape 29
# adjusted_n_components: 29
# column preprocessed_ingredients_tags
# encoded.shape 273
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_main_category
# encoded.shape 20
# adjusted_n_components: 20
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  20
#               code                                                url  \
# 63   3270160821266  http://world-en.openfoodfacts.org/product/3270...
# 171  3760385230504  http://world-en.openfoodfacts.org/product/3760...
# 28   3250391526086  http://world-en.openfoodfacts.org/product/3250...
# 57   3270160730414  http://world-en.openfoodfacts.org/product/3270...
# 13   3184830032671  http://world-en.openfoodfacts.org/product/3184...
# 93   3292590503222  http://world-en.openfoodfacts.org/product/3292...
# 110  3428420011265  http://world-en.openfoodfacts.org/product/3428...
# 64   3270160821280  http://world-en.openfoodfacts.org/product/3270...
# 162  3760156370248  http://world-en.openfoodfacts.org/product/3760...
# 32   3256220064491  http://world-en.openfoodfacts.org/product/3256...
#
#                                           product_name  \
# 63                    2 Rennes Glacés Chocolat-Vanille
# 171                   Pot crème glacée vanille cookies
# 28                     Bûche glacée façon crème brûlée
# 57                    4 vanille macadamia crème glacée
# 13              Chocolat avec copeaux de chocolat noir
# 93                             Glace brownies chocolat
# 110                          Crème glacée façon Rocher
# 64   Chocolat noir nougat Crème glacée au chocolat ...
# 162                    Crème glacée café noix de pécan
# 32                            Crème glacée 3 chocolats
#
#                                         packaging_tags  \
# 63                   en:plastic,en:cardboard,en:frozen
# 171                                         en:unknown
# 28                                          en:unknown
# 57   en:plastic,en:cardboard,en:frozen,fr:batonnet-...
# 13                                          en:unknown
# 93                                          en:unknown
# 110                                         en:unknown
# 64   en:plastic,en:cardboard,en:frozen,en:sleeve,fr...
# 162                                         en:unknown
# 32                                           en:frozen
#
#                                        categories_tags  \
# 63   en:desserts,en:festive-foods,en:frozen-foods,e...
# 171  en:desserts,en:frozen-foods,en:frozen-desserts...
# 28   en:desserts,en:festive-foods,en:frozen-foods,e...
# 57   en:desserts,en:frozen-foods,en:frozen-desserts...
# 13                                          en:unknown
# 93   en:desserts,en:frozen-foods,en:frozen-desserts...
# 110  en:desserts,en:frozen-foods,en:frozen-desserts...
# 64      en:desserts,en:frozen-foods,en:frozen-desserts
# 162  en:desserts,en:frozen-foods,en:frozen-desserts...
# 32   en:desserts,en:frozen-foods,en:frozen-desserts...
#
#                                       ingredients_tags  \
# 63   en:whole-milk,en:dairy,en:milk,en:water,en:liq...
# 171  en:water,en:cream,en:dairy,en:sugar,en:added-s...
# 28   en:water,en:fresh-cream,en:dairy,en:cream,en:l...
# 57   en:milk-chocolate,en:chocolate,en:water,en:con...
# 13   en:water,en:reconstituted-skimmed-milk,en:dair...
# 93   en:skimmed-milk,en:dairy,en:milk,en:fresh-crea...
# 110  en:pasteurised-whole-milk,en:dairy,en:milk,en:...
# 64   en:water,en:reconstituted-skimmed-milk,en:dair...
# 162  fr:creme-glacee-cafe,fr:lait-entier-fermier,en...
# 32   en:whole-milk,en:dairy,en:milk,en:water,en:cre...
#
#                              ingredients_analysis_tags allergens  \
# 63   en:palm-oil-free,en:non-vegan,en:vegetarian-st...   en:milk
# 171  en:may-contain-palm-oil,en:non-vegan,en:vegeta...     other
# 28   en:may-contain-palm-oil,en:non-vegan,en:vegeta...     other
# 57   en:palm-oil-content-unknown,en:non-vegan,en:ve...     other
# 13   en:may-contain-palm-oil,en:non-vegan,en:vegeta...     other
# 93   en:palm-oil-content-unknown,en:non-vegan,en:ve...   en:none
# 110  en:may-contain-palm-oil,en:non-vegan,en:vegeta...   en:nuts
# 64   en:palm-oil-free,en:non-vegan,en:vegetarian-st...     other
# 162  en:may-contain-palm-oil,en:non-vegan,en:vegeta...     other
# 32   en:may-contain-palm-oil,en:non-vegan,en:vegeta...     other
#
#                               traces_tags  \
# 63      en:gluten,en:nuts,en:sesame-seeds
# 171                               en:none
# 28                  en:gluten,en:soybeans
# 57           en:gluten,en:nuts,en:peanuts
# 13   en:eggs,en:gluten,en:nuts,en:peanuts
# 93                                en:none
# 110            en:eggs,en:nuts,en:peanuts
# 64           en:gluten,en:nuts,en:peanuts
# 162      en:gluten,en:peanuts,en:soybeans
# 32   en:eggs,en:gluten,en:nuts,en:peanuts
#
#                                         additives_tags nutriscore_grade  \
# 63            en:e322,en:e322i,en:e407,en:e412,en:e471                d
# 171  en:e322,en:e322i,en:e412,en:e471,en:e500,en:e5...                d
# 28   en:e150a,en:e160,en:e160b,en:e270,en:e407,en:e...                d
# 57            en:e322,en:e322i,en:e417,en:e471,en:e500                d
# 13                            en:e322,en:e322i,en:e471          unknown
# 93          en:e322,en:e322i,en:e440,en:e500,en:e500ii                d
# 110                           en:e322,en:e322i,en:e471                d
# 64           en:e322,en:e322i,en:e417,en:e471,en:e472b                c
# 162   en:e322,en:e322i,en:e401,en:e407,en:e412,en:e471                d
# 32   en:e322,en:e322i,en:e412,en:e417,en:e440,en:e4...                d
#
#                             food_groups_tags  \
# 63                                   en:none
# 171  en:milk-and-dairy-products,en:ice-cream
# 28                                   en:none
# 57   en:milk-and-dairy-products,en:ice-cream
# 13                                   en:none
# 93   en:milk-and-dairy-products,en:ice-cream
# 110  en:milk-and-dairy-products,en:ice-cream
# 64                                   en:none
# 162  en:milk-and-dairy-products,en:ice-cream
# 32   en:milk-and-dairy-products,en:ice-cream
#
#                                            states_tags ecoscore_grade  \
# 63   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 171  en:to-be-completed,en:nutrition-facts-complete...              b
# 28   en:to-be-completed,en:nutrition-facts-complete...              b
# 57   en:to-be-checked,en:complete,en:nutrition-fact...              b
# 13   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 93   en:to-be-completed,en:nutrition-facts-complete...              b
# 110  en:to-be-completed,en:nutrition-facts-complete...              b
# 64   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 162  en:to-be-completed,en:nutrition-facts-complete...              b
# 32   en:to-be-completed,en:nutrition-facts-complete...        unknown
#
#                                   nutrient_levels_tags  \
# 63   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 171  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 28   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 57   en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 13                                          en:unknown
# 93   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 110  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 64   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 162  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 32   en:fat-in-moderate-quantity,en:saturated-fat-i...
#
#                                        popularity_tags  \
# 63                                             unknown
# 171                                            unknown
# 28                                             unknown
# 57   top-50000-scans-2019,top-100000-scans-2019,at-...
# 13                                             unknown
# 93   bottom-25-percent-scans-2020,top-80-percent-sc...
# 110  top-75-percent-scans-2021,top-80-percent-scans...
# 64                           top-country-fr-scans-2019
# 162                                            unknown
# 32   top-100000-scans-2019,at-least-5-scans-2019,to...
#
#                  main_category  \
# 63          en:frozen-desserts
# 171              en:ice-creams
# 28            en:ice-cream-log
# 57   en:vanilla-ice-cream-bars
# 13                     en:none
# 93           en:ice-cream-tubs
# 110          en:ice-cream-tubs
# 64          en:frozen-desserts
# 162   en:coffee-ice-cream-tubs
# 32   en:ice-creams-and-sorbets
#
#                                              image_url  energy_100g  fat_100g  \
# 63   https://images.openfoodfacts.org/images/produc...    -0.001978  0.056961
# 171  https://images.openfoodfacts.org/images/produc...    -0.001978 -0.002863
# 28   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.170371
# 57   https://images.openfoodfacts.org/images/produc...    -0.001978  0.595376
# 13   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.236177
# 93   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.128494
# 110  https://images.openfoodfacts.org/images/produc...    -0.001978  0.302239
# 64   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.146441
# 162  https://images.openfoodfacts.org/images/produc...    -0.001978 -0.002863
# 32   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.140459
#
#      saturated-fat_100g  cholesterol_100g  sugars_100g  proteins_100g  \
# 63             0.480970         -0.030242     0.672633      -0.358957
# 171            0.416475         -0.030242     0.568548      -0.413773
# 28             0.171393         -0.030242     0.709063      -0.578221
# 57             1.216217         -0.030242     0.828760      -0.249325
# 13             0.093998         -0.030242     0.516506      -0.468589
# 93             0.210090         -0.030242     0.620591      -0.260289
# 110            0.455172         -0.030242     0.802739      -0.293178
# 64             0.132696         -0.030242     0.204252      -0.402810
# 162            0.261686         -0.030242     0.672633      -0.380884
# 32             0.235888         -0.030242     0.620591      -0.490516
#
#      salt_100g  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 63   -0.115818                                          -0.388979
# 171  -0.117291                                          -0.395266
# 28   -0.102560                                          -0.395266
# 57   -0.112871                                          -0.321049
# 13   -0.111398                                          -0.395266
# 93   -0.093721                                          -0.395266
# 110  -0.117291                                          -0.317956
# 64   -0.112871                                          -0.346518
# 162  -0.106979                                           0.614918
# 32   -0.108452                                          -0.395266
#
#      last_modified_year                          preprocessed_product_name  \
# 63                 2022                   2 rennes glacés chocolat vanille
# 171                2024                   pot crème glacée vanille cookies
# 28                 2023                    bûche glacée façon crème brûlée
# 57                 2023                   4 vanille macadamia crème glacée
# 13                 2023             chocolat avec copeaux de chocolat noir
# 93                 2023                            glace brownies chocolat
# 110                2022                          crème glacée façon rocher
# 64                 2022  chocolat noir nougat crème glacée au chocolat ...
# 162                2020                    crème glacée café noix de pécan
# 32                 2023                           crème glacée 3 chocolats
#
#                       preprocessed_packaging_tags  \
# 63                       plastic cardboard frozen
# 171                                       unknown
# 28                                        unknown
# 57         plastic cardboard frozen batonnet bois
# 13                                        unknown
# 93                                        unknown
# 110                                       unknown
# 64   plastic cardboard frozen sleeve cloche socle
# 162                                       unknown
# 32                                         frozen
#
#                           preprocessed_categories_tags  \
# 63   desserts festive foods frozen foods christmas ...
# 171  desserts frozen foods frozen desserts ice crea...
# 28   desserts festive foods frozen foods christmas ...
# 57   desserts frozen foods frozen desserts ice crea...
# 13                                             unknown
# 93   desserts frozen foods frozen desserts ice crea...
# 110  desserts frozen foods frozen desserts ice crea...
# 64               desserts frozen foods frozen desserts
# 162  desserts frozen foods frozen desserts ice crea...
# 32   desserts frozen foods frozen desserts ice crea...
#
#                          preprocessed_ingredients_tags  \
# 63   whole milk dairy milk water liquid sugar added...
# 171  water cream dairy sugar added sugar disacchari...
# 28   water fresh cream dairy cream lactose proteine...
# 57   milk chocolate chocolate water condensed skimm...
# 13   water reconstituted skimmed milk dairy milk sk...
# 93   skimmed milk dairy milk fresh cream cream crem...
# 110  pasteurised whole milk dairy milk pasteurised ...
# 64   water reconstituted skimmed milk dairy milk sk...
# 162  creme glacee cafe lait entier fermier sugar ad...
# 32   whole milk dairy milk water cream sugar added ...
#
#                 preprocessed_ingredients_analysis_tags  \
# 63   palm oil free non vegan vegetarian status unknown
# 171  may contain palm oil non vegan vegetarian stat...
# 28   may contain palm oil non vegan vegetarian stat...
# 57   palm oil content unknown non vegan vegetarian ...
# 13   may contain palm oil non vegan vegetarian stat...
# 93   palm oil content unknown non vegan vegetarian ...
# 110  may contain palm oil non vegan vegetarian stat...
# 64   palm oil free non vegan vegetarian status unknown
# 162  may contain palm oil non vegan vegetarian stat...
# 32   may contain palm oil non vegan vegetarian stat...
#
#                      preprocessed_nutrient_levels_tags  \
# 63   fat in moderate quantity saturated fat in high...
# 171  fat in moderate quantity saturated fat in high...
# 28   fat in moderate quantity saturated fat in high...
# 57   fat in high quantity saturated fat in high qua...
# 13                                             unknown
# 93   fat in moderate quantity saturated fat in high...
# 110  fat in moderate quantity saturated fat in high...
# 64   fat in moderate quantity saturated fat in high...
# 162  fat in moderate quantity saturated fat in high...
# 32   fat in moderate quantity saturated fat in high...
#
#     preprocessed_nutriscore_grade preprocessed_main_category  \
# 63                              d            frozen desserts
# 171                             d                 ice creams
# 28                              d              ice cream log
# 57                              d     vanilla ice cream bars
# 13                        unknown                       none
# 93                              d             ice cream tubs
# 110                             d             ice cream tubs
# 64                              c            frozen desserts
# 162                             d      coffee ice cream tubs
# 32                              d     ice creams and sorbets
#
#     preprocessed_ecoscore_grade  \
# 63                      unknown
# 171                           b
# 28                            b
# 57                            b
# 13                      unknown
# 93                            b
# 110                           b
# 64                      unknown
# 162                           b
# 32                      unknown
#
#                           preprocessed_popularity_tags  cluster  similarity
# 63                                             unknown       45    0.751038
# 171                                            unknown       45    0.738370
# 28                                             unknown       45    0.724604
# 57   top 50000 scans 2019top 100000 scans 2019at le...       45    0.722907
# 13                                             unknown       45    0.715596
# 93   bottom 25 percent scans 2020top 80 percent sca...       45    0.711912
# 110  top 75 percent scans 2021top 80 percent scans ...       45    0.711228
# 64                           top country fr scans 2019       45    0.710916
# 162                                            unknown       45    0.705775
# 32   top 100000 scans 2019at least 5 scans 2019top ...       45    0.702231

# %%
find_similar_products(clean_data, "Choco caraïbes & vanille", "milk")
# Out:
# encode_categorical_data_with_svd
# column preprocessed_product_name
# encoded.shape 36
# adjusted_n_components: 36
# column preprocessed_packaging_tags
# encoded.shape 17
# adjusted_n_components: 17
# column preprocessed_categories_tags
# encoded.shape 27
# adjusted_n_components: 27
# column preprocessed_ingredients_tags
# encoded.shape 235
# adjusted_n_components: 50
# column preprocessed_ingredients_analysis_tags
# encoded.shape 12
# adjusted_n_components: 12
# column preprocessed_main_category
# encoded.shape 18
# adjusted_n_components: 18
# [INFO][CountVectorizer] : Nombre de features dans le vocabulaire :  18
#               code                                                url  \
# 129  3760385230504  http://world-en.openfoodfacts.org/product/3760...
# 18   3250391526086  http://world-en.openfoodfacts.org/product/3250...
# 44   3270160730414  http://world-en.openfoodfacts.org/product/3270...
# 7    3184830032671  http://world-en.openfoodfacts.org/product/3184...
# 120  3760156370248  http://world-en.openfoodfacts.org/product/3760...
# 83   3428420011265  http://world-en.openfoodfacts.org/product/3428...
# 69   3292590503222  http://world-en.openfoodfacts.org/product/3292...
# 47   3270160821280  http://world-en.openfoodfacts.org/product/3270...
# 22   3256220064491  http://world-en.openfoodfacts.org/product/3256...
# 90   3475884001547  http://world-en.openfoodfacts.org/product/3475...
#
#                                           product_name  \
# 129                   Pot crème glacée vanille cookies
# 18                     Bûche glacée façon crème brûlée
# 44                    4 vanille macadamia crème glacée
# 7               Chocolat avec copeaux de chocolat noir
# 120                    Crème glacée café noix de pécan
# 83                           Crème glacée façon Rocher
# 69                             Glace brownies chocolat
# 47   Chocolat noir nougat Crème glacée au chocolat ...
# 22                            Crème glacée 3 chocolats
# 90                                 Piémontais 12 Parts
#
#                                         packaging_tags  \
# 129                                         en:unknown
# 18                                          en:unknown
# 44   en:plastic,en:cardboard,en:frozen,fr:batonnet-...
# 7                                           en:unknown
# 120                                         en:unknown
# 83                                          en:unknown
# 69                                          en:unknown
# 47   en:plastic,en:cardboard,en:frozen,en:sleeve,fr...
# 22                                           en:frozen
# 90                                          en:unknown
#
#                                        categories_tags  \
# 129  en:desserts,en:frozen-foods,en:frozen-desserts...
# 18   en:desserts,en:festive-foods,en:frozen-foods,e...
# 44   en:desserts,en:frozen-foods,en:frozen-desserts...
# 7                                           en:unknown
# 120  en:desserts,en:frozen-foods,en:frozen-desserts...
# 83   en:desserts,en:frozen-foods,en:frozen-desserts...
# 69   en:desserts,en:frozen-foods,en:frozen-desserts...
# 47      en:desserts,en:frozen-foods,en:frozen-desserts
# 22   en:desserts,en:frozen-foods,en:frozen-desserts...
# 90      en:desserts,en:frozen-foods,en:frozen-desserts
#
#                                       ingredients_tags  \
# 129  en:water,en:cream,en:dairy,en:sugar,en:added-s...
# 18   en:water,en:fresh-cream,en:dairy,en:cream,en:l...
# 44   en:milk-chocolate,en:chocolate,en:water,en:con...
# 7    en:water,en:reconstituted-skimmed-milk,en:dair...
# 120  fr:creme-glacee-cafe,fr:lait-entier-fermier,en...
# 83   en:pasteurised-whole-milk,en:dairy,en:milk,en:...
# 69   en:skimmed-milk,en:dairy,en:milk,en:fresh-crea...
# 47   en:water,en:reconstituted-skimmed-milk,en:dair...
# 22   en:whole-milk,en:dairy,en:milk,en:water,en:cre...
# 90   en:fresh-whole-milk,en:dairy,en:milk,en:whole-...
#
#                              ingredients_analysis_tags  allergens  \
# 129  en:may-contain-palm-oil,en:non-vegan,en:vegeta...      other
# 18   en:may-contain-palm-oil,en:non-vegan,en:vegeta...      other
# 44   en:palm-oil-content-unknown,en:non-vegan,en:ve...      other
# 7    en:may-contain-palm-oil,en:non-vegan,en:vegeta...      other
# 120  en:may-contain-palm-oil,en:non-vegan,en:vegeta...      other
# 83   en:may-contain-palm-oil,en:non-vegan,en:vegeta...    en:nuts
# 69   en:palm-oil-content-unknown,en:non-vegan,en:ve...    en:none
# 47   en:palm-oil-free,en:non-vegan,en:vegetarian-st...      other
# 22   en:may-contain-palm-oil,en:non-vegan,en:vegeta...      other
# 90   en:palm-oil-content-unknown,en:non-vegan,en:ve...  en:gluten
#
#                               traces_tags  \
# 129                               en:none
# 18                  en:gluten,en:soybeans
# 44           en:gluten,en:nuts,en:peanuts
# 7    en:eggs,en:gluten,en:nuts,en:peanuts
# 120      en:gluten,en:peanuts,en:soybeans
# 83             en:eggs,en:nuts,en:peanuts
# 69                                en:none
# 47           en:gluten,en:nuts,en:peanuts
# 22   en:eggs,en:gluten,en:nuts,en:peanuts
# 90                                en:none
#
#                                         additives_tags nutriscore_grade  \
# 129  en:e322,en:e322i,en:e412,en:e471,en:e500,en:e5...                d
# 18   en:e150a,en:e160,en:e160b,en:e270,en:e407,en:e...                d
# 44            en:e322,en:e322i,en:e417,en:e471,en:e500                d
# 7                             en:e322,en:e322i,en:e471          unknown
# 120   en:e322,en:e322i,en:e401,en:e407,en:e412,en:e471                d
# 83                            en:e322,en:e322i,en:e471                d
# 69          en:e322,en:e322i,en:e440,en:e500,en:e500ii                d
# 47           en:e322,en:e322i,en:e417,en:e471,en:e472b                c
# 22   en:e322,en:e322i,en:e412,en:e417,en:e440,en:e4...                d
# 90   en:e153,en:e322,en:e322i,en:e401,en:e407,en:e4...          unknown
#
#                             food_groups_tags  \
# 129  en:milk-and-dairy-products,en:ice-cream
# 18                                   en:none
# 44   en:milk-and-dairy-products,en:ice-cream
# 7                                    en:none
# 120  en:milk-and-dairy-products,en:ice-cream
# 83   en:milk-and-dairy-products,en:ice-cream
# 69   en:milk-and-dairy-products,en:ice-cream
# 47                                   en:none
# 22   en:milk-and-dairy-products,en:ice-cream
# 90                                   en:none
#
#                                            states_tags ecoscore_grade  \
# 129  en:to-be-completed,en:nutrition-facts-complete...              b
# 18   en:to-be-completed,en:nutrition-facts-complete...              b
# 44   en:to-be-checked,en:complete,en:nutrition-fact...              b
# 7    en:to-be-completed,en:nutrition-facts-complete...        unknown
# 120  en:to-be-completed,en:nutrition-facts-complete...              b
# 83   en:to-be-completed,en:nutrition-facts-complete...              b
# 69   en:to-be-completed,en:nutrition-facts-complete...              b
# 47   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 22   en:to-be-completed,en:nutrition-facts-complete...        unknown
# 90   en:to-be-completed,en:nutrition-facts-to-be-co...        unknown
#
#                                   nutrient_levels_tags  \
# 129  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 18   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 44   en:fat-in-high-quantity,en:saturated-fat-in-hi...
# 7                                           en:unknown
# 120  en:fat-in-moderate-quantity,en:saturated-fat-i...
# 83   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 69   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 47   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 22   en:fat-in-moderate-quantity,en:saturated-fat-i...
# 90                                          en:unknown
#
#                                        popularity_tags  \
# 129                                            unknown
# 18                                             unknown
# 44   top-50000-scans-2019,top-100000-scans-2019,at-...
# 7                                              unknown
# 120                                            unknown
# 83   top-75-percent-scans-2021,top-80-percent-scans...
# 69   bottom-25-percent-scans-2020,top-80-percent-sc...
# 47                           top-country-fr-scans-2019
# 22   top-100000-scans-2019,at-least-5-scans-2019,to...
# 90   top-75-percent-scans-2023,top-80-percent-scans...
#
#                  main_category  \
# 129              en:ice-creams
# 18            en:ice-cream-log
# 44   en:vanilla-ice-cream-bars
# 7                      en:none
# 120   en:coffee-ice-cream-tubs
# 83           en:ice-cream-tubs
# 69           en:ice-cream-tubs
# 47          en:frozen-desserts
# 22   en:ice-creams-and-sorbets
# 90          en:frozen-desserts
#
#                                              image_url  energy_100g  fat_100g  \
# 129  https://images.openfoodfacts.org/images/produc...    -0.001978 -0.002863
# 18   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.170371
# 44   https://images.openfoodfacts.org/images/produc...    -0.001978  0.595376
# 7    https://images.openfoodfacts.org/images/produc...    -0.001978 -0.236177
# 120  https://images.openfoodfacts.org/images/produc...    -0.001978 -0.002863
# 83   https://images.openfoodfacts.org/images/produc...    -0.001978  0.302239
# 69   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.128494
# 47   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.146441
# 22   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.140459
# 90   https://images.openfoodfacts.org/images/produc...    -0.001978 -0.780575
#
#      saturated-fat_100g  cholesterol_100g  sugars_100g  proteins_100g  \
# 129            0.416475         -0.030242     0.568548      -0.413773
# 18             0.171393         -0.030242     0.709063      -0.578221
# 44             1.216217         -0.030242     0.828760      -0.249325
# 7              0.093998         -0.030242     0.516506      -0.468589
# 120            0.261686         -0.030242     0.672633      -0.380884
# 83             0.455172         -0.030242     0.802739      -0.293178
# 69             0.210090         -0.030242     0.620591      -0.260289
# 47             0.132696         -0.030242     0.204252      -0.402810
# 22             0.235888         -0.030242     0.620591      -0.490516
# 90            -0.718642         -0.030242    -0.680469      -0.918081
#
#      salt_100g  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 129  -0.117291                                          -0.395266
# 18   -0.102560                                          -0.395266
# 44   -0.112871                                          -0.321049
# 7    -0.111398                                          -0.395266
# 120  -0.106979                                           0.614918
# 83   -0.117291                                          -0.317956
# 69   -0.093721                                          -0.395266
# 47   -0.112871                                          -0.346518
# 22   -0.108452                                          -0.395266
# 90   -0.279329                                          -0.250310
#
#      last_modified_year                          preprocessed_product_name  \
# 129                2024                   pot crème glacée vanille cookies
# 18                 2023                    bûche glacée façon crème brûlée
# 44                 2023                   4 vanille macadamia crème glacée
# 7                  2023             chocolat avec copeaux de chocolat noir
# 120                2020                    crème glacée café noix de pécan
# 83                 2022                          crème glacée façon rocher
# 69                 2023                            glace brownies chocolat
# 47                 2022  chocolat noir nougat crème glacée au chocolat ...
# 22                 2023                           crème glacée 3 chocolats
# 90                 2023                                piémontais 12 parts
#
#                       preprocessed_packaging_tags  \
# 129                                       unknown
# 18                                        unknown
# 44         plastic cardboard frozen batonnet bois
# 7                                         unknown
# 120                                       unknown
# 83                                        unknown
# 69                                        unknown
# 47   plastic cardboard frozen sleeve cloche socle
# 22                                         frozen
# 90                                        unknown
#
#                           preprocessed_categories_tags  \
# 129  desserts frozen foods frozen desserts ice crea...
# 18   desserts festive foods frozen foods christmas ...
# 44   desserts frozen foods frozen desserts ice crea...
# 7                                              unknown
# 120  desserts frozen foods frozen desserts ice crea...
# 83   desserts frozen foods frozen desserts ice crea...
# 69   desserts frozen foods frozen desserts ice crea...
# 47               desserts frozen foods frozen desserts
# 22   desserts frozen foods frozen desserts ice crea...
# 90               desserts frozen foods frozen desserts
#
#                          preprocessed_ingredients_tags  \
# 129  water cream dairy sugar added sugar disacchari...
# 18   water fresh cream dairy cream lactose proteine...
# 44   milk chocolate chocolate water condensed skimm...
# 7    water reconstituted skimmed milk dairy milk sk...
# 120  creme glacee cafe lait entier fermier sugar ad...
# 83   pasteurised whole milk dairy milk pasteurised ...
# 69   skimmed milk dairy milk fresh cream cream crem...
# 47   water reconstituted skimmed milk dairy milk sk...
# 22   whole milk dairy milk water cream sugar added ...
# 90   fresh whole milk dairy milk whole milk fresh m...
#
#                 preprocessed_ingredients_analysis_tags  \
# 129  may contain palm oil non vegan vegetarian stat...
# 18   may contain palm oil non vegan vegetarian stat...
# 44   palm oil content unknown non vegan vegetarian ...
# 7    may contain palm oil non vegan vegetarian stat...
# 120  may contain palm oil non vegan vegetarian stat...
# 83   may contain palm oil non vegan vegetarian stat...
# 69   palm oil content unknown non vegan vegetarian ...
# 47   palm oil free non vegan vegetarian status unknown
# 22   may contain palm oil non vegan vegetarian stat...
# 90   palm oil content unknown non vegan vegetarian ...
#
#                      preprocessed_nutrient_levels_tags  \
# 129  fat in moderate quantity saturated fat in high...
# 18   fat in moderate quantity saturated fat in high...
# 44   fat in high quantity saturated fat in high qua...
# 7                                              unknown
# 120  fat in moderate quantity saturated fat in high...
# 83   fat in moderate quantity saturated fat in high...
# 69   fat in moderate quantity saturated fat in high...
# 47   fat in moderate quantity saturated fat in high...
# 22   fat in moderate quantity saturated fat in high...
# 90                                             unknown
#
#     preprocessed_nutriscore_grade preprocessed_main_category  \
# 129                             d                 ice creams
# 18                              d              ice cream log
# 44                              d     vanilla ice cream bars
# 7                         unknown                       none
# 120                             d      coffee ice cream tubs
# 83                              d             ice cream tubs
# 69                              d             ice cream tubs
# 47                              c            frozen desserts
# 22                              d     ice creams and sorbets
# 90                        unknown            frozen desserts
#
#     preprocessed_ecoscore_grade  \
# 129                           b
# 18                            b
# 44                            b
# 7                       unknown
# 120                           b
# 83                            b
# 69                            b
# 47                      unknown
# 22                      unknown
# 90                      unknown
#
#                           preprocessed_popularity_tags  cluster  similarity
# 129                                            unknown       45    0.737697
# 18                                             unknown       45    0.716459
# 44   top 50000 scans 2019top 100000 scans 2019at le...       45    0.715817
# 7                                              unknown       45    0.707578
# 120                                            unknown       45    0.701841
# 83   top 75 percent scans 2021top 80 percent scans ...       45    0.701604
# 69   bottom 25 percent scans 2020top 80 percent sca...       45    0.701242
# 47                           top country fr scans 2019       45    0.699609
# 22   top 100000 scans 2019at least 5 scans 2019top ...       45    0.695352
# 90   top 75 percent scans 2023top 80 percent scans ...       45    0.687110

# %% [markdown]
# ### Notes

# %%
clean_data['code'].value_counts() ## Drop duplicates subset (code, product_name)
# Out:
# code
# 3220034020004    2
# 3250391652983    2
# 3240931546681    2
# 3220033120002    2
# 3523680248427    2
#                 ..
# 3258590000321    1
# 3258590000338    1
# 3258590000352    1
# 3258590000369    1
# 3258590000024    1
# Name: count, Length: 254765, dtype: int64
